# %% [markdown]
# # CNN_UTK_Model for AgeRange detection

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
plt.style.use('ggplot')

# %% [markdown]
# ### Data preprocessing

# %%
df = pd.read_csv('./dataset/UTK_dataset.csv')
df.head()
# Out:
#    age  ethnicity  gender                        img_name  \
# 0    1          2       0  20161219203650636.jpg.chip.jpg
# 1    1          2       0  20161219222752047.jpg.chip.jpg
# 2    1          2       0  20161219222832191.jpg.chip.jpg
# 3    1          2       0  20161220144911423.jpg.chip.jpg
# 4    1          2       0  20161220144914327.jpg.chip.jpg
#
#                                               pixels
# 0  129 128 128 126 127 130 133 135 139 142 145 14...
# 1  164 74 111 168 169 171 175 182 184 188 193 199...
# 2  67 70 71 70 69 67 70 79 90 103 116 132 145 155...
# 3  193 197 198 200 199 200 202 203 204 205 208 21...
# 4  202 205 209 210 209 209 210 211 212 214 218 21...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23705 entries, 0 to 23704
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        23705 non-null  int64
#  1   ethnicity  23705 non-null  int64
#  2   gender     23705 non-null  int64
#  3   img_name   23705 non-null  object
#  4   pixels     23705 non-null  object
# dtypes: int64(3), object(2)
# memory usage: 926.1+ KB

# %%
df.describe()
# Out:
#                 age     ethnicity        gender
# count  23705.000000  23705.000000  23705.000000
# mean      33.300907      1.269226      0.477283
# std       19.885708      1.345638      0.499494
# min        1.000000      0.000000      0.000000
# 25%       23.000000      0.000000      0.000000
# 50%       29.000000      1.000000      0.000000
# 75%       45.000000      2.000000      1.000000
# max      116.000000      4.000000      1.000000

# %%
df.isna().sum()
# Out:
# age          0
# ethnicity    0
# gender       0
# img_name     0
# pixels       0
# dtype: int64

# %%
df['pixels']=df['pixels'].apply(lambda x:  np.array(x.split(), dtype="float32"))

df.head()
# Out:
#    age  ethnicity  gender                        img_name  \
# 0    1          2       0  20161219203650636.jpg.chip.jpg
# 1    1          2       0  20161219222752047.jpg.chip.jpg
# 2    1          2       0  20161219222832191.jpg.chip.jpg
# 3    1          2       0  20161220144911423.jpg.chip.jpg
# 4    1          2       0  20161220144914327.jpg.chip.jpg
#
#                                               pixels
# 0  [129.0, 128.0, 128.0, 126.0, 127.0, 130.0, 133...
# 1  [164.0, 74.0, 111.0, 168.0, 169.0, 171.0, 175....
# 2  [67.0, 70.0, 71.0, 70.0, 69.0, 67.0, 70.0, 79....
# 3  [193.0, 197.0, 198.0, 200.0, 199.0, 200.0, 202...
# 4  [202.0, 205.0, 209.0, 210.0, 209.0, 209.0, 210...

# %% [markdown]
# ### Data analysis

# %%
sns.histplot(data=df, x='age')
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
plt.figure(figsize=(16,16))
for i in range(1500,1520):
    plt.subplot(5,5,(i%25)+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(df['pixels'].iloc[i].reshape(48,48))
    plt.xlabel(
        "Age:"+str(df['age'].iloc[i]))
plt.show()

# %%
X = np.array(df['pixels'].tolist())
y = df['age'] // 5 # taking range of 5

# %%
scaler = MinMaxScaler()
X = scaler.fit_transform(X)

# %%
X = X.reshape(X.shape[0],48,48,1)

# %%
X[:5].shape
# Out:
# (5, 48, 48, 1)

# %%
y[:5].shape
# Out:
# (5,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %% [markdown]
# ### Model creation

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Conv2D, MaxPooling2D, Dense, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.utils import plot_model

# %%
model = Sequential()

model.add(InputLayer(input_shape=(48, 48, 1)))
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

model.add(Flatten())

model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='relu'))

model.compile(loss="mse", optimizer="adam", metrics=["mae", "accuracy"])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 46, 46, 32)        320
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 23, 23, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 21, 21, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 6400)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                204832
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 223,681
# Trainable params: 223,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model, to_file='models/cnn_utk_model_2_age-range.png')

# %%
filepath = 'checkpoints/age_range_model2_normalized.epoch{epoch:02d}-loss{val_loss:.2f}.hdf5'
checkpoint = ModelCheckpoint(filepath, monitor="val_loss", save_best_only=True, mode="min", verbose=1)

# %%
model.fit(X_train, y_train, epochs=20, batch_size=64, validation_data=(X_test, y_test), callbacks=[checkpoint])
# Out:
# Epoch 1/20
# 333/334 [============================>.] - ETA: 0s - loss: 14.3619 - mae: 2.9030 - accuracy: 0.0399
# Epoch 00001: val_loss improved from inf to 9.63274, saving model to checkpoints\age_range_model2_normalized.epoch01-loss9.63.hdf5
# 334/334 [==============================] - 18s 54ms/step - loss: 14.3568 - mae: 2.9028 - accuracy: 0.0399 - val_loss: 9.6327 - val_mae: 2.4627 - val_accuracy: 0.0481
# Epoch 2/20
# 333/334 [============================>.] - ETA: 0s - loss: 8.6938 - mae: 2.2387 - accuracy: 0.0592
# Epoch 00002: val_loss improved from 9.63274 to 7.78777, saving model to checkpoints\age_range_model2_normalized.epoch02-loss7.79.hdf5
# 334/334 [==============================] - 19s 58ms/step - loss: 8.6938 - mae: 2.2386 - accuracy: 0.0592 - val_loss: 7.7878 - val_mae: 2.0172 - val_accuracy: 0.0738
# Epoch 3/20
# 333/334 [============================>.] - ETA: 0s - loss: 7.1168 - mae: 2.0013 - accuracy: 0.0714
# Epoch 00003: val_loss improved from 7.78777 to 6.42177, saving model to checkpoints\age_range_model2_normalized.epoch03-loss6.42.hdf5
# 334/334 [==============================] - 22s 65ms/step - loss: 7.1138 - mae: 2.0009 - accuracy: 0.0713 - val_loss: 6.4218 - val_mae: 1.8677 - val_accuracy: 0.0696
# Epoch 4/20
# 333/334 [============================>.] - ETA: 0s - loss: 6.2783 - mae: 1.8731 - accuracy: 0.0746
# Epoch 00004: val_loss improved from 6.42177 to 5.85702, saving model to checkpoints\age_range_model2_normalized.epoch04-loss5.86.hdf5
# 334/334 [==============================] - 22s 65ms/step - loss: 6.2753 - mae: 1.8727 - accuracy: 0.0746 - val_loss: 5.8570 - val_mae: 1.7304 - val_accuracy: 0.0793
# Epoch 5/20
# 333/334 [============================>.] - ETA: 0s - loss: 5.6219 - mae: 1.7568 - accuracy: 0.0786
# Epoch 00005: val_loss did not improve from 5.85702
# 334/334 [==============================] - 21s 63ms/step - loss: 5.6222 - mae: 1.7571 - accuracy: 0.0786 - val_loss: 6.1401 - val_mae: 1.7469 - val_accuracy: 0.0818
# Epoch 6/20
# 333/334 [============================>.] - ETA: 0s - loss: 5.2526 - mae: 1.6945 - accuracy: 0.0804
# Epoch 00006: val_loss improved from 5.85702 to 5.12691, saving model to checkpoints\age_range_model2_normalized.epoch06-loss5.13.hdf5
# 334/334 [==============================] - 22s 66ms/step - loss: 5.2499 - mae: 1.6940 - accuracy: 0.0805 - val_loss: 5.1269 - val_mae: 1.6065 - val_accuracy: 0.0814
# Epoch 7/20
# 333/334 [============================>.] - ETA: 0s - loss: 4.9564 - mae: 1.6479 - accuracy: 0.0823
# Epoch 00007: val_loss improved from 5.12691 to 5.00068, saving model to checkpoints\age_range_model2_normalized.epoch07-loss5.00.hdf5
# 334/334 [==============================] - 21s 63ms/step - loss: 4.9573 - mae: 1.6482 - accuracy: 0.0823 - val_loss: 5.0007 - val_mae: 1.6064 - val_accuracy: 0.0776
# Epoch 8/20
# 333/334 [============================>.] - ETA: 0s - loss: 4.7224 - mae: 1.6058 - accuracy: 0.0825
# Epoch 00008: val_loss improved from 5.00068 to 4.86575, saving model to checkpoints\age_range_model2_normalized.epoch08-loss4.87.hdf5
# 334/334 [==============================] - 21s 63ms/step - loss: 4.7218 - mae: 1.6057 - accuracy: 0.0826 - val_loss: 4.8658 - val_mae: 1.5741 - val_accuracy: 0.0801
# Epoch 9/20
# 333/334 [============================>.] - ETA: 0s - loss: 4.5381 - mae: 1.5753 - accuracy: 0.0842
# Epoch 00009: val_loss did not improve from 4.86575
# 334/334 [==============================] - 21s 63ms/step - loss: 4.5391 - mae: 1.5753 - accuracy: 0.0842 - val_loss: 5.1354 - val_mae: 1.6837 - val_accuracy: 0.0687
# Epoch 10/20
# 333/334 [============================>.] - ETA: 0s - loss: 4.3598 - mae: 1.5431 - accuracy: 0.0850
# Epoch 00010: val_loss improved from 4.86575 to 4.74575, saving model to checkpoints\age_range_model2_normalized.epoch10-loss4.75.hdf5
# 334/334 [==============================] - 21s 64ms/step - loss: 4.3584 - mae: 1.5430 - accuracy: 0.0850 - val_loss: 4.7457 - val_mae: 1.5728 - val_accuracy: 0.0776
# Epoch 11/20
# 333/334 [============================>.] - ETA: 0s - loss: 4.1365 - mae: 1.5048 - accuracy: 0.0859
# Epoch 00011: val_loss improved from 4.74575 to 4.38317, saving model to checkpoints\age_range_model2_normalized.epoch11-loss4.38.hdf5
# 334/334 [==============================] - 20s 61ms/step - loss: 4.1356 - mae: 1.5048 - accuracy: 0.0859 - val_loss: 4.3832 - val_mae: 1.4832 - val_accuracy: 0.0831
# Epoch 12/20
# 333/334 [============================>.] - ETA: 0s - loss: 3.9758 - mae: 1.4744 - accuracy: 0.0874
# Epoch 00012: val_loss did not improve from 4.38317
# 334/334 [==============================] - 20s 61ms/step - loss: 3.9744 - mae: 1.4741 - accuracy: 0.0874 - val_loss: 4.7903 - val_mae: 1.5404 - val_accuracy: 0.0894
# Epoch 13/20
# 333/334 [============================>.] - ETA: 0s - loss: 3.8382 - mae: 1.4499 - accuracy: 0.0880
# Epoch 00013: val_loss did not improve from 4.38317
# 334/334 [==============================] - 25s 75ms/step - loss: 3.8391 - mae: 1.4498 - accuracy: 0.0879 - val_loss: 4.4479 - val_mae: 1.4987 - val_accuracy: 0.0835
# Epoch 14/20
# 333/334 [============================>.] - ETA: 0s - loss: 3.7696 - mae: 1.4313 - accuracy: 0.0900
# Epoch 00014: val_loss improved from 4.38317 to 4.27239, saving model to checkpoints\age_range_model2_normalized.epoch14-loss4.27.hdf5
# 334/334 [==============================] - 34s 103ms/step - loss: 3.7725 - mae: 1.4317 - accuracy: 0.0900 - val_loss: 4.2724 - val_mae: 1.4663 - val_accuracy: 0.0873
# Epoch 15/20
# 333/334 [============================>.] - ETA: 0s - loss: 3.5990 - mae: 1.4005 - accuracy: 0.0902
# Epoch 00015: val_loss improved from 4.27239 to 4.20289, saving model to checkpoints\age_range_model2_normalized.epoch15-loss4.20.hdf5
# 334/334 [==============================] - 34s 102ms/step - loss: 3.5984 - mae: 1.4003 - accuracy: 0.0902 - val_loss: 4.2029 - val_mae: 1.4607 - val_accuracy: 0.0822
# Epoch 16/20
# 333/334 [============================>.] - ETA: 0s - loss: 3.4865 - mae: 1.3810 - accuracy: 0.0904
# Epoch 00016: val_loss did not improve from 4.20289
# 334/334 [==============================] - 35s 106ms/step - loss: 3.4869 - mae: 1.3811 - accuracy: 0.0905 - val_loss: 4.9918 - val_mae: 1.6738 - val_accuracy: 0.0772
# Epoch 17/20
# 334/334 [==============================] - ETA: 0s - loss: 3.4102 - mae: 1.3698 - accuracy: 0.0913
# Epoch 00017: val_loss did not improve from 4.20289
# 334/334 [==============================] - 36s 108ms/step - loss: 3.4102 - mae: 1.3698 - accuracy: 0.0913 - val_loss: 4.7559 - val_mae: 1.6109 - val_accuracy: 0.0789
# Epoch 18/20
# 333/334 [============================>.] - ETA: 0s - loss: 3.2878 - mae: 1.3408 - accuracy: 0.0910
# Epoch 00018: val_loss improved from 4.20289 to 3.98029, saving model to checkpoints\age_range_model2_normalized.epoch18-loss3.98.hdf5
# 334/334 [==============================] - 35s 105ms/step - loss: 3.2882 - mae: 1.3411 - accuracy: 0.0910 - val_loss: 3.9803 - val_mae: 1.4059 - val_accuracy: 0.0865
# Epoch 19/20
# 333/334 [============================>.] - ETA: 0s - loss: 3.1896 - mae: 1.3259 - accuracy: 0.0930
# Epoch 00019: val_loss did not improve from 3.98029
# 334/334 [==============================] - 35s 106ms/step - loss: 3.1894 - mae: 1.3260 - accuracy: 0.0930 - val_loss: 4.1229 - val_mae: 1.4406 - val_accuracy: 0.0844
# Epoch 20/20
# 334/334 [==============================] - ETA: 0s - loss: 3.0729 - mae: 1.2983 - accuracy: 0.0930
# Epoch 00020: val_loss did not improve from 3.98029
# 334/334 [==============================] - 36s 106ms/step - loss: 3.0729 - mae: 1.2983 - accuracy: 0.0930 - val_loss: 4.1072 - val_mae: 1.4288 - val_accuracy: 0.0907

# %%
pd.DataFrame(model.history.history)[["loss", "val_loss"]].plot()
# Out:
# <AxesSubplot:>

# %%
y_pred = model.predict(X)

# %%
pd.Series((5 * y_pred.reshape((len(y_pred))))).plot(kind='hist', bins=40, label='Predicted', alpha=0.5)
(5 * y).plot(kind='hist', bins=40, label='Original', alpha=0.5)

plt.legend(title='Group')

plt.ylabel('Frequency', fontsize=14)
plt.xlabel('Age', fontsize=14)
plt.title('Predicted vs Original', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Predicted vs Original')

# %%
plt.figure(figsize=(16,16))
for i in range(1500,1520):
    plt.subplot(5,5,(i%25)+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(df['pixels'].iloc[i].reshape(48,48))
    pred_age = round((5 * (y_pred[i][0])))
    plt.xlabel(
        "Age:"+str(df['age'].iloc[i])+" Predicted: "+str(pred_age) + " to " + str(pred_age + 5))
plt.show()

# %% [markdown]
# ### Predictions for best model

# %%
import os
path = os.getcwd() + r'\checkpoints\age_range_model2_normalized.epoch18-loss3.98.hdf5'

# %%
best_model = tf.keras.models.load_model(path)

# %%
y_pred_best = best_model.predict(X)

# %%
pd.Series(y_pred.reshape((len(y_pred_best)))).plot(kind='hist', bins=40, label='Predicted', alpha=0.5)
y.plot(kind='hist', bins=40, label='Original', alpha=0.5)

plt.legend(title='Group')

plt.ylabel('Frequency', fontsize=14)
plt.xlabel('Age', fontsize=14)
plt.title('Predicted vs Original', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Predicted vs Original')

# %%
plt.figure(figsize=(16,16))
for i in range(1500,1520):
    plt.subplot(5,5,(i%25)+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(df['pixels'].iloc[i].reshape(48,48))
    pred_age = round((5 * (y_pred[i][0])))
    plt.xlabel(
        "Age:"+str(df['age'].iloc[i])+" Predicted: "+str(pred_age) + " to " + str(pred_age + 5))
plt.show()
