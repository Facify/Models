# %% [markdown]
# # CNN_UTK_Model for AgeRange 6 class classification - Canny Edges

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.utils import to_categorical
import cv2
plt.style.use('ggplot')

# %% [markdown]
# ### Data preprocessing

# %%
df = pd.read_csv('./dataset/UTK_dataset.csv')
df.head()
# Out:
#    age  ethnicity  gender                        img_name  \
# 0    1          2       0  20161219203650636.jpg.chip.jpg
# 1    1          2       0  20161219222752047.jpg.chip.jpg
# 2    1          2       0  20161219222832191.jpg.chip.jpg
# 3    1          2       0  20161220144911423.jpg.chip.jpg
# 4    1          2       0  20161220144914327.jpg.chip.jpg
#
#                                               pixels
# 0  129 128 128 126 127 130 133 135 139 142 145 14...
# 1  164 74 111 168 169 171 175 182 184 188 193 199...
# 2  67 70 71 70 69 67 70 79 90 103 116 132 145 155...
# 3  193 197 198 200 199 200 202 203 204 205 208 21...
# 4  202 205 209 210 209 209 210 211 212 214 218 21...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23705 entries, 0 to 23704
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        23705 non-null  int64
#  1   ethnicity  23705 non-null  int64
#  2   gender     23705 non-null  int64
#  3   img_name   23705 non-null  object
#  4   pixels     23705 non-null  object
# dtypes: int64(3), object(2)
# memory usage: 926.1+ KB

# %%
df.describe()
# Out:
#                 age     ethnicity        gender
# count  23705.000000  23705.000000  23705.000000
# mean      33.300907      1.269226      0.477283
# std       19.885708      1.345638      0.499494
# min        1.000000      0.000000      0.000000
# 25%       23.000000      0.000000      0.000000
# 50%       29.000000      1.000000      0.000000
# 75%       45.000000      2.000000      1.000000
# max      116.000000      4.000000      1.000000

# %%
df.isna().sum()
# Out:
# age          0
# ethnicity    0
# gender       0
# img_name     0
# pixels       0
# dtype: int64

# %%
df['pixels']=df['pixels'].apply(lambda x:  np.array(x.split(), dtype="float32"))

df.head()
# Out:
#    age  ethnicity  gender                        img_name  \
# 0    1          2       0  20161219203650636.jpg.chip.jpg
# 1    1          2       0  20161219222752047.jpg.chip.jpg
# 2    1          2       0  20161219222832191.jpg.chip.jpg
# 3    1          2       0  20161220144911423.jpg.chip.jpg
# 4    1          2       0  20161220144914327.jpg.chip.jpg
#
#                                               pixels
# 0  [129.0, 128.0, 128.0, 126.0, 127.0, 130.0, 133...
# 1  [164.0, 74.0, 111.0, 168.0, 169.0, 171.0, 175....
# 2  [67.0, 70.0, 71.0, 70.0, 69.0, 67.0, 70.0, 79....
# 3  [193.0, 197.0, 198.0, 200.0, 199.0, 200.0, 202...
# 4  [202.0, 205.0, 209.0, 210.0, 209.0, 209.0, 210...

# %%
len(df['age'].unique())
# Out:
# 104

# %% [markdown]
# ### Data analysis

# %%
sns.histplot(data=df, x='age')
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
plt.figure(figsize=(16,16))
for i in range(1500,1520):
    plt.subplot(5,5,(i%25)+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    img = df['pixels'].iloc[i].reshape(48,48).astype( np.uint8)
    plt.imshow(cv2.Canny(img, 50, 200))
    plt.xlabel(
        "Age:"+str(df['age'].iloc[i]))
plt.show()

# %%
df['pixels']=df['pixels'].apply(lambda x:  cv2.Canny(x.reshape(48,48).astype( np.uint8), 50, 200).reshape(2304))

# %%
X = np.array(df['pixels'].tolist())
# taking range of 5
y = df['age'] // 20

# %%
scaler = MinMaxScaler()
X = scaler.fit_transform(X)

# %%
X = X.reshape(X.shape[0],48,48,1)

# %%
X[:5].shape
# Out:
# (5, 48, 48, 1)

# %%
y.unique()
# Out:
# array([0, 5, 1, 2, 3, 4], dtype=int64)

# %%
y = to_categorical(y, num_classes=6)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %% [markdown]
# ### Model creation

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Conv2D, MaxPooling2D, Dense, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.utils import plot_model

# %%
model = Sequential()

model.add(InputLayer(input_shape=(48, 48, 1)))
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

model.add(Flatten())

model.add(Dense(32, activation='relu'))
model.add(Dense(6, activation='softmax'))

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy", "mae"])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 46, 46, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 23, 23, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 21, 21, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 32)          18464
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                16416
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 198
# =================================================================
# Total params: 53,894
# Trainable params: 53,894
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model, to_file='models/cnn_utk_model_2_age-range-classification_6classes_canny.png')

# %%
filepath = 'checkpoints/age_range_model2_classification_6classes_canny.epoch{epoch:02d}-loss{val_loss:.2f}.hdf5'
checkpoint = ModelCheckpoint(filepath, monitor="val_loss", save_best_only=True, mode="min", verbose=1)

# %%
model.fit(X_train, y_train, epochs=20, batch_size=64, validation_data=(X_test, y_test), callbacks=[checkpoint])
# Out:
# Epoch 1/20
# 333/334 [============================>.] - ETA: 0s - loss: 1.1324 - accuracy: 0.5552 - mae: 0.1953
# Epoch 00001: val_loss improved from inf to 1.03486, saving model to checkpoints\age_range_model2_classification_6classes_canny.epoch01-loss1.03.hdf5
# 334/334 [==============================] - 23s 69ms/step - loss: 1.1325 - accuracy: 0.5552 - mae: 0.1953 - val_loss: 1.0349 - val_accuracy: 0.5968 - val_mae: 0.1836
# Epoch 2/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.9965 - accuracy: 0.5994 - mae: 0.1743
# Epoch 00002: val_loss improved from 1.03486 to 0.97670, saving model to checkpoints\age_range_model2_classification_6classes_canny.epoch02-loss0.98.hdf5
# 334/334 [==============================] - 23s 68ms/step - loss: 0.9967 - accuracy: 0.5993 - mae: 0.1743 - val_loss: 0.9767 - val_accuracy: 0.6099 - val_mae: 0.1734
# Epoch 3/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.9307 - accuracy: 0.6242 - mae: 0.1646
# Epoch 00003: val_loss improved from 0.97670 to 0.93750, saving model to checkpoints\age_range_model2_classification_6classes_canny.epoch03-loss0.94.hdf5
# 334/334 [==============================] - 25s 74ms/step - loss: 0.9308 - accuracy: 0.6243 - mae: 0.1646 - val_loss: 0.9375 - val_accuracy: 0.6305 - val_mae: 0.1670
# Epoch 4/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.8784 - accuracy: 0.6447 - mae: 0.1565
# Epoch 00004: val_loss did not improve from 0.93750
# 334/334 [==============================] - 26s 77ms/step - loss: 0.8785 - accuracy: 0.6448 - mae: 0.1565 - val_loss: 0.9425 - val_accuracy: 0.6196 - val_mae: 0.1632
# Epoch 5/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.8376 - accuracy: 0.6629 - mae: 0.1501
# Epoch 00005: val_loss improved from 0.93750 to 0.89725, saving model to checkpoints\age_range_model2_classification_6classes_canny.epoch05-loss0.90.hdf5
# 334/334 [==============================] - 26s 78ms/step - loss: 0.8377 - accuracy: 0.6628 - mae: 0.1501 - val_loss: 0.8973 - val_accuracy: 0.6343 - val_mae: 0.1556
# Epoch 6/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.7916 - accuracy: 0.6805 - mae: 0.1434
# Epoch 00006: val_loss did not improve from 0.89725
# 334/334 [==============================] - 28s 83ms/step - loss: 0.7916 - accuracy: 0.6805 - mae: 0.1434 - val_loss: 0.9207 - val_accuracy: 0.6221 - val_mae: 0.1542
# Epoch 7/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.7424 - accuracy: 0.7016 - mae: 0.1355
# Epoch 00007: val_loss did not improve from 0.89725
# 334/334 [==============================] - 28s 84ms/step - loss: 0.7425 - accuracy: 0.7016 - mae: 0.1355 - val_loss: 0.9235 - val_accuracy: 0.6474 - val_mae: 0.1437
# Epoch 8/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.6973 - accuracy: 0.7196 - mae: 0.1282
# Epoch 00008: val_loss did not improve from 0.89725
# 334/334 [==============================] - 28s 85ms/step - loss: 0.6971 - accuracy: 0.7197 - mae: 0.1282 - val_loss: 0.9508 - val_accuracy: 0.6234 - val_mae: 0.1525
# Epoch 9/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.6521 - accuracy: 0.7399 - mae: 0.1211
# Epoch 00009: val_loss did not improve from 0.89725
# 334/334 [==============================] - 27s 81ms/step - loss: 0.6523 - accuracy: 0.7399 - mae: 0.1211 - val_loss: 0.9811 - val_accuracy: 0.6217 - val_mae: 0.1477
# Epoch 10/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.5991 - accuracy: 0.7641 - mae: 0.1122
# Epoch 00010: val_loss did not improve from 0.89725
# 334/334 [==============================] - 28s 84ms/step - loss: 0.5991 - accuracy: 0.7640 - mae: 0.1121 - val_loss: 1.0477 - val_accuracy: 0.6326 - val_mae: 0.1398
# Epoch 11/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.5495 - accuracy: 0.7813 - mae: 0.1041
# Epoch 00011: val_loss did not improve from 0.89725
# 334/334 [==============================] - 29s 87ms/step - loss: 0.5496 - accuracy: 0.7812 - mae: 0.1042 - val_loss: 1.1024 - val_accuracy: 0.6082 - val_mae: 0.1478
# Epoch 12/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.4996 - accuracy: 0.8052 - mae: 0.0956
# Epoch 00012: val_loss did not improve from 0.89725
# 334/334 [==============================] - 28s 83ms/step - loss: 0.4997 - accuracy: 0.8051 - mae: 0.0956 - val_loss: 1.1236 - val_accuracy: 0.6234 - val_mae: 0.1403
# Epoch 13/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.4551 - accuracy: 0.8216 - mae: 0.0880
# Epoch 00013: val_loss did not improve from 0.89725
# 334/334 [==============================] - 29s 88ms/step - loss: 0.4549 - accuracy: 0.8217 - mae: 0.0879 - val_loss: 1.2368 - val_accuracy: 0.6094 - val_mae: 0.1433
# Epoch 14/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.4065 - accuracy: 0.8412 - mae: 0.0797
# Epoch 00014: val_loss did not improve from 0.89725
# 334/334 [==============================] - 27s 80ms/step - loss: 0.4066 - accuracy: 0.8411 - mae: 0.0797 - val_loss: 1.3510 - val_accuracy: 0.5926 - val_mae: 0.1473
# Epoch 15/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.3677 - accuracy: 0.8553 - mae: 0.0726
# Epoch 00015: val_loss did not improve from 0.89725
# 334/334 [==============================] - 26s 79ms/step - loss: 0.3679 - accuracy: 0.8551 - mae: 0.0726 - val_loss: 1.4204 - val_accuracy: 0.6065 - val_mae: 0.1390
# Epoch 16/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.3330 - accuracy: 0.8708 - mae: 0.0661
# Epoch 00016: val_loss did not improve from 0.89725
# 334/334 [==============================] - 26s 79ms/step - loss: 0.3330 - accuracy: 0.8709 - mae: 0.0662 - val_loss: 1.4829 - val_accuracy: 0.5943 - val_mae: 0.1446
# Epoch 17/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.2974 - accuracy: 0.8851 - mae: 0.0600
# Epoch 00017: val_loss did not improve from 0.89725
# 334/334 [==============================] - 25s 75ms/step - loss: 0.2973 - accuracy: 0.8852 - mae: 0.0599 - val_loss: 1.6517 - val_accuracy: 0.5833 - val_mae: 0.1424
# Epoch 18/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.2650 - accuracy: 0.8994 - mae: 0.0536
# Epoch 00018: val_loss did not improve from 0.89725
# 334/334 [==============================] - 27s 80ms/step - loss: 0.2651 - accuracy: 0.8994 - mae: 0.0536 - val_loss: 1.7684 - val_accuracy: 0.6103 - val_mae: 0.1370
# Epoch 19/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.2346 - accuracy: 0.9107 - mae: 0.0483
# Epoch 00019: val_loss did not improve from 0.89725
# 334/334 [==============================] - 27s 80ms/step - loss: 0.2345 - accuracy: 0.9108 - mae: 0.0483 - val_loss: 2.0087 - val_accuracy: 0.6107 - val_mae: 0.1337
# Epoch 20/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.2025 - accuracy: 0.9244 - mae: 0.0423
# Epoch 00020: val_loss did not improve from 0.89725
# 334/334 [==============================] - 28s 85ms/step - loss: 0.2027 - accuracy: 0.9243 - mae: 0.0423 - val_loss: 2.1226 - val_accuracy: 0.5871 - val_mae: 0.1394

# %%
pd.DataFrame(model.history.history)[["loss", "val_loss"]].plot()
# Out:
# <AxesSubplot:>

# %%
from tensorflow.math import argmax

# %%
y_pred = argmax(model.predict(X), axis=1)

# %%
np.array(y_pred).sum() / len(y_pred)
# Out:
# 1.238430710820502

# %%
pd.Series((y_pred)).plot(kind='hist', bins=40, label='Predicted', alpha=0.5)
pd.Series(argmax(y, axis = 1)).plot(kind='hist', bins=40, label='Original', alpha=0.5)

plt.legend(title='Group')

plt.ylabel('Frequency', fontsize=14)
plt.xlabel('Age', fontsize=14)
plt.title('Predicted vs Original', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Predicted vs Original')

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
sns.heatmap(confusion_matrix(argmax(y, axis = 1), y_pred))
# Out:
# <AxesSubplot:>

# %%
print(classification_report(argmax(y, axis = 1), y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.95      4593
#            1       0.95      0.95      0.95     11880
#            2       0.80      0.89      0.84      4544
#            3       0.91      0.68      0.78      2015
#            4       0.81      0.88      0.85       641
#            5       1.00      0.09      0.17        32
#
#     accuracy                           0.91     23705
#    macro avg       0.91      0.74      0.76     23705
# weighted avg       0.92      0.91      0.91     23705

# %%
y_pred.numpy()
# Out:
# array([0, 0, 0, ..., 4, 4, 4], dtype=int64)

# %%
plt.figure(figsize=(16,16))
for i in range(1400,1420):
    plt.subplot(5,5,(i%25)+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(df['pixels'].iloc[i].reshape(48,48))
    pred_age = (20 * (y_pred.numpy()[i]))
    plt.xlabel(
        "Age:"+str(df['age'].iloc[i])+" Predicted: "+str(pred_age) + " to " + str(pred_age + 20))
plt.show()

# %% [markdown]
# ### Predictions for best model

# %%
import os
path = os.getcwd() + r'\checkpoints\age_range_model2_classification_6classes_canny.epoch05-loss0.90.hdf5'

# %%
best_model = tf.keras.models.load_model(path)

# %%
y_pred_best = argmax(best_model.predict(X), axis=1)

# %%
pd.Series((y_pred_best)).plot(kind='hist', bins=40, label='Predicted', alpha=0.5)
pd.Series(argmax(y, axis = 1)).plot(kind='hist', bins=40, label='Original', alpha=0.5)

plt.legend(title='Group')

plt.ylabel('Frequency', fontsize=14)
plt.xlabel('Age', fontsize=14)
plt.title('Predicted vs Original', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Predicted vs Original')

# %%
from sklearn.metrics import confusion_matrix, classification_report
sns.heatmap(confusion_matrix(argmax(y, axis = 1), y_pred_best))
# Out:
# <AxesSubplot:>

# %%
print(classification_report(argmax(y, axis = 1), y_pred_best))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.64      0.63      4593
#            1       0.65      0.79      0.72     11880
#            2       0.42      0.28      0.34      4544
#            3       0.33      0.23      0.27      2015
#            4       0.48      0.02      0.04       641
#            5       0.00      0.00      0.00        32
#
#     accuracy                           0.60     23705
#    macro avg       0.42      0.33      0.33     23705
# weighted avg       0.57      0.60      0.57     23705
# C:\Users\DELL\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\DELL\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\DELL\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
plt.figure(figsize=(16,16))
for i in range(1300,1320):
    plt.subplot(5,5,(i%25)+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(df['pixels'].iloc[i].reshape(48,48))
    pred_age = (20 * (y_pred_best.numpy()[i]))
    plt.xlabel(
        "Age:"+str(df['age'].iloc[i])+" Predicted: "+str(pred_age) + " to " + str(pred_age + 20))
plt.show()
