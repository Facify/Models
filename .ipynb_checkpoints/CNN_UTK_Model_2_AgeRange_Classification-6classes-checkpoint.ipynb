# %% [markdown]
# # CNN_UTK_Model for AgeRange classification

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.utils import to_categorical
plt.style.use('ggplot')

# %% [markdown]
# ### Data preprocessing

# %%
df = pd.read_csv('./dataset/UTK_dataset.csv')
df.head()
# Out:
#    age  ethnicity  gender                        img_name  \
# 0    1          2       0  20161219203650636.jpg.chip.jpg
# 1    1          2       0  20161219222752047.jpg.chip.jpg
# 2    1          2       0  20161219222832191.jpg.chip.jpg
# 3    1          2       0  20161220144911423.jpg.chip.jpg
# 4    1          2       0  20161220144914327.jpg.chip.jpg
#
#                                               pixels
# 0  129 128 128 126 127 130 133 135 139 142 145 14...
# 1  164 74 111 168 169 171 175 182 184 188 193 199...
# 2  67 70 71 70 69 67 70 79 90 103 116 132 145 155...
# 3  193 197 198 200 199 200 202 203 204 205 208 21...
# 4  202 205 209 210 209 209 210 211 212 214 218 21...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23705 entries, 0 to 23704
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        23705 non-null  int64
#  1   ethnicity  23705 non-null  int64
#  2   gender     23705 non-null  int64
#  3   img_name   23705 non-null  object
#  4   pixels     23705 non-null  object
# dtypes: int64(3), object(2)
# memory usage: 926.1+ KB

# %%
df.describe()
# Out:
#                 age     ethnicity        gender
# count  23705.000000  23705.000000  23705.000000
# mean      33.300907      1.269226      0.477283
# std       19.885708      1.345638      0.499494
# min        1.000000      0.000000      0.000000
# 25%       23.000000      0.000000      0.000000
# 50%       29.000000      1.000000      0.000000
# 75%       45.000000      2.000000      1.000000
# max      116.000000      4.000000      1.000000

# %%
df.isna().sum()
# Out:
# age          0
# ethnicity    0
# gender       0
# img_name     0
# pixels       0
# dtype: int64

# %%
df['pixels']=df['pixels'].apply(lambda x:  np.array(x.split(), dtype="float32"))

df.head()
# Out:
#    age  ethnicity  gender                        img_name  \
# 0    1          2       0  20161219203650636.jpg.chip.jpg
# 1    1          2       0  20161219222752047.jpg.chip.jpg
# 2    1          2       0  20161219222832191.jpg.chip.jpg
# 3    1          2       0  20161220144911423.jpg.chip.jpg
# 4    1          2       0  20161220144914327.jpg.chip.jpg
#
#                                               pixels
# 0  [129.0, 128.0, 128.0, 126.0, 127.0, 130.0, 133...
# 1  [164.0, 74.0, 111.0, 168.0, 169.0, 171.0, 175....
# 2  [67.0, 70.0, 71.0, 70.0, 69.0, 67.0, 70.0, 79....
# 3  [193.0, 197.0, 198.0, 200.0, 199.0, 200.0, 202...
# 4  [202.0, 205.0, 209.0, 210.0, 209.0, 209.0, 210...

# %%
len(df['age'].unique())
# Out:
# 104

# %% [markdown]
# ### Data analysis

# %%
sns.histplot(data=df, x='age')
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
plt.figure(figsize=(16,16))
for i in range(1500,1520):
    plt.subplot(5,5,(i%25)+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(df['pixels'].iloc[i].reshape(48,48))
    plt.xlabel(
        "Age:"+str(df['age'].iloc[i]))
plt.show()

# %%
X = np.array(df['pixels'].tolist())
# taking range of 5
y = df['age'] // 20

# %%
scaler = MinMaxScaler()
X = scaler.fit_transform(X)

# %%
X = X.reshape(X.shape[0],48,48,1)

# %%
X[:5].shape
# Out:
# (5, 48, 48, 1)

# %%
y.unique()
# Out:
# array([0, 5, 1, 2, 3, 4], dtype=int64)

# %%
y = to_categorical(y, num_classes=6)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %% [markdown]
# ### Model creation

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Conv2D, MaxPooling2D, Dense, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.utils import plot_model

# %%
model = Sequential()

model.add(InputLayer(input_shape=(48, 48, 1)))
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

model.add(Flatten())

model.add(Dense(32, activation='relu'))
model.add(Dense(6, activation='softmax'))

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy", "mae"])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 46, 46, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 23, 23, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 21, 21, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 32)          18464
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                16416
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 198
# =================================================================
# Total params: 53,894
# Trainable params: 53,894
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model, to_file='models/cnn_utk_model_2_age-range-classification_6classes.png')

# %%
filepath = 'checkpoints/age_range_model2_classification_6classes.epoch{epoch:02d}-loss{val_loss:.2f}.hdf5'
checkpoint = ModelCheckpoint(filepath, monitor="val_loss", save_best_only=True, mode="min", verbose=1)

# %%
model.fit(X_train, y_train, epochs=20, batch_size=64, validation_data=(X_test, y_test), callbacks=[checkpoint])
# Out:
# Epoch 1/20
# 333/334 [============================>.] - ETA: 0s - loss: 1.1627 - accuracy: 0.5571 - mae: 0.1977
# Epoch 00001: val_loss improved from inf to 0.93035, saving model to checkpoints\age_range_model2_classification_6classes.epoch01-loss0.93.hdf5
# 334/334 [==============================] - 26s 77ms/step - loss: 1.1622 - accuracy: 0.5573 - mae: 0.1977 - val_loss: 0.9303 - val_accuracy: 0.6482 - val_mae: 0.1528
# Epoch 2/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.8983 - accuracy: 0.6494 - mae: 0.1581
# Epoch 00002: val_loss improved from 0.93035 to 0.83833, saving model to checkpoints\age_range_model2_classification_6classes.epoch02-loss0.84.hdf5
# 334/334 [==============================] - 26s 76ms/step - loss: 0.8983 - accuracy: 0.6493 - mae: 0.1581 - val_loss: 0.8383 - val_accuracy: 0.6740 - val_mae: 0.1444
# Epoch 3/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.8190 - accuracy: 0.6795 - mae: 0.1460
# Epoch 00003: val_loss improved from 0.83833 to 0.78571, saving model to checkpoints\age_range_model2_classification_6classes.epoch03-loss0.79.hdf5
# 334/334 [==============================] - 25s 76ms/step - loss: 0.8191 - accuracy: 0.6795 - mae: 0.1459 - val_loss: 0.7857 - val_accuracy: 0.6875 - val_mae: 0.1429
# Epoch 4/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.7636 - accuracy: 0.6992 - mae: 0.1380
# Epoch 00004: val_loss improved from 0.78571 to 0.74325, saving model to checkpoints\age_range_model2_classification_6classes.epoch04-loss0.74.hdf5
# 334/334 [==============================] - 25s 75ms/step - loss: 0.7634 - accuracy: 0.6993 - mae: 0.1380 - val_loss: 0.7432 - val_accuracy: 0.7086 - val_mae: 0.1355
# Epoch 5/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.7232 - accuracy: 0.7106 - mae: 0.1323
# Epoch 00005: val_loss improved from 0.74325 to 0.72699, saving model to checkpoints\age_range_model2_classification_6classes.epoch05-loss0.73.hdf5
# 334/334 [==============================] - 29s 86ms/step - loss: 0.7231 - accuracy: 0.7106 - mae: 0.1323 - val_loss: 0.7270 - val_accuracy: 0.7140 - val_mae: 0.1284
# Epoch 6/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.6875 - accuracy: 0.7234 - mae: 0.1269
# Epoch 00006: val_loss improved from 0.72699 to 0.70547, saving model to checkpoints\age_range_model2_classification_6classes.epoch06-loss0.71.hdf5
# 334/334 [==============================] - 25s 76ms/step - loss: 0.6879 - accuracy: 0.7233 - mae: 0.1270 - val_loss: 0.7055 - val_accuracy: 0.7221 - val_mae: 0.1256
# Epoch 7/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.6653 - accuracy: 0.7316 - mae: 0.1230
# Epoch 00007: val_loss improved from 0.70547 to 0.69246, saving model to checkpoints\age_range_model2_classification_6classes.epoch07-loss0.69.hdf5
# 334/334 [==============================] - 25s 76ms/step - loss: 0.6653 - accuracy: 0.7315 - mae: 0.1230 - val_loss: 0.6925 - val_accuracy: 0.7191 - val_mae: 0.1310
# Epoch 8/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.6428 - accuracy: 0.7386 - mae: 0.1198
# Epoch 00008: val_loss improved from 0.69246 to 0.68957, saving model to checkpoints\age_range_model2_classification_6classes.epoch08-loss0.69.hdf5
# 334/334 [==============================] - 26s 77ms/step - loss: 0.6427 - accuracy: 0.7387 - mae: 0.1198 - val_loss: 0.6896 - val_accuracy: 0.7267 - val_mae: 0.1309
# Epoch 9/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.6258 - accuracy: 0.7485 - mae: 0.1170
# Epoch 00009: val_loss improved from 0.68957 to 0.68109, saving model to checkpoints\age_range_model2_classification_6classes.epoch09-loss0.68.hdf5
# 334/334 [==============================] - 26s 78ms/step - loss: 0.6257 - accuracy: 0.7486 - mae: 0.1170 - val_loss: 0.6811 - val_accuracy: 0.7288 - val_mae: 0.1217
# Epoch 10/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.6101 - accuracy: 0.7559 - mae: 0.1143
# Epoch 00010: val_loss improved from 0.68109 to 0.64580, saving model to checkpoints\age_range_model2_classification_6classes.epoch10-loss0.65.hdf5
# 334/334 [==============================] - 28s 84ms/step - loss: 0.6100 - accuracy: 0.7559 - mae: 0.1143 - val_loss: 0.6458 - val_accuracy: 0.7419 - val_mae: 0.1174
# Epoch 11/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.5951 - accuracy: 0.7596 - mae: 0.1121
# Epoch 00011: val_loss did not improve from 0.64580
# 334/334 [==============================] - 25s 75ms/step - loss: 0.5949 - accuracy: 0.7597 - mae: 0.1121 - val_loss: 0.6551 - val_accuracy: 0.7381 - val_mae: 0.1178
# Epoch 12/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.5808 - accuracy: 0.7666 - mae: 0.1095
# Epoch 00012: val_loss did not improve from 0.64580
# 334/334 [==============================] - 26s 78ms/step - loss: 0.5806 - accuracy: 0.7667 - mae: 0.1095 - val_loss: 0.6681 - val_accuracy: 0.7292 - val_mae: 0.1230
# Epoch 13/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.5673 - accuracy: 0.7721 - mae: 0.1073
# Epoch 00013: val_loss did not improve from 0.64580
# 334/334 [==============================] - 25s 75ms/step - loss: 0.5672 - accuracy: 0.7721 - mae: 0.1073 - val_loss: 0.6593 - val_accuracy: 0.7453 - val_mae: 0.1130
# Epoch 14/20
# 334/334 [==============================] - ETA: 0s - loss: 0.5493 - accuracy: 0.7744 - mae: 0.1047
# Epoch 00014: val_loss improved from 0.64580 to 0.64531, saving model to checkpoints\age_range_model2_classification_6classes.epoch14-loss0.65.hdf5
# 334/334 [==============================] - 27s 81ms/step - loss: 0.5493 - accuracy: 0.7744 - mae: 0.1047 - val_loss: 0.6453 - val_accuracy: 0.7537 - val_mae: 0.1105
# Epoch 15/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.5362 - accuracy: 0.7835 - mae: 0.1021
# Epoch 00015: val_loss improved from 0.64531 to 0.61880, saving model to checkpoints\age_range_model2_classification_6classes.epoch15-loss0.62.hdf5
# 334/334 [==============================] - 26s 78ms/step - loss: 0.5360 - accuracy: 0.7835 - mae: 0.1020 - val_loss: 0.6188 - val_accuracy: 0.7579 - val_mae: 0.1068
# Epoch 16/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.5359 - accuracy: 0.7835 - mae: 0.1018
# Epoch 00016: val_loss did not improve from 0.61880
# 334/334 [==============================] - 28s 82ms/step - loss: 0.5358 - accuracy: 0.7835 - mae: 0.1018 - val_loss: 0.6403 - val_accuracy: 0.7550 - val_mae: 0.1046
# Epoch 17/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.5194 - accuracy: 0.7901 - mae: 0.0990
# Epoch 00017: val_loss did not improve from 0.61880
# 334/334 [==============================] - 28s 82ms/step - loss: 0.5193 - accuracy: 0.7901 - mae: 0.0990 - val_loss: 0.6364 - val_accuracy: 0.7482 - val_mae: 0.1114
# Epoch 18/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.5054 - accuracy: 0.7949 - mae: 0.0968
# Epoch 00018: val_loss did not improve from 0.61880
# 334/334 [==============================] - 29s 87ms/step - loss: 0.5052 - accuracy: 0.7950 - mae: 0.0968 - val_loss: 0.6334 - val_accuracy: 0.7533 - val_mae: 0.1056
# Epoch 19/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.4942 - accuracy: 0.8015 - mae: 0.0951
# Epoch 00019: val_loss did not improve from 0.61880
# 334/334 [==============================] - 27s 82ms/step - loss: 0.4942 - accuracy: 0.8015 - mae: 0.0951 - val_loss: 0.6464 - val_accuracy: 0.7588 - val_mae: 0.1042
# Epoch 20/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.4888 - accuracy: 0.8036 - mae: 0.0940
# Epoch 00020: val_loss did not improve from 0.61880
# 334/334 [==============================] - 28s 83ms/step - loss: 0.4889 - accuracy: 0.8035 - mae: 0.0940 - val_loss: 0.6543 - val_accuracy: 0.7541 - val_mae: 0.1084

# %%
pd.DataFrame(model.history.history)[["loss", "val_loss"]].plot()
# Out:
# <AxesSubplot:>

# %%
from tensorflow.math import argmax

# %%
y_pred = argmax(model.predict(X), axis=1)

# %%
np.array(y_pred).sum() / len(y_pred)
# Out:
# 1.1729171060957604

# %%
pd.Series((y_pred)).plot(kind='hist', bins=40, label='Predicted', alpha=0.5)
pd.Series(argmax(y, axis = 1)).plot(kind='hist', bins=40, label='Original', alpha=0.5)

plt.legend(title='Group')

plt.ylabel('Frequency', fontsize=14)
plt.xlabel('Age', fontsize=14)
plt.title('Predicted vs Original', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Predicted vs Original')

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
sns.heatmap(confusion_matrix(argmax(y, axis = 1), y_pred))
# Out:
# <AxesSubplot:>

# %%
print(classification_report(argmax(y, axis = 1), y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.92      0.89      4593
#            1       0.86      0.89      0.87     11880
#            2       0.64      0.63      0.64      4544
#            3       0.69      0.47      0.56      2015
#            4       0.69      0.65      0.67       641
#            5       0.00      0.00      0.00        32
#
#     accuracy                           0.80     23705
#    macro avg       0.62      0.59      0.61     23705
# weighted avg       0.80      0.80      0.80     23705
# C:\Users\DELL\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\DELL\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\DELL\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
y_pred.numpy()
# Out:
# array([0, 0, 0, ..., 4, 4, 4], dtype=int64)

# %%
plt.figure(figsize=(16,16))
for i in range(1400,1420):
    plt.subplot(5,5,(i%25)+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(df['pixels'].iloc[i].reshape(48,48))
    pred_age = (20 * (y_pred.numpy()[i]))
    plt.xlabel(
        "Age:"+str(df['age'].iloc[i])+" Predicted: "+str(pred_age) + " to " + str(pred_age + 20))
plt.show()

# %% [markdown]
# ### Predictions for best model

# %%
import os
path = os.getcwd() + r'\checkpoints\age_range_model2_classification_6classes.epoch15-loss0.62.hdf5'

# %%
best_model = tf.keras.models.load_model(path)

# %%
y_pred_best = argmax(best_model.predict(X), axis=1)

# %%
pd.Series((y_pred_best)).plot(kind='hist', bins=40, label='Predicted', alpha=0.5)
pd.Series(argmax(y, axis = 1)).plot(kind='hist', bins=40, label='Original', alpha=0.5)

plt.legend(title='Group')

plt.ylabel('Frequency', fontsize=14)
plt.xlabel('Age', fontsize=14)
plt.title('Predicted vs Original', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Predicted vs Original')

# %%
from sklearn.metrics import confusion_matrix, classification_report
sns.heatmap(confusion_matrix(argmax(y, axis = 1), y_pred_best))
# Out:
# <AxesSubplot:>

# %%
print(classification_report(argmax(y, axis = 1), y_pred_best))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.83      0.89      4593
#            1       0.82      0.93      0.87     11880
#            2       0.67      0.50      0.57      4544
#            3       0.58      0.63      0.60      2015
#            4       0.69      0.54      0.61       641
#            5       0.00      0.00      0.00        32
#
#     accuracy                           0.79     23705
#    macro avg       0.62      0.57      0.59     23705
# weighted avg       0.79      0.79      0.79     23705
# C:\Users\DELL\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\DELL\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\DELL\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
plt.figure(figsize=(16,16))
for i in range(1300,1320):
    plt.subplot(5,5,(i%25)+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(df['pixels'].iloc[i].reshape(48,48))
    pred_age = (20 * (y_pred_best.numpy()[i]))
    plt.xlabel(
        "Age:"+str(df['age'].iloc[i])+" Predicted: "+str(pred_age) + " to " + str(pred_age + 20))
plt.show()
