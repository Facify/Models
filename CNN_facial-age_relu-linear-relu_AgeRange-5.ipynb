# %% [markdown]
# ## Importing and Processing Data

# %%
import pandas as pd
import numpy as np

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

from tensorflow import keras
from keras.models import Sequential
from keras.layers import InputLayer, Conv2D, MaxPooling2D,GlobalAveragePooling2D,Dropout, Flatten, Dense
from keras import regularizers
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

from PIL import Image
import os

# %%
path="../input/facial-age/face_age/"

# %%
# Visualization of images

def visualize_image(age, number_of_images):
    plt.figure(figsize=(10, 10))
    folder=path+age+'/'
    images=os.listdir(folder)[:number_of_images]
    for i in range(number_of_images):
        img=mpimg.imread(folder+images[i])
        plt.subplot(number_of_images//2, 2, i+1)
        plt.imshow(img)

visualize_image("023", 10)

# %%
X=[]
y=[]
width=200
height=200
for folder, _, imgs in os.walk(path):
    if folder!="face_age":
        for img in imgs:
            img_path=folder+'/'+img
            image=Image.open(img_path)
            image=image.convert('L') #gray-scale images
            image=image.resize((width, height))
            X.append(np.array(image))
            y.append(int(folder[-3:]))

X=np.array(X)
y=np.array(y);

# %%
X=X.astype("float32")
#normalization
X /= 255.0
y = y//5 #dividing in range of 5

# %%
X = X.reshape(X.shape[0], width, height, 1)
X.shape
# Out:
# (19556, 200, 200, 1)

# %%
# os.mkdir("../dataset/Data")

# %%
# np.save("../dataset/face_age_data/X.npy", X)
# np.save("../dataset/face_age_data/y.npy", y)
# X = np.load('../dataset/face_age_data/X.npy')
# y = np.load('../dataset/face_age_data/y.npy')

# %% [markdown]
# ## Train, Test and Validation Datasets

# %%
# Train, validation and testing split (70/15/15)

test_size = 0.3
seed = 42
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=seed, shuffle=True, stratify=y)
# X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size=0.5)

# %%
# save to files
# np.save('../dataset/face_age_data/X_train.npy', X_train)
# np.save('../dataset/face_age_data/y_train.npy', y_train)
# np.save('../dataset/face_age_data/X_val.npy', X_val)
# np.save('../dataset/face_age_data/y_val.npy', y_val)
# np.save('../dataset/face_age_data/X_test.npy', X_test)
# np.save('../dataset/face_age_data/y_test.npy', y_test)

# X_train = np.load('../dataset/face_age_data/X_train.npy')
# y_train = np.load('../dataset/face_age_data/y_train.npy')
# X_val = np.load('../dataset/face_age_data/X_val.npy')
# y_val = np.load('../dataset/face_age_data/y_val.npy')
# X_test = np.load('../dataset/face_age_data/X_test.npy')
# y_test = np.load('../dataset/face_age_data/y_test.npy')

# %%
# confirm the saved files
# os.listdir("../face_age_dataset/Data")

# %% [markdown]
# ## Image Augmentation

# %%
# Apply Image Augmentation

train_datagen = ImageDataGenerator(
    shear_range = 0.2, # random application of shearing
    zoom_range = 0.2, 
    horizontal_flip = True) # randomly flipping half of the images horizontally

test_datagen = ImageDataGenerator()

# %% [markdown]
# ## Callbacks and Default Hyperparameters

# %%
from keras.callbacks import Callback, ReduceLROnPlateau, EarlyStopping
from timeit import default_timer as timer

class TimingCallback(Callback):
    def __init__(self, logs={}):
        self.logs=[]
    def on_epoch_begin(self, epoch, logs={}):
        self.starttime = timer()
    def on_epoch_end(self, epoch, logs={}):
        self.logs.append(timer()-self.starttime)

early_stopping = EarlyStopping(
                                patience=5, # wait for 5 epochs
                                min_delta = 0.01, # if in 5 epochs the loss function doesn't increase (for accuracy) 
                                               # or decrease (for val_loss) by 1%, then stop
                                verbose=1, # print the training epoch on which training was stopped
                                mode = 'min',
                                monitor='val_loss')

reduce_learning_rate = ReduceLROnPlateau(
                                    monitor="val_loss",
                                    patience=3, # if val_loss plateaus for 3 epochs such that it doesn't see 
                                                # an improvement of size = epsilon
                                    episilon= 0.01,
                                    factor=0.1,  # then we reduce the learning rate by a factor of 0.1
                                    cooldown = 4, # and we wait for 4 epochs before we restart again
                                    verbose=1)

time_callback = TimingCallback()

        
# hyperparameters
lr = 0.01
epochs = 50
batch_size = 128
results = {}
input_shape =[width, height]

# %% [markdown]
# ## CNN Model

# %%
def baseline_model():
    model = Sequential()
    model.add(Conv2D(filters=32,kernel_size=(3,3),activation="relu",
                   padding="valid",
                   input_shape=(input_shape[0], input_shape[1], 1)))
    model.add(MaxPooling2D(pool_size=2, strides=2, padding='valid'))
    model.add(Conv2D(filters=32,kernel_size=(3,3),activation="linear",
                   padding="valid",
                   input_shape=(198, 198, 32)))
    model.add(Dropout(0.2))
    model.add(Flatten())
    model.add(Dense(1,activation="relu")) 
    return model

# %%
filepath = './cnn_face-age__relu-relu.epoch{epoch:02d}-loss{val_loss:.2f}.hdf5'
checkpoint = ModelCheckpoint(filepath, monitor="val_loss", save_best_only=True, mode="min", verbose=1)

# %%
# Adam= keras.optimizers.Adam(learning_rate=0.01,beta_1=0.9, beta_2=0.999, decay=0.0)

# %%
model = baseline_model()
model.compile(optimizer="adam", loss="mse", metrics=['mae'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 198, 198, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 99, 99, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 97, 97, 32)        9248
# _________________________________________________________________
# dropout (Dropout)            (None, 97, 97, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 301088)            0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 301089
# =================================================================
# Total params: 310,657
# Trainable params: 310,657
# Non-trainable params: 0
# _________________________________________________________________
# User settings:
#
#    KMP_AFFINITY=granularity=fine,verbose,compact,1,0
#    KMP_BLOCKTIME=0
#    KMP_DUPLICATE_LIB_OK=True
#    KMP_INIT_AT_FORK=FALSE
#    KMP_SETTINGS=1
#    KMP_WARNINGS=0
#
# Effective settings:
#
#    KMP_ABORT_DELAY=0
#    KMP_ADAPTIVE_LOCK_PROPS='1,1024'
#    KMP_ALIGN_ALLOC=64
#    KMP_ALL_THREADPRIVATE=128
#    KMP_ATOMIC_MODE=2
#    KMP_BLOCKTIME=0
#    KMP_CPUINFO_FILE: value is not defined
#    KMP_DETERMINISTIC_REDUCTION=false
#    KMP_DEVICE_THREAD_LIMIT=2147483647
#    KMP_DISP_NUM_BUFFERS=7
#    KMP_DUPLICATE_LIB_OK=true
#    KMP_ENABLE_TASK_THROTTLING=true
#    KMP_FORCE_REDUCTION: value is not defined
#    KMP_FOREIGN_THREADS_THREADPRIVATE=true
#    KMP_FORKJOIN_BARRIER='2,2'
#    KMP_FORKJOIN_BARRIER_PATTERN='hyper,hyper'
#    KMP_GTID_MODE=3
#    KMP_HANDLE_SIGNALS=false
#    KMP_HOT_TEAMS_MAX_LEVEL=1
#    KMP_HOT_TEAMS_MODE=0
#    KMP_INIT_AT_FORK=true
#    KMP_LIBRARY=throughput
#    KMP_LOCK_KIND=queuing
#    KMP_MALLOC_POOL_INCR=1M
#    KMP_NUM_LOCKS_IN_BLOCK=1
#    KMP_PLAIN_BARRIER='2,2'
#    KMP_PLAIN_BARRIER_PATTERN='hyper,hyper'
#    KMP_REDUCTION_BARRIER='1,1'
#    KMP_REDUCTION_BARRIER_PATTERN='hyper,hyper'
#    KMP_SCHEDULE='static,balanced;guided,iterative'
#    KMP_SETTINGS=true
#    KMP_SPIN_BACKOFF_PARAMS='4096,100'
#    KMP_STACKOFFSET=64
#    KMP_STACKPAD=0
#    KMP_STACKSIZE=8M
#    KMP_STORAGE_MAP=false
#    KMP_TASKING=2
#    KMP_TASKLOOP_MIN_TASKS=0
#    KMP_TASK_STEALING_CONSTRAINT=1
#    KMP_TEAMS_THREAD_LIMIT=4
#    KMP_TOPOLOGY_METHOD=all
#    KMP_USE_YIELD=1
#    KMP_VERSION=false
#    KMP_WARNINGS=false
#    OMP_AFFINITY_FORMAT='OMP: pid %P tid %i thread %n bound to OS proc set {%A}'
#    OMP_ALLOCATOR=omp_default_mem_alloc
#    OMP_CANCELLATION=false
#    OMP_DEFAULT_DEVICE=0
#    OMP_DISPLAY_AFFINITY=false
#    OMP_DISPLAY_ENV=false
#    OMP_DYNAMIC=false
#    OMP_MAX_ACTIVE_LEVELS=1
#    OMP_MAX_TASK_PRIORITY=0
#    OMP_NESTED: deprecated; max-active-levels-var=1
#    OMP_NUM_THREADS: value is not defined
#    OMP_PLACES: value is not defined
#    OMP_PROC_BIND='intel'
#    OMP_SCHEDULE='static'
#    OMP_STACKSIZE=8M
#    OMP_TARGET_OFFLOAD=DEFAULT
#    OMP_THREAD_LIMIT=2147483647
#    OMP_WAIT_POLICY=PASSIVE
#    KMP_AFFINITY='verbose,warnings,respect,granularity=fine,compact,1,0'
#
# 2021-11-29 15:01:44.818398: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='./cnn_facial_age-relu-relu.png')

# %%
model.fit(
    train_datagen.flow(
        X_train, y_train,
        batch_size = batch_size
    ), # use augmented images
    validation_data = (X_test, y_test),
    steps_per_epoch=X_train.shape[0] // batch_size,
    epochs = epochs,
    callbacks = [
                    reduce_learning_rate,
                    early_stopping,
                    time_callback,
                    checkpoint
                ],
    verbose=True)
# Out:
# 2021-11-29 15:01:46.993688: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/50
# 106/106 [==============================] - 201s 2s/step - loss: 30.8182 - mae: 4.3225 - val_loss: 17.8329 - val_mae: 3.1911
#
# Epoch 00001: val_loss improved from inf to 17.83293, saving model to ./cnn_face-age__relu-relu.epoch01-loss17.83.hdf5
# Epoch 2/50
# 106/106 [==============================] - 197s 2s/step - loss: 16.2670 - mae: 3.1610 - val_loss: 12.7538 - val_mae: 2.8737
#
# Epoch 00002: val_loss improved from 17.83293 to 12.75384, saving model to ./cnn_face-age__relu-relu.epoch02-loss12.75.hdf5
# Epoch 3/50
# 106/106 [==============================] - 198s 2s/step - loss: 13.9976 - mae: 2.8551 - val_loss: 10.8014 - val_mae: 2.4817
#
# Epoch 00003: val_loss improved from 12.75384 to 10.80140, saving model to ./cnn_face-age__relu-relu.epoch03-loss10.80.hdf5
# Epoch 4/50
# 106/106 [==============================] - 197s 2s/step - loss: 12.6838 - mae: 2.6876 - val_loss: 10.1275 - val_mae: 2.3409
#
# Epoch 00004: val_loss improved from 10.80140 to 10.12750, saving model to ./cnn_face-age__relu-relu.epoch04-loss10.13.hdf5
# Epoch 5/50
# 106/106 [==============================] - 196s 2s/step - loss: 11.9503 - mae: 2.6069 - val_loss: 9.6058 - val_mae: 2.2546
#
# Epoch 00005: val_loss improved from 10.12750 to 9.60581, saving model to ./cnn_face-age__relu-relu.epoch05-loss9.61.hdf5
# Epoch 6/50
# 106/106 [==============================] - 195s 2s/step - loss: 11.7759 - mae: 2.5659 - val_loss: 9.1026 - val_mae: 2.2381
#
# Epoch 00006: val_loss improved from 9.60581 to 9.10261, saving model to ./cnn_face-age__relu-relu.epoch06-loss9.10.hdf5
# Epoch 7/50
# 106/106 [==============================] - 196s 2s/step - loss: 10.7867 - mae: 2.4389 - val_loss: 8.3282 - val_mae: 2.1335
#
# Epoch 00007: val_loss improved from 9.10261 to 8.32825, saving model to ./cnn_face-age__relu-relu.epoch07-loss8.33.hdf5
# Epoch 8/50
# 106/106 [==============================] - 197s 2s/step - loss: 10.4229 - mae: 2.3960 - val_loss: 8.0569 - val_mae: 2.0369
#
# Epoch 00008: val_loss improved from 8.32825 to 8.05686, saving model to ./cnn_face-age__relu-relu.epoch08-loss8.06.hdf5
# Epoch 9/50
# 106/106 [==============================] - 197s 2s/step - loss: 9.6125 - mae: 2.2825 - val_loss: 8.2505 - val_mae: 2.1466
#
# Epoch 00009: val_loss did not improve from 8.05686
# Epoch 10/50
# 106/106 [==============================] - 196s 2s/step - loss: 9.3239 - mae: 2.2559 - val_loss: 8.7774 - val_mae: 2.2702
#
# Epoch 00010: val_loss did not improve from 8.05686
# Epoch 11/50
# 106/106 [==============================] - 196s 2s/step - loss: 9.0572 - mae: 2.2133 - val_loss: 7.1221 - val_mae: 1.9140
#
# Epoch 00011: val_loss improved from 8.05686 to 7.12206, saving model to ./cnn_face-age__relu-relu.epoch11-loss7.12.hdf5
# Epoch 12/50
# 106/106 [==============================] - 196s 2s/step - loss: 8.6489 - mae: 2.1462 - val_loss: 9.0369 - val_mae: 2.3313
#
# Epoch 00012: val_loss did not improve from 7.12206
# Epoch 13/50
# 106/106 [==============================] - 196s 2s/step - loss: 8.5734 - mae: 2.1454 - val_loss: 7.7165 - val_mae: 2.0614
#
# Epoch 00013: val_loss did not improve from 7.12206
# Epoch 14/50
# 106/106 [==============================] - 196s 2s/step - loss: 8.4657 - mae: 2.1164 - val_loss: 6.8700 - val_mae: 1.8881
#
# Epoch 00014: val_loss improved from 7.12206 to 6.87004, saving model to ./cnn_face-age__relu-relu.epoch14-loss6.87.hdf5
# Epoch 15/50
# 106/106 [==============================] - 198s 2s/step - loss: 7.7119 - mae: 2.0112 - val_loss: 6.6028 - val_mae: 1.8253
#
# Epoch 00015: val_loss improved from 6.87004 to 6.60284, saving model to ./cnn_face-age__relu-relu.epoch15-loss6.60.hdf5
# Epoch 16/50
# 106/106 [==============================] - 196s 2s/step - loss: 7.8854 - mae: 2.0346 - val_loss: 6.4656 - val_mae: 1.7987
#
# Epoch 00016: val_loss improved from 6.60284 to 6.46558, saving model to ./cnn_face-age__relu-relu.epoch16-loss6.47.hdf5
# Epoch 17/50
# 106/106 [==============================] - 196s 2s/step - loss: 7.6209 - mae: 2.0111 - val_loss: 6.3779 - val_mae: 1.8068
#
# Epoch 00017: val_loss improved from 6.46558 to 6.37788, saving model to ./cnn_face-age__relu-relu.epoch17-loss6.38.hdf5
# Epoch 18/50
# 106/106 [==============================] - 196s 2s/step - loss: 7.5200 - mae: 1.9792 - val_loss: 6.5924 - val_mae: 1.8754
#
# Epoch 00018: val_loss did not improve from 6.37788
# Epoch 19/50
# 106/106 [==============================] - 197s 2s/step - loss: 7.1743 - mae: 1.9317 - val_loss: 6.1991 - val_mae: 1.8115
#
# Epoch 00019: val_loss improved from 6.37788 to 6.19914, saving model to ./cnn_face-age__relu-relu.epoch19-loss6.20.hdf5
# Epoch 20/50
# 106/106 [==============================] - 196s 2s/step - loss: 7.1851 - mae: 1.9287 - val_loss: 5.9413 - val_mae: 1.7032
#
# Epoch 00020: val_loss improved from 6.19914 to 5.94128, saving model to ./cnn_face-age__relu-relu.epoch20-loss5.94.hdf5
# Epoch 21/50
# 106/106 [==============================] - 198s 2s/step - loss: 7.2344 - mae: 1.9428 - val_loss: 6.0195 - val_mae: 1.6811
#
# Epoch 00021: val_loss did not improve from 5.94128
# Epoch 22/50
# 106/106 [==============================] - 195s 2s/step - loss: 6.8814 - mae: 1.8867 - val_loss: 5.7683 - val_mae: 1.7063
#
# Epoch 00022: val_loss improved from 5.94128 to 5.76825, saving model to ./cnn_face-age__relu-relu.epoch22-loss5.77.hdf5
# Epoch 23/50
# 106/106 [==============================] - 196s 2s/step - loss: 7.0654 - mae: 1.9148 - val_loss: 6.0982 - val_mae: 1.7998
#
# Epoch 00023: val_loss did not improve from 5.76825
# Epoch 24/50
# 106/106 [==============================] - 195s 2s/step - loss: 6.9388 - mae: 1.8998 - val_loss: 6.0579 - val_mae: 1.7893
#
# Epoch 00024: val_loss did not improve from 5.76825
# Epoch 25/50
# 106/106 [==============================] - 196s 2s/step - loss: 6.6106 - mae: 1.8465 - val_loss: 5.6675 - val_mae: 1.6969
#
# Epoch 00025: val_loss improved from 5.76825 to 5.66752, saving model to ./cnn_face-age__relu-relu.epoch25-loss5.67.hdf5
# Epoch 26/50
# 106/106 [==============================] - 196s 2s/step - loss: 7.0059 - mae: 1.9021 - val_loss: 6.1470 - val_mae: 1.7586
#
# Epoch 00026: val_loss did not improve from 5.66752
# Epoch 27/50
# 106/106 [==============================] - 197s 2s/step - loss: 6.7483 - mae: 1.8684 - val_loss: 5.6291 - val_mae: 1.7038
#
# Epoch 00027: val_loss improved from 5.66752 to 5.62911, saving model to ./cnn_face-age__relu-relu.epoch27-loss5.63.hdf5
# Epoch 28/50
# 106/106 [==============================] - 196s 2s/step - loss: 6.5300 - mae: 1.8324 - val_loss: 5.4880 - val_mae: 1.6731
#
# Epoch 00028: val_loss improved from 5.62911 to 5.48800, saving model to ./cnn_face-age__relu-relu.epoch28-loss5.49.hdf5
# Epoch 29/50
# 106/106 [==============================] - 196s 2s/step - loss: 6.4257 - mae: 1.8198 - val_loss: 5.6054 - val_mae: 1.6422
#
# Epoch 00029: val_loss did not improve from 5.48800
# Epoch 30/50
# 106/106 [==============================] - 197s 2s/step - loss: 6.3897 - mae: 1.8090 - val_loss: 5.7306 - val_mae: 1.6877
#
# Epoch 00030: val_loss did not improve from 5.48800
# Epoch 31/50
# 106/106 [==============================] - 197s 2s/step - loss: 6.5462 - mae: 1.8457 - val_loss: 5.8119 - val_mae: 1.7048
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00031: val_loss did not improve from 5.48800
# Epoch 32/50
# 106/106 [==============================] - 196s 2s/step - loss: 5.9246 - mae: 1.7489 - val_loss: 5.1935 - val_mae: 1.6098
#
# Epoch 00032: val_loss improved from 5.48800 to 5.19355, saving model to ./cnn_face-age__relu-relu.epoch32-loss5.19.hdf5
# Epoch 33/50
# 106/106 [==============================] - 196s 2s/step - loss: 5.7555 - mae: 1.7164 - val_loss: 5.0340 - val_mae: 1.5861
#
# Epoch 00033: val_loss improved from 5.19355 to 5.03397, saving model to ./cnn_face-age__relu-relu.epoch33-loss5.03.hdf5
# Epoch 34/50
# 106/106 [==============================] - 195s 2s/step - loss: 5.6304 - mae: 1.6942 - val_loss: 4.9979 - val_mae: 1.5795
#
# Epoch 00034: val_loss improved from 5.03397 to 4.99792, saving model to ./cnn_face-age__relu-relu.epoch34-loss5.00.hdf5
# Epoch 35/50
# 106/106 [==============================] - 196s 2s/step - loss: 5.6524 - mae: 1.7004 - val_loss: 4.9296 - val_mae: 1.5647
#
# Epoch 00035: val_loss improved from 4.99792 to 4.92963, saving model to ./cnn_face-age__relu-relu.epoch35-loss4.93.hdf5
# Epoch 36/50
# 106/106 [==============================] - 197s 2s/step - loss: 5.5483 - mae: 1.6829 - val_loss: 4.8926 - val_mae: 1.5572
#
# Epoch 00036: val_loss improved from 4.92963 to 4.89262, saving model to ./cnn_face-age__relu-relu.epoch36-loss4.89.hdf5
# Epoch 37/50
# 106/106 [==============================] - 195s 2s/step - loss: 5.4883 - mae: 1.6704 - val_loss: 5.0225 - val_mae: 1.6070
#
# Epoch 00037: val_loss did not improve from 4.89262
# Epoch 38/50
# 106/106 [==============================] - 196s 2s/step - loss: 5.6917 - mae: 1.7013 - val_loss: 5.1232 - val_mae: 1.6333
#
# Epoch 00038: val_loss did not improve from 4.89262
# Epoch 39/50
# 106/106 [==============================] - 196s 2s/step - loss: 5.4654 - mae: 1.6751 - val_loss: 4.8335 - val_mae: 1.5598
#
# Epoch 00039: val_loss improved from 4.89262 to 4.83353, saving model to ./cnn_face-age__relu-relu.epoch39-loss4.83.hdf5
# Epoch 40/50
# 106/106 [==============================] - 198s 2s/step - loss: 5.5739 - mae: 1.6813 - val_loss: 4.8653 - val_mae: 1.5494
#
# Epoch 00040: val_loss did not improve from 4.83353
# Epoch 41/50
# 106/106 [==============================] - 195s 2s/step - loss: 5.5214 - mae: 1.6768 - val_loss: 4.9573 - val_mae: 1.5547
#
# Epoch 00041: val_loss did not improve from 4.83353
# Epoch 42/50
# 106/106 [==============================] - 196s 2s/step - loss: 5.4621 - mae: 1.6652 - val_loss: 5.1494 - val_mae: 1.6364
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00042: val_loss did not improve from 4.83353
# Epoch 43/50
# 106/106 [==============================] - 195s 2s/step - loss: 5.5207 - mae: 1.6792 - val_loss: 4.7855 - val_mae: 1.5565
#
# Epoch 00043: val_loss improved from 4.83353 to 4.78547, saving model to ./cnn_face-age__relu-relu.epoch43-loss4.79.hdf5
# Epoch 44/50
# 106/106 [==============================] - 195s 2s/step - loss: 5.3629 - mae: 1.6534 - val_loss: 4.7886 - val_mae: 1.5556
#
# Epoch 00044: val_loss did not improve from 4.78547
# Epoch 45/50
# 106/106 [==============================] - 196s 2s/step - loss: 5.3621 - mae: 1.6453 - val_loss: 4.7711 - val_mae: 1.5513
#
# Epoch 00045: val_loss improved from 4.78547 to 4.77110, saving model to ./cnn_face-age__relu-relu.epoch45-loss4.77.hdf5
# Epoch 46/50
# 106/106 [==============================] - 199s 2s/step - loss: 5.3463 - mae: 1.6518 - val_loss: 4.7593 - val_mae: 1.5414
#
# Epoch 00046: val_loss improved from 4.77110 to 4.75925, saving model to ./cnn_face-age__relu-relu.epoch46-loss4.76.hdf5
# Epoch 47/50
# 106/106 [==============================] - 196s 2s/step - loss: 5.3183 - mae: 1.6460 - val_loss: 4.8499 - val_mae: 1.5745
#
# Epoch 00047: val_loss did not improve from 4.75925
# Epoch 48/50
# 106/106 [==============================] - 199s 2s/step - loss: 5.2925 - mae: 1.6368 - val_loss: 4.7493 - val_mae: 1.5367
#
# Epoch 00048: val_loss improved from 4.75925 to 4.74933, saving model to ./cnn_face-age__relu-relu.epoch48-loss4.75.hdf5
# Epoch 49/50
# 106/106 [==============================] - 198s 2s/step - loss: 5.2173 - mae: 1.6332 - val_loss: 4.7795 - val_mae: 1.5558
#
# Epoch 00049: val_loss did not improve from 4.74933
# Epoch 50/50
# 106/106 [==============================] - 196s 2s/step - loss: 5.3245 - mae: 1.6408 - val_loss: 4.7412 - val_mae: 1.5395
#
# Epoch 00050: val_loss improved from 4.74933 to 4.74121, saving model to ./cnn_face-age__relu-relu.epoch50-loss4.74.hdf5

# %%
baseline_adam_train_loss = model.history.history["loss"]
baseline_adam_val_loss = model.history.history["val_loss"]
baseline_adam_train_acc = model.history.history["mae"]
baseline_adam_val_acc = model.history.history["val_mae"]

results["baseline_adam"] = {'train-loss': baseline_adam_train_loss,
                             'val-loss': baseline_adam_val_loss,
                             'train-mae': baseline_adam_train_acc,
                             'val-mae': baseline_adam_val_acc}

# %% [markdown]
# ## Performance Visualization

# %%
plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-mae'])),results[cond]['train-mae'], '-', label=cond+"_train", color="blue")
    plt.plot(range(len(results[cond]['val-mae'])),results[cond]['val-mae'], '-', label=cond+"_val", color="green")
plt.title("Mean Absolute Error")
plt.xlabel("Epochs")
plt.legend()
plt.show()

# %% [markdown]
# ## Results on Test Set

# %%
model_test_results = model.evaluate(X_test, y_test, batch_size=128)
dict(zip(model.metrics_names, model_test_results))
# Out:
# 46/46 [==============================] - 13s 274ms/step - loss: 4.7412 - mae: 1.5395
# {'loss': 4.7412109375, 'mae': 1.5394905805587769}

# %%
y_pred = model.predict(X).reshape(-1)

# %% [markdown]
# ## Performance in Age Range of 5

# %%
y_pred_range=np.round((y_pred), 0).astype(int)
float(100*sum(np.equal(y, y_pred_range).astype(int))/len(y_pred_range))
# Out:
# 31.049294334219677

# %%
pd.Series((5 * y_pred_range.reshape((len(y_pred))))).plot(kind='hist', bins=40, label='Predicted', alpha=0.5)
pd.Series((5 * y)).plot(kind='hist', bins=40, label='Original', alpha=0.5)

plt.legend(title='Group')

plt.ylabel('Frequency', fontsize=14)
plt.xlabel('Age', fontsize=14)
plt.title('Predicted vs Original', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Predicted vs Original')

# %%
import seaborn as sns
sns.heatmap(confusion_matrix(y, y_pred_range))
# Out:
# <AxesSubplot:>

# %%
print(classification_report(y, y_pred_range))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.80      0.79      4262
#            1       0.28      0.17      0.21      1630
#            2       0.16      0.17      0.16      1042
#            3       0.19      0.15      0.16      1394
#            4       0.21      0.22      0.22      1322
#            5       0.23      0.21      0.22      1712
#            6       0.13      0.19      0.16       960
#            7       0.18      0.21      0.19      1108
#            8       0.11      0.24      0.15       608
#            9       0.13      0.18      0.15       742
#           10       0.21      0.18      0.19      1078
#           11       0.15      0.14      0.14       798
#           12       0.15      0.14      0.14       678
#           13       0.20      0.16      0.18       634
#           14       0.11      0.10      0.11       384
#           15       0.15      0.09      0.11       374
#           16       0.11      0.09      0.10       256
#           17       0.36      0.10      0.16       378
#           18       0.16      0.10      0.12       144
#           19       0.04      0.05      0.04        42
#           20       0.00      0.00      0.00         6
#           21       0.00      0.00      0.00         0
#           22       0.00      0.00      0.00         4
#           23       0.00      0.00      0.00         0
#           24       0.00      0.00      0.00         0
#           25       0.00      0.00      0.00         0
#           26       0.00      0.00      0.00         0
#
#     accuracy                           0.31     19556
#    macro avg       0.15      0.14      0.14     19556
# weighted avg       0.32      0.31      0.31     19556
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
