# %% [markdown]
# # CNN_UTK_Model for AgeRange 6 class classification - Canny Edges - Dropout

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.utils import to_categorical
import cv2
plt.style.use('ggplot')

# %% [markdown]
# ### Data preprocessing

# %%
df = pd.read_csv('./dataset/UTK_dataset.csv')
df.head()
# Out:
#    age  ethnicity  gender                        img_name  \
# 0    1          2       0  20161219203650636.jpg.chip.jpg
# 1    1          2       0  20161219222752047.jpg.chip.jpg
# 2    1          2       0  20161219222832191.jpg.chip.jpg
# 3    1          2       0  20161220144911423.jpg.chip.jpg
# 4    1          2       0  20161220144914327.jpg.chip.jpg
#
#                                               pixels
# 0  129 128 128 126 127 130 133 135 139 142 145 14...
# 1  164 74 111 168 169 171 175 182 184 188 193 199...
# 2  67 70 71 70 69 67 70 79 90 103 116 132 145 155...
# 3  193 197 198 200 199 200 202 203 204 205 208 21...
# 4  202 205 209 210 209 209 210 211 212 214 218 21...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23705 entries, 0 to 23704
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        23705 non-null  int64
#  1   ethnicity  23705 non-null  int64
#  2   gender     23705 non-null  int64
#  3   img_name   23705 non-null  object
#  4   pixels     23705 non-null  object
# dtypes: int64(3), object(2)
# memory usage: 926.1+ KB

# %%
df.describe()
# Out:
#                 age     ethnicity        gender
# count  23705.000000  23705.000000  23705.000000
# mean      33.300907      1.269226      0.477283
# std       19.885708      1.345638      0.499494
# min        1.000000      0.000000      0.000000
# 25%       23.000000      0.000000      0.000000
# 50%       29.000000      1.000000      0.000000
# 75%       45.000000      2.000000      1.000000
# max      116.000000      4.000000      1.000000

# %%
df.isna().sum()
# Out:
# age          0
# ethnicity    0
# gender       0
# img_name     0
# pixels       0
# dtype: int64

# %%
df['pixels']=df['pixels'].apply(lambda x:  np.array(x.split(), dtype="float32"))

df.head()
# Out:
#    age  ethnicity  gender                        img_name  \
# 0    1          2       0  20161219203650636.jpg.chip.jpg
# 1    1          2       0  20161219222752047.jpg.chip.jpg
# 2    1          2       0  20161219222832191.jpg.chip.jpg
# 3    1          2       0  20161220144911423.jpg.chip.jpg
# 4    1          2       0  20161220144914327.jpg.chip.jpg
#
#                                               pixels
# 0  [129.0, 128.0, 128.0, 126.0, 127.0, 130.0, 133...
# 1  [164.0, 74.0, 111.0, 168.0, 169.0, 171.0, 175....
# 2  [67.0, 70.0, 71.0, 70.0, 69.0, 67.0, 70.0, 79....
# 3  [193.0, 197.0, 198.0, 200.0, 199.0, 200.0, 202...
# 4  [202.0, 205.0, 209.0, 210.0, 209.0, 209.0, 210...

# %%
len(df['age'].unique())
# Out:
# 104

# %% [markdown]
# ### Data analysis

# %%
sns.histplot(data=df, x='age')
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
plt.figure(figsize=(16,16))
for i in range(1500,1520):
    plt.subplot(5,5,(i%25)+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    img = df['pixels'].iloc[i].reshape(48,48).astype( np.uint8)
    plt.imshow(cv2.Canny(img, 50, 200))
    plt.xlabel(
        "Age:"+str(df['age'].iloc[i]))
plt.show()

# %%
df['pixels']=df['pixels'].apply(lambda x:  cv2.Canny(x.reshape(48,48).astype( np.uint8), 50, 200).reshape(2304))

# %%
X = np.array(df['pixels'].tolist())
# taking range of 5
y = df['age'] // 20

# %%
scaler = MinMaxScaler()
X = scaler.fit_transform(X)

# %%
X = X.reshape(X.shape[0],48,48,1)

# %%
X[:5].shape
# Out:
# (5, 48, 48, 1)

# %%
y.unique()
# Out:
# array([0, 5, 1, 2, 3, 4], dtype=int64)

# %%
y = to_categorical(y, num_classes=6)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %% [markdown]
# ### Model creation

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.utils import plot_model

# %%
model = Sequential()

model.add(InputLayer(input_shape=(48, 48, 1)))
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(Dropout(0.2))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(Dropout(0.5))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(Dropout(0.2))
model.add(MaxPooling2D((2, 2)))

model.add(Flatten())

model.add(Dense(32, activation='relu'))
model.add(Dense(6, activation='softmax'))

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy", "mae"])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 46, 46, 32)        320
# _________________________________________________________________
# dropout (Dropout)            (None, 46, 46, 32)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 23, 23, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 21, 21, 64)        18496
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 21, 21, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 32)          18464
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8, 8, 32)          0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                16416
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 198
# =================================================================
# Total params: 53,894
# Trainable params: 53,894
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model, to_file='models/cnn_utk_model_2_age-range-classification_6classes_canny-dropout.png')

# %%
filepath = 'checkpoints/age_range_model2_classification_6classes_canny-dropout.epoch{epoch:02d}-loss{val_loss:.2f}.hdf5'
checkpoint = ModelCheckpoint(filepath, monitor="val_loss", save_best_only=True, mode="min", verbose=1)

# %%
model.fit(X_train, y_train, epochs=20, batch_size=64, validation_data=(X_test, y_test), callbacks=[checkpoint])
# Out:
# Epoch 1/20
# 334/334 [==============================] - ETA: 0s - loss: 1.1164 - accuracy: 0.5648 - mae: 0.1921
# Epoch 00001: val_loss improved from inf to 1.12300, saving model to checkpoints\age_range_model2_classification_6classes_canny-dropout.epoch01-loss1.12.hdf5
# 334/334 [==============================] - 95s 285ms/step - loss: 1.1164 - accuracy: 0.5648 - mae: 0.1921 - val_loss: 1.1230 - val_accuracy: 0.6145 - val_mae: 0.2128
# Epoch 2/20
# 334/334 [==============================] - ETA: 0s - loss: 0.9614 - accuracy: 0.6206 - mae: 0.1680
# Epoch 00002: val_loss improved from 1.12300 to 1.01684, saving model to checkpoints\age_range_model2_classification_6classes_canny-dropout.epoch02-loss1.02.hdf5
# 334/334 [==============================] - 93s 278ms/step - loss: 0.9614 - accuracy: 0.6206 - mae: 0.1680 - val_loss: 1.0168 - val_accuracy: 0.6090 - val_mae: 0.1934
# Epoch 3/20
# 334/334 [==============================] - ETA: 0s - loss: 0.9017 - accuracy: 0.6410 - mae: 0.1590
# Epoch 00003: val_loss improved from 1.01684 to 1.00242, saving model to checkpoints\age_range_model2_classification_6classes_canny-dropout.epoch03-loss1.00.hdf5
# 334/334 [==============================] - 95s 285ms/step - loss: 0.9017 - accuracy: 0.6410 - mae: 0.1590 - val_loss: 1.0024 - val_accuracy: 0.6525 - val_mae: 0.1970
# Epoch 4/20
# 334/334 [==============================] - ETA: 0s - loss: 0.8629 - accuracy: 0.6499 - mae: 0.1534
# Epoch 00004: val_loss improved from 1.00242 to 0.99257, saving model to checkpoints\age_range_model2_classification_6classes_canny-dropout.epoch04-loss0.99.hdf5
# 334/334 [==============================] - 91s 273ms/step - loss: 0.8629 - accuracy: 0.6499 - mae: 0.1534 - val_loss: 0.9926 - val_accuracy: 0.6677 - val_mae: 0.1961
# Epoch 5/20
# 334/334 [==============================] - ETA: 0s - loss: 0.8429 - accuracy: 0.6603 - mae: 0.1506
# Epoch 00005: val_loss improved from 0.99257 to 0.98539, saving model to checkpoints\age_range_model2_classification_6classes_canny-dropout.epoch05-loss0.99.hdf5
# 334/334 [==============================] - 92s 277ms/step - loss: 0.8429 - accuracy: 0.6603 - mae: 0.1506 - val_loss: 0.9854 - val_accuracy: 0.6584 - val_mae: 0.1956
# Epoch 6/20
# 334/334 [==============================] - ETA: 0s - loss: 0.8213 - accuracy: 0.6682 - mae: 0.1473
# Epoch 00006: val_loss improved from 0.98539 to 0.92943, saving model to checkpoints\age_range_model2_classification_6classes_canny-dropout.epoch06-loss0.93.hdf5
# 334/334 [==============================] - 91s 273ms/step - loss: 0.8213 - accuracy: 0.6682 - mae: 0.1473 - val_loss: 0.9294 - val_accuracy: 0.6693 - val_mae: 0.1858
# Epoch 7/20
# 334/334 [==============================] - ETA: 0s - loss: 0.8040 - accuracy: 0.6720 - mae: 0.1453
# Epoch 00007: val_loss improved from 0.92943 to 0.89954, saving model to checkpoints\age_range_model2_classification_6classes_canny-dropout.epoch07-loss0.90.hdf5
# 334/334 [==============================] - 93s 279ms/step - loss: 0.8040 - accuracy: 0.6720 - mae: 0.1453 - val_loss: 0.8995 - val_accuracy: 0.6774 - val_mae: 0.1793
# Epoch 8/20
# 334/334 [==============================] - ETA: 0s - loss: 0.7920 - accuracy: 0.6775 - mae: 0.1430
# Epoch 00008: val_loss did not improve from 0.89954
# 334/334 [==============================] - 56s 168ms/step - loss: 0.7920 - accuracy: 0.6775 - mae: 0.1430 - val_loss: 0.9033 - val_accuracy: 0.6592 - val_mae: 0.1810
# Epoch 9/20
# 334/334 [==============================] - ETA: 0s - loss: 0.7800 - accuracy: 0.6839 - mae: 0.1411
# Epoch 00009: val_loss did not improve from 0.89954
# 334/334 [==============================] - 76s 228ms/step - loss: 0.7800 - accuracy: 0.6839 - mae: 0.1411 - val_loss: 0.9208 - val_accuracy: 0.6765 - val_mae: 0.1847
# Epoch 10/20
# 334/334 [==============================] - ETA: 0s - loss: 0.7692 - accuracy: 0.6875 - mae: 0.1396
# Epoch 00010: val_loss did not improve from 0.89954
# 334/334 [==============================] - 86s 258ms/step - loss: 0.7692 - accuracy: 0.6875 - mae: 0.1396 - val_loss: 0.9116 - val_accuracy: 0.6706 - val_mae: 0.1822
# Epoch 11/20
# 334/334 [==============================] - ETA: 0s - loss: 0.7625 - accuracy: 0.6890 - mae: 0.1381
# Epoch 00011: val_loss improved from 0.89954 to 0.89486, saving model to checkpoints\age_range_model2_classification_6classes_canny-dropout.epoch11-loss0.89.hdf5
# 334/334 [==============================] - 85s 256ms/step - loss: 0.7625 - accuracy: 0.6890 - mae: 0.1381 - val_loss: 0.8949 - val_accuracy: 0.6828 - val_mae: 0.1788
# Epoch 12/20
# 334/334 [==============================] - ETA: 0s - loss: 0.7527 - accuracy: 0.6928 - mae: 0.1368
# Epoch 00012: val_loss did not improve from 0.89486
# 334/334 [==============================] - 86s 257ms/step - loss: 0.7527 - accuracy: 0.6928 - mae: 0.1368 - val_loss: 0.9308 - val_accuracy: 0.6580 - val_mae: 0.1840
# Epoch 13/20
# 334/334 [==============================] - ETA: 0s - loss: 0.7414 - accuracy: 0.6946 - mae: 0.1348
# Epoch 00013: val_loss improved from 0.89486 to 0.87667, saving model to checkpoints\age_range_model2_classification_6classes_canny-dropout.epoch13-loss0.88.hdf5
# 334/334 [==============================] - 80s 241ms/step - loss: 0.7414 - accuracy: 0.6946 - mae: 0.1348 - val_loss: 0.8767 - val_accuracy: 0.6803 - val_mae: 0.1754
# Epoch 14/20
# 334/334 [==============================] - ETA: 0s - loss: 0.7323 - accuracy: 0.7015 - mae: 0.1339
# Epoch 00014: val_loss improved from 0.87667 to 0.84859, saving model to checkpoints\age_range_model2_classification_6classes_canny-dropout.epoch14-loss0.85.hdf5
# 334/334 [==============================] - 83s 248ms/step - loss: 0.7323 - accuracy: 0.7015 - mae: 0.1339 - val_loss: 0.8486 - val_accuracy: 0.6744 - val_mae: 0.1700
# Epoch 15/20
# 334/334 [==============================] - ETA: 0s - loss: 0.7307 - accuracy: 0.7032 - mae: 0.1329
# Epoch 00015: val_loss did not improve from 0.84859
# 334/334 [==============================] - 82s 247ms/step - loss: 0.7307 - accuracy: 0.7032 - mae: 0.1329 - val_loss: 0.8490 - val_accuracy: 0.6858 - val_mae: 0.1706
# Epoch 16/20
# 334/334 [==============================] - ETA: 0s - loss: 0.7244 - accuracy: 0.7047 - mae: 0.1320
# Epoch 00016: val_loss did not improve from 0.84859
# 334/334 [==============================] - 82s 246ms/step - loss: 0.7244 - accuracy: 0.7047 - mae: 0.1320 - val_loss: 0.8819 - val_accuracy: 0.6681 - val_mae: 0.1747
# Epoch 17/20
# 334/334 [==============================] - ETA: 0s - loss: 0.7191 - accuracy: 0.7072 - mae: 0.1315
# Epoch 00017: val_loss did not improve from 0.84859
# 334/334 [==============================] - 82s 246ms/step - loss: 0.7191 - accuracy: 0.7072 - mae: 0.1315 - val_loss: 0.8586 - val_accuracy: 0.6790 - val_mae: 0.1716
# Epoch 18/20
# 334/334 [==============================] - ETA: 0s - loss: 0.7082 - accuracy: 0.7095 - mae: 0.1299
# Epoch 00018: val_loss improved from 0.84859 to 0.83842, saving model to checkpoints\age_range_model2_classification_6classes_canny-dropout.epoch18-loss0.84.hdf5
# 334/334 [==============================] - 82s 244ms/step - loss: 0.7082 - accuracy: 0.7095 - mae: 0.1299 - val_loss: 0.8384 - val_accuracy: 0.6811 - val_mae: 0.1680
# Epoch 19/20
# 334/334 [==============================] - ETA: 0s - loss: 0.7068 - accuracy: 0.7120 - mae: 0.1297
# Epoch 00019: val_loss improved from 0.83842 to 0.82745, saving model to checkpoints\age_range_model2_classification_6classes_canny-dropout.epoch19-loss0.83.hdf5
# 334/334 [==============================] - 82s 245ms/step - loss: 0.7068 - accuracy: 0.7120 - mae: 0.1297 - val_loss: 0.8275 - val_accuracy: 0.6858 - val_mae: 0.1636
# Epoch 20/20
# 334/334 [==============================] - ETA: 0s - loss: 0.6956 - accuracy: 0.7187 - mae: 0.1274
# Epoch 00020: val_loss did not improve from 0.82745
# 334/334 [==============================] - 81s 244ms/step - loss: 0.6956 - accuracy: 0.7187 - mae: 0.1274 - val_loss: 0.8468 - val_accuracy: 0.6849 - val_mae: 0.1695

# %%
pd.DataFrame(model.history.history)[["loss", "val_loss"]].plot()
# Out:
# <AxesSubplot:>

# %%
from tensorflow.math import argmax

# %%
y_pred = argmax(model.predict(X), axis=1)

# %%
np.array(y_pred).sum() / len(y_pred)
# Out:
# 1.219616114743725

# %%
pd.Series((y_pred)).plot(kind='hist', bins=40, label='Predicted', alpha=0.5)
pd.Series(argmax(y, axis = 1)).plot(kind='hist', bins=40, label='Original', alpha=0.5)

plt.legend(title='Group')

plt.ylabel('Frequency', fontsize=14)
plt.xlabel('Age', fontsize=14)
plt.title('Predicted vs Original', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Predicted vs Original')

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
sns.heatmap(confusion_matrix(argmax(y, axis = 1), y_pred))
# Out:
# <AxesSubplot:>

# %%
print(classification_report(argmax(y, axis = 1), y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.81      0.85      4593
#            1       0.81      0.89      0.85     11880
#            2       0.60      0.55      0.58      4544
#            3       0.64      0.42      0.51      2015
#            4       0.56      0.73      0.63       641
#            5       1.00      0.03      0.06        32
#
#     accuracy                           0.77     23705
#    macro avg       0.75      0.57      0.58     23705
# weighted avg       0.76      0.77      0.76     23705

# %%
y_pred.numpy()
# Out:
# array([0, 0, 0, ..., 4, 4, 4], dtype=int64)

# %%
plt.figure(figsize=(16,16))
for i in range(1400,1420):
    plt.subplot(5,5,(i%25)+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(df['pixels'].iloc[i].reshape(48,48))
    pred_age = (20 * (y_pred.numpy()[i]))
    plt.xlabel(
        "Age:"+str(df['age'].iloc[i])+" Predicted: "+str(pred_age) + " to " + str(pred_age + 20))
plt.show()

# %% [markdown]
# ### Predictions for best model

# %%
import os
path = os.getcwd() + r'\checkpoints\age_range_model2_classification_6classes_canny-dropout.epoch19-loss0.83.hdf5'

# %%
best_model = tf.keras.models.load_model(path)

# %%
y_pred_best = argmax(best_model.predict(X), axis=1)

# %%
pd.Series((y_pred_best)).plot(kind='hist', bins=40, label='Predicted', alpha=0.5)
pd.Series(argmax(y, axis = 1)).plot(kind='hist', bins=40, label='Original', alpha=0.5)

plt.legend(title='Group')

plt.ylabel('Frequency', fontsize=14)
plt.xlabel('Age', fontsize=14)
plt.title('Predicted vs Original', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Predicted vs Original')

# %%
from sklearn.metrics import confusion_matrix, classification_report
sns.heatmap(confusion_matrix(argmax(y, axis = 1), y_pred_best))
# Out:
# <AxesSubplot:>

# %%
print(classification_report(argmax(y, axis = 1), y_pred_best))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.81      0.84      4593
#            1       0.78      0.92      0.84     11880
#            2       0.61      0.48      0.54      4544
#            3       0.62      0.44      0.52      2015
#            4       0.66      0.59      0.62       641
#            5       1.00      0.03      0.06        32
#
#     accuracy                           0.76     23705
#    macro avg       0.76      0.54      0.57     23705
# weighted avg       0.75      0.76      0.75     23705

# %%
plt.figure(figsize=(16,16))
for i in range(1300,1320):
    plt.subplot(5,5,(i%25)+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(df['pixels'].iloc[i].reshape(48,48))
    pred_age = (20 * (y_pred_best.numpy()[i]))
    plt.xlabel(
        "Age:"+str(df['age'].iloc[i])+" Predicted: "+str(pred_age) + " to " + str(pred_age + 20))
plt.show()
