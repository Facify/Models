# %% [markdown]
# # CNN_UTK_Model for AgeRange classification

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.utils import to_categorical
plt.style.use('ggplot')

# %% [markdown]
# ### Data preprocessing

# %%
df = pd.read_csv('./dataset/UTK_dataset.csv')
df.head()
# Out:
#    age  ethnicity  gender                        img_name  \
# 0    1          2       0  20161219203650636.jpg.chip.jpg
# 1    1          2       0  20161219222752047.jpg.chip.jpg
# 2    1          2       0  20161219222832191.jpg.chip.jpg
# 3    1          2       0  20161220144911423.jpg.chip.jpg
# 4    1          2       0  20161220144914327.jpg.chip.jpg
#
#                                               pixels
# 0  129 128 128 126 127 130 133 135 139 142 145 14...
# 1  164 74 111 168 169 171 175 182 184 188 193 199...
# 2  67 70 71 70 69 67 70 79 90 103 116 132 145 155...
# 3  193 197 198 200 199 200 202 203 204 205 208 21...
# 4  202 205 209 210 209 209 210 211 212 214 218 21...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23705 entries, 0 to 23704
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        23705 non-null  int64
#  1   ethnicity  23705 non-null  int64
#  2   gender     23705 non-null  int64
#  3   img_name   23705 non-null  object
#  4   pixels     23705 non-null  object
# dtypes: int64(3), object(2)
# memory usage: 926.1+ KB

# %%
df.describe()
# Out:
#                 age     ethnicity        gender
# count  23705.000000  23705.000000  23705.000000
# mean      33.300907      1.269226      0.477283
# std       19.885708      1.345638      0.499494
# min        1.000000      0.000000      0.000000
# 25%       23.000000      0.000000      0.000000
# 50%       29.000000      1.000000      0.000000
# 75%       45.000000      2.000000      1.000000
# max      116.000000      4.000000      1.000000

# %%
df.isna().sum()
# Out:
# age          0
# ethnicity    0
# gender       0
# img_name     0
# pixels       0
# dtype: int64

# %%
df['pixels']=df['pixels'].apply(lambda x:  np.array(x.split(), dtype="float32"))

df.head()
# Out:
#    age  ethnicity  gender                        img_name  \
# 0    1          2       0  20161219203650636.jpg.chip.jpg
# 1    1          2       0  20161219222752047.jpg.chip.jpg
# 2    1          2       0  20161219222832191.jpg.chip.jpg
# 3    1          2       0  20161220144911423.jpg.chip.jpg
# 4    1          2       0  20161220144914327.jpg.chip.jpg
#
#                                               pixels
# 0  [129.0, 128.0, 128.0, 126.0, 127.0, 130.0, 133...
# 1  [164.0, 74.0, 111.0, 168.0, 169.0, 171.0, 175....
# 2  [67.0, 70.0, 71.0, 70.0, 69.0, 67.0, 70.0, 79....
# 3  [193.0, 197.0, 198.0, 200.0, 199.0, 200.0, 202...
# 4  [202.0, 205.0, 209.0, 210.0, 209.0, 209.0, 210...

# %%
len(df['age'].unique())
# Out:
# 104

# %% [markdown]
# ### Data analysis

# %%
sns.histplot(data=df, x='age')
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
plt.figure(figsize=(16,16))
for i in range(1500,1520):
    plt.subplot(5,5,(i%25)+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(df['pixels'].iloc[i].reshape(48,48))
    plt.xlabel(
        "Age:"+str(df['age'].iloc[i]))
plt.show()

# %%
X = np.array(df['pixels'].tolist())
# taking range of 5
y = df['age'] // 5

# %%
scaler = MinMaxScaler()
X = scaler.fit_transform(X)

# %%
X = X.reshape(X.shape[0],48,48,1)

# %%
X[:5].shape
# Out:
# (5, 48, 48, 1)

# %%
y[:5].shape
# Out:
# (5,)

# %%
y = to_categorical(y, num_classes=24)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %% [markdown]
# ### Model creation

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Conv2D, MaxPooling2D, Dense, Flatten
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.utils import plot_model

# %%
model = Sequential()

model.add(InputLayer(input_shape=(48, 48, 1)))
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

model.add(Flatten())

model.add(Dense(32, activation='relu'))
model.add(Dense(24, activation='softmax'))

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy", "mae"])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 46, 46, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 23, 23, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 21, 21, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 32)          18464
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                16416
# _________________________________________________________________
# dense_1 (Dense)              (None, 24)                792
# =================================================================
# Total params: 54,488
# Trainable params: 54,488
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model, to_file='models/cnn_utk_model_2_age-range-classification.png')

# %%
filepath = 'checkpoints/age_range_model2_classification_relu.epoch{epoch:02d}-loss{val_loss:.2f}.hdf5'
checkpoint = ModelCheckpoint(filepath, monitor="val_loss", save_best_only=True, mode="min", verbose=1)

# %%
model.fit(X_train, y_train, epochs=20, batch_size=64, validation_data=(X_test, y_test), callbacks=[checkpoint])
# Out:
# Epoch 1/20
# 333/334 [============================>.] - ETA: 0s - loss: 2.5634 - accuracy: 0.2387 - mae: 0.0739
# Epoch 00001: val_loss improved from inf to 2.32909, saving model to checkpoints\age_range_model2_classification_relu.epoch01-loss2.33.hdf5
# 334/334 [==============================] - 21s 64ms/step - loss: 2.5628 - accuracy: 0.2389 - mae: 0.0739 - val_loss: 2.3291 - val_accuracy: 0.2868 - val_mae: 0.0699
# Epoch 2/20
# 333/334 [============================>.] - ETA: 0s - loss: 2.2169 - accuracy: 0.2922 - mae: 0.0678
# Epoch 00002: val_loss improved from 2.32909 to 2.11760, saving model to checkpoints\age_range_model2_classification_relu.epoch02-loss2.12.hdf5
# 334/334 [==============================] - 23s 68ms/step - loss: 2.2166 - accuracy: 0.2922 - mae: 0.0678 - val_loss: 2.1176 - val_accuracy: 0.3054 - val_mae: 0.0669
# Epoch 3/20
# 333/334 [============================>.] - ETA: 0s - loss: 2.0931 - accuracy: 0.3100 - mae: 0.0662
# Epoch 00003: val_loss improved from 2.11760 to 2.08894, saving model to checkpoints\age_range_model2_classification_relu.epoch03-loss2.09.hdf5
# 334/334 [==============================] - 26s 77ms/step - loss: 2.0932 - accuracy: 0.3100 - mae: 0.0662 - val_loss: 2.0889 - val_accuracy: 0.3125 - val_mae: 0.0642
# Epoch 4/20
# 333/334 [============================>.] - ETA: 0s - loss: 2.0182 - accuracy: 0.3199 - mae: 0.0652
# Epoch 00004: val_loss improved from 2.08894 to 2.00283, saving model to checkpoints\age_range_model2_classification_relu.epoch04-loss2.00.hdf5
# 334/334 [==============================] - 26s 77ms/step - loss: 2.0182 - accuracy: 0.3200 - mae: 0.0652 - val_loss: 2.0028 - val_accuracy: 0.3226 - val_mae: 0.0651
# Epoch 5/20
# 333/334 [============================>.] - ETA: 0s - loss: 1.9602 - accuracy: 0.3313 - mae: 0.0643 ETA: 1s - loss: 1.9616 - ac
# Epoch 00005: val_loss improved from 2.00283 to 1.96379, saving model to checkpoints\age_range_model2_classification_relu.epoch05-loss1.96.hdf5
# 334/334 [==============================] - 24s 71ms/step - loss: 1.9603 - accuracy: 0.3312 - mae: 0.0643 - val_loss: 1.9638 - val_accuracy: 0.3260 - val_mae: 0.0637
# Epoch 6/20
# 333/334 [============================>.] - ETA: 0s - loss: 1.9152 - accuracy: 0.3386 - mae: 0.0636
# Epoch 00006: val_loss improved from 1.96379 to 1.92613, saving model to checkpoints\age_range_model2_classification_relu.epoch06-loss1.93.hdf5
# 334/334 [==============================] - 24s 72ms/step - loss: 1.9149 - accuracy: 0.3388 - mae: 0.0636 - val_loss: 1.9261 - val_accuracy: 0.3214 - val_mae: 0.0654
# Epoch 7/20
# 333/334 [============================>.] - ETA: 0s - loss: 1.8693 - accuracy: 0.3502 - mae: 0.0630
# Epoch 00007: val_loss improved from 1.92613 to 1.89707, saving model to checkpoints\age_range_model2_classification_relu.epoch07-loss1.90.hdf5
# 334/334 [==============================] - 24s 72ms/step - loss: 1.8689 - accuracy: 0.3504 - mae: 0.0630 - val_loss: 1.8971 - val_accuracy: 0.3357 - val_mae: 0.0635
# Epoch 8/20
# 333/334 [============================>.] - ETA: 0s - loss: 1.8262 - accuracy: 0.3584 - mae: 0.0623
# Epoch 00008: val_loss improved from 1.89707 to 1.85390, saving model to checkpoints\age_range_model2_classification_relu.epoch08-loss1.85.hdf5
# 334/334 [==============================] - 25s 75ms/step - loss: 1.8261 - accuracy: 0.3585 - mae: 0.0623 - val_loss: 1.8539 - val_accuracy: 0.3408 - val_mae: 0.0630
# Epoch 9/20
# 333/334 [============================>.] - ETA: 0s - loss: 1.7994 - accuracy: 0.3615 - mae: 0.0619
# Epoch 00009: val_loss did not improve from 1.85390
# 334/334 [==============================] - 23s 68ms/step - loss: 1.7989 - accuracy: 0.3617 - mae: 0.0618 - val_loss: 1.8539 - val_accuracy: 0.3484 - val_mae: 0.0622
# Epoch 10/20
# 333/334 [============================>.] - ETA: 0s - loss: 1.7654 - accuracy: 0.3696 - mae: 0.0613
# Epoch 00010: val_loss improved from 1.85390 to 1.82820, saving model to checkpoints\age_range_model2_classification_relu.epoch10-loss1.83.hdf5
# 334/334 [==============================] - 24s 71ms/step - loss: 1.7653 - accuracy: 0.3696 - mae: 0.0613 - val_loss: 1.8282 - val_accuracy: 0.3475 - val_mae: 0.0625
# Epoch 11/20
# 333/334 [============================>.] - ETA: 0s - loss: 1.7490 - accuracy: 0.3760 - mae: 0.0610
# Epoch 00011: val_loss improved from 1.82820 to 1.81050, saving model to checkpoints\age_range_model2_classification_relu.epoch11-loss1.81.hdf5
# 334/334 [==============================] - 23s 69ms/step - loss: 1.7493 - accuracy: 0.3759 - mae: 0.0610 - val_loss: 1.8105 - val_accuracy: 0.3551 - val_mae: 0.0620
# Epoch 12/20
# 333/334 [============================>.] - ETA: 0s - loss: 1.7226 - accuracy: 0.3781 - mae: 0.0607
# Epoch 00012: val_loss improved from 1.81050 to 1.80985, saving model to checkpoints\age_range_model2_classification_relu.epoch12-loss1.81.hdf5
# 334/334 [==============================] - 22s 66ms/step - loss: 1.7228 - accuracy: 0.3779 - mae: 0.0607 - val_loss: 1.8098 - val_accuracy: 0.3539 - val_mae: 0.0612
# Epoch 13/20
# 333/334 [============================>.] - ETA: 0s - loss: 1.7061 - accuracy: 0.3801 - mae: 0.0604
# Epoch 00013: val_loss improved from 1.80985 to 1.79337, saving model to checkpoints\age_range_model2_classification_relu.epoch13-loss1.79.hdf5
# 334/334 [==============================] - 24s 71ms/step - loss: 1.7063 - accuracy: 0.3801 - mae: 0.0604 - val_loss: 1.7934 - val_accuracy: 0.3640 - val_mae: 0.0611
# Epoch 14/20
# 333/334 [============================>.] - ETA: 0s - loss: 1.6850 - accuracy: 0.3847 - mae: 0.0600
# Epoch 00014: val_loss did not improve from 1.79337
# 334/334 [==============================] - 23s 69ms/step - loss: 1.6854 - accuracy: 0.3845 - mae: 0.0600 - val_loss: 1.7995 - val_accuracy: 0.3534 - val_mae: 0.0614
# Epoch 15/20
# 333/334 [============================>.] - ETA: 0s - loss: 1.6659 - accuracy: 0.3917 - mae: 0.0596
# Epoch 00015: val_loss did not improve from 1.79337
# 334/334 [==============================] - 21s 62ms/step - loss: 1.6660 - accuracy: 0.3916 - mae: 0.0596 - val_loss: 1.8105 - val_accuracy: 0.3555 - val_mae: 0.0609
# Epoch 16/20
# 333/334 [============================>.] - ETA: 0s - loss: 1.6534 - accuracy: 0.3979 - mae: 0.0594
# Epoch 00016: val_loss improved from 1.79337 to 1.78275, saving model to checkpoints\age_range_model2_classification_relu.epoch16-loss1.78.hdf5
# 334/334 [==============================] - 21s 63ms/step - loss: 1.6535 - accuracy: 0.3979 - mae: 0.0594 - val_loss: 1.7827 - val_accuracy: 0.3581 - val_mae: 0.0607
# Epoch 17/20
# 333/334 [============================>.] - ETA: 0s - loss: 1.6418 - accuracy: 0.3974 - mae: 0.0592
# Epoch 00017: val_loss did not improve from 1.78275
# 334/334 [==============================] - 22s 66ms/step - loss: 1.6417 - accuracy: 0.3976 - mae: 0.0592 - val_loss: 1.7900 - val_accuracy: 0.3606 - val_mae: 0.0606
# Epoch 18/20
# 333/334 [============================>.] - ETA: 0s - loss: 1.6260 - accuracy: 0.4005 - mae: 0.0589
# Epoch 00018: val_loss did not improve from 1.78275
# 334/334 [==============================] - 26s 77ms/step - loss: 1.6259 - accuracy: 0.4005 - mae: 0.0589 - val_loss: 1.7838 - val_accuracy: 0.3581 - val_mae: 0.0601
# Epoch 19/20
# 333/334 [============================>.] - ETA: 0s - loss: 1.6196 - accuracy: 0.3977 - mae: 0.0588
# Epoch 00019: val_loss did not improve from 1.78275
# 334/334 [==============================] - 26s 79ms/step - loss: 1.6195 - accuracy: 0.3977 - mae: 0.0588 - val_loss: 1.8454 - val_accuracy: 0.3391 - val_mae: 0.0623
# Epoch 20/20
# 333/334 [============================>.] - ETA: 0s - loss: 1.6037 - accuracy: 0.4064 - mae: 0.0585
# Epoch 00020: val_loss did not improve from 1.78275
# 334/334 [==============================] - 23s 67ms/step - loss: 1.6040 - accuracy: 0.4063 - mae: 0.0585 - val_loss: 1.7889 - val_accuracy: 0.3505 - val_mae: 0.0611

# %%
pd.DataFrame(model.history.history)[["loss", "val_loss"]].plot()
# Out:
# <AxesSubplot:>

# %%
from tensorflow.math import argmax

# %%
y_pred = argmax(model.predict(X), axis=1)

# %%
np.array(y_pred).sum() / len(y_pred)
# Out:
# 6.32845391267665

# %%
pd.Series((y_pred)).plot(kind='hist', bins=40, label='Predicted', alpha=0.5)
pd.Series(argmax(y, axis = 1)).plot(kind='hist', bins=40, label='Original', alpha=0.5)

plt.legend(title='Group')

plt.ylabel('Frequency', fontsize=14)
plt.xlabel('Age', fontsize=14)
plt.title('Predicted vs Original', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Predicted vs Original')

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
sns.heatmap(confusion_matrix(argmax(y, axis = 1), y_pred))
# Out:
# <AxesSubplot:>

# %%
print(classification_report(argmax(y, axis = 1), y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.91      0.93      2167
#            1       0.56      0.70      0.62       895
#            2       0.56      0.27      0.36       589
#            3       0.49      0.34      0.40       942
#            4       0.49      0.15      0.23      2310
#            5       0.44      0.78      0.56      5034
#            6       0.30      0.14      0.19      2290
#            7       0.28      0.24      0.26      2246
#            8       0.28      0.03      0.05      1181
#            9       0.20      0.13      0.16      1064
#           10       0.25      0.45      0.32      1345
#           11       0.21      0.33      0.26       954
#           12       0.29      0.11      0.16       730
#           13       0.21      0.25      0.23       586
#           14       0.19      0.05      0.08       373
#           15       0.16      0.11      0.13       326
#           16       0.21      0.28      0.24       237
#           17       0.26      0.45      0.33       267
#           18       0.31      0.12      0.17       102
#           19       0.00      0.00      0.00        35
#           20       0.00      0.00      0.00        14
#           21       0.00      0.00      0.00         5
#           22       0.00      0.00      0.00         6
#           23       0.00      0.00      0.00         7
#
#     accuracy                           0.41     23705
#    macro avg       0.28      0.24      0.24     23705
# weighted avg       0.41      0.41      0.38     23705
# C:\Users\DELL\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\DELL\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\DELL\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
y_pred.numpy()
# Out:
# array([ 0,  0,  0, ..., 10, 16, 16], dtype=int64)

# %%
plt.figure(figsize=(16,16))
for i in range(1400,1420):
    plt.subplot(5,5,(i%25)+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(df['pixels'].iloc[i].reshape(48,48))
    pred_age = (5 * (y_pred.numpy()[i]))
    plt.xlabel(
        "Age:"+str(df['age'].iloc[i])+" Predicted: "+str(pred_age) + " to " + str(pred_age + 5))
plt.show()

# %% [markdown]
# ### Predictions for best model

# %%
import os
path = os.getcwd() + r'\checkpoints\age_range_model2_classification_relu.epoch16-loss1.78.hdf5'

# %%
best_model = tf.keras.models.load_model(path)

# %%
y_pred_best = argmax(best_model.predict(X), axis=1)

# %%
pd.Series((y_pred_best)).plot(kind='hist', bins=40, label='Predicted', alpha=0.5)
pd.Series(argmax(y, axis = 1)).plot(kind='hist', bins=40, label='Original', alpha=0.5)

plt.legend(title='Group')

plt.ylabel('Frequency', fontsize=14)
plt.xlabel('Age', fontsize=14)
plt.title('Predicted vs Original', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Predicted vs Original')

# %%
from sklearn.metrics import confusion_matrix, classification_report
sns.heatmap(confusion_matrix(argmax(y, axis = 1), y_pred_best))
# Out:
# <AxesSubplot:>

# %%
print(classification_report(argmax(y, axis = 1), y_pred_best))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.98      0.87      2167
#            1       0.56      0.33      0.42       895
#            2       0.42      0.35      0.38       589
#            3       0.49      0.22      0.31       942
#            4       0.46      0.12      0.20      2310
#            5       0.40      0.87      0.55      5034
#            6       0.28      0.04      0.07      2290
#            7       0.25      0.23      0.24      2246
#            8       0.24      0.10      0.14      1181
#            9       0.19      0.10      0.13      1064
#           10       0.26      0.35      0.30      1345
#           11       0.20      0.18      0.19       954
#           12       0.24      0.09      0.13       730
#           13       0.18      0.34      0.24       586
#           14       0.16      0.04      0.06       373
#           15       0.17      0.10      0.12       326
#           16       0.28      0.02      0.04       237
#           17       0.28      0.38      0.32       267
#           18       0.11      0.01      0.02       102
#           19       0.00      0.00      0.00        35
#           20       0.00      0.00      0.00        14
#           21       0.00      0.00      0.00         5
#           22       0.00      0.00      0.00         6
#           23       0.00      0.00      0.00         7
#
#     accuracy                           0.40     23705
#    macro avg       0.25      0.20      0.20     23705
# weighted avg       0.37      0.40      0.34     23705
# C:\Users\DELL\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\DELL\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\DELL\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
plt.figure(figsize=(16,16))
for i in range(1300,1320):
    plt.subplot(5,5,(i%25)+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(df['pixels'].iloc[i].reshape(48,48))
    pred_age = (5 * (y_pred_best.numpy()[i]))
    plt.xlabel(
        "Age:"+str(df['age'].iloc[i])+" Predicted: "+str(pred_age) + " to " + str(pred_age + 5))
plt.show()
