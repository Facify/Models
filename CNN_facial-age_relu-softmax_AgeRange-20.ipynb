# %% [markdown]
# ## Importing and Processing Data

# %%
import pandas as pd
import numpy as np

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

from tensorflow import keras
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import InputLayer, Conv2D, MaxPooling2D,GlobalAveragePooling2D,Dropout, Flatten, Dense
from keras import regularizers
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

from PIL import Image
import os

# %%
path="../input/facial-age/face_age/"

# %%
# Visualization of images

def visualize_image(age, number_of_images):
    plt.figure(figsize=(10, 10))
    folder=path+age+'/'
    images=os.listdir(folder)[:number_of_images]
    for i in range(number_of_images):
        img=mpimg.imread(folder+images[i])
        plt.subplot(number_of_images//2, 2, i+1)
        plt.imshow(img)

visualize_image("023", 10)

# %%
X=[]
y=[]

for folder, _, imgs in os.walk(path):
    if folder!="face_age":
        for img in imgs:
            img_path=folder+'/'+img
            image=Image.open(img_path)
            image=image.convert('L') #gray-scale images
            X.append(np.array(image))
            y.append(int(folder[-3:]))

X=np.array(X)
y=np.array(y);

# %%
X=X.astype("float32")
#normalization
X /= 255.0
y = y//20 #dividing in range of 20

# %%
X = X.reshape(X.shape[0], 200, 200, 1)
X.shape
# Out:
# (19556, 200, 200, 1)

# %%
pd.DataFrame(y)[0].unique()

# %%
y = to_categorical(y, num_classes=6)

# %%
# os.mkdir("../dataset/Data")

# %%
# np.save("../dataset/face_age_data/X.npy", X)
# np.save("../dataset/face_age_data/y.npy", y)
# X = np.load('../dataset/face_age_data/X.npy')
# y = np.load('../dataset/face_age_data/y.npy')

# %% [markdown]
# ## Train, Test and Validation Datasets

# %%
# Train, validation and testing split (70/15/15)

test_size = 0.2
seed = 42
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=seed, shuffle=True, stratify=y)
# X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size=0.5)

# %%
# save to files
# np.save('../dataset/face_age_data/X_train.npy', X_train)
# np.save('../dataset/face_age_data/y_train.npy', y_train)
# np.save('../dataset/face_age_data/X_val.npy', X_val)
# np.save('../dataset/face_age_data/y_val.npy', y_val)
# np.save('../dataset/face_age_data/X_test.npy', X_test)
# np.save('../dataset/face_age_data/y_test.npy', y_test)

# X_train = np.load('../dataset/face_age_data/X_train.npy')
# y_train = np.load('../dataset/face_age_data/y_train.npy')
# X_val = np.load('../dataset/face_age_data/X_val.npy')
# y_val = np.load('../dataset/face_age_data/y_val.npy')
# X_test = np.load('../dataset/face_age_data/X_test.npy')
# y_test = np.load('../dataset/face_age_data/y_test.npy')

# %%
# confirm the saved files
# os.listdir("../face_age_dataset/Data")

# %% [markdown]
# ## Image Augmentation

# %%
# Apply Image Augmentation

train_datagen = ImageDataGenerator(
    shear_range = 0.2, # random application of shearing
    zoom_range = 0.2, 
    horizontal_flip = True) # randomly flipping half of the images horizontally

test_datagen = ImageDataGenerator()

# %% [markdown]
# ## Callbacks and Default Hyperparameters

# %%
from keras.callbacks import Callback, ReduceLROnPlateau, EarlyStopping
from timeit import default_timer as timer

class TimingCallback(Callback):
    def __init__(self, logs={}):
        self.logs=[]
    def on_epoch_begin(self, epoch, logs={}):
        self.starttime = timer()
    def on_epoch_end(self, epoch, logs={}):
        self.logs.append(timer()-self.starttime)

early_stopping = EarlyStopping(
                                patience=5, # wait for 5 epochs
                                min_delta = 0.01, # if in 5 epochs the loss function doesn't increase (for accuracy) 
                                               # or decrease (for val_loss) by 1%, then stop
                                verbose=1, # print the training epoch on which training was stopped
                                mode = 'min',
                                monitor='val_loss')

reduce_learning_rate = ReduceLROnPlateau(
                                    monitor="val_loss",
                                    patience=3, # if val_loss plateaus for 3 epochs such that it doesn't see 
                                                # an improvement of size = epsilon
                                    episilon= 0.01,
                                    factor=0.1,  # then we reduce the learning rate by a factor of 0.1
                                    cooldown = 4, # and we wait for 4 epochs before we restart again
                                    verbose=1)

time_callback = TimingCallback()

        
# hyperparameters
lr = 0.01
epochs = 100
batch_size = 128
results = {}
input_shape =[200, 200]

# %% [markdown]
# ## CNN Model

# %%
def baseline_model():
    model = Sequential()

    model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(200, 200, 1)))
    model.add(MaxPooling2D((2, 2)))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Conv2D(32, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2, 2)))

    model.add(Flatten())

    model.add(Dense(32, activation='relu'))
    model.add(Dense(6, activation='softmax'))
    return model

# %%
filepath = './cnn_face-age__relu-softmax_AgeRange-20.epoch{epoch:02d}-loss{val_loss:.2f}.hdf5'
checkpoint = ModelCheckpoint(filepath, monitor="val_loss", save_best_only=True, mode="min", verbose=1)

# %%
# Adam= keras.optimizers.Adam(learning_rate=0.01,beta_1=0.9, beta_2=0.999, decay=0.0)

# %%
model = baseline_model()
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy", "mae"])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 198, 198, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 99, 99, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 97, 97, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 48, 48, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 46, 46, 32)        18464
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 23, 23, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 16928)             0
# _________________________________________________________________
# dense (Dense)                (None, 32)                541728
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 198
# =================================================================
# Total params: 579,206
# Trainable params: 579,206
# Non-trainable params: 0
# _________________________________________________________________
# User settings:
#
#    KMP_AFFINITY=granularity=fine,verbose,compact,1,0
#    KMP_BLOCKTIME=0
#    KMP_DUPLICATE_LIB_OK=True
#    KMP_INIT_AT_FORK=FALSE
#    KMP_SETTINGS=1
#    KMP_WARNINGS=0
#
# Effective settings:
#
#    KMP_ABORT_DELAY=0
#    KMP_ADAPTIVE_LOCK_PROPS='1,1024'
#    KMP_ALIGN_ALLOC=64
#    KMP_ALL_THREADPRIVATE=128
#    KMP_ATOMIC_MODE=2
#    KMP_BLOCKTIME=0
#    KMP_CPUINFO_FILE: value is not defined
#    KMP_DETERMINISTIC_REDUCTION=false
#    KMP_DEVICE_THREAD_LIMIT=2147483647
#    KMP_DISP_NUM_BUFFERS=7
#    KMP_DUPLICATE_LIB_OK=true
#    KMP_ENABLE_TASK_THROTTLING=true
#    KMP_FORCE_REDUCTION: value is not defined
#    KMP_FOREIGN_THREADS_THREADPRIVATE=true
#    KMP_FORKJOIN_BARRIER='2,2'
#    KMP_FORKJOIN_BARRIER_PATTERN='hyper,hyper'
#    KMP_GTID_MODE=3
#    KMP_HANDLE_SIGNALS=false
#    KMP_HOT_TEAMS_MAX_LEVEL=1
#    KMP_HOT_TEAMS_MODE=0
#    KMP_INIT_AT_FORK=true
#    KMP_LIBRARY=throughput
#    KMP_LOCK_KIND=queuing
#    KMP_MALLOC_POOL_INCR=1M
#    KMP_NUM_LOCKS_IN_BLOCK=1
#    KMP_PLAIN_BARRIER='2,2'
#    KMP_PLAIN_BARRIER_PATTERN='hyper,hyper'
#    KMP_REDUCTION_BARRIER='1,1'
#    KMP_REDUCTION_BARRIER_PATTERN='hyper,hyper'
#    KMP_SCHEDULE='static,balanced;guided,iterative'
#    KMP_SETTINGS=true
#    KMP_SPIN_BACKOFF_PARAMS='4096,100'
#    KMP_STACKOFFSET=64
#    KMP_STACKPAD=0
#    KMP_STACKSIZE=8M
#    KMP_STORAGE_MAP=false
#    KMP_TASKING=2
#    KMP_TASKLOOP_MIN_TASKS=0
#    KMP_TASK_STEALING_CONSTRAINT=1
#    KMP_TEAMS_THREAD_LIMIT=4
#    KMP_TOPOLOGY_METHOD=all
#    KMP_USE_YIELD=1
#    KMP_VERSION=false
#    KMP_WARNINGS=false
#    OMP_AFFINITY_FORMAT='OMP: pid %P tid %i thread %n bound to OS proc set {%A}'
#    OMP_ALLOCATOR=omp_default_mem_alloc
#    OMP_CANCELLATION=false
#    OMP_DEFAULT_DEVICE=0
#    OMP_DISPLAY_AFFINITY=false
#    OMP_DISPLAY_ENV=false
#    OMP_DYNAMIC=false
#    OMP_MAX_ACTIVE_LEVELS=1
#    OMP_MAX_TASK_PRIORITY=0
#    OMP_NESTED: deprecated; max-active-levels-var=1
#    OMP_NUM_THREADS: value is not defined
#    OMP_PLACES: value is not defined
#    OMP_PROC_BIND='intel'
#    OMP_SCHEDULE='static'
#    OMP_STACKSIZE=8M
#    OMP_TARGET_OFFLOAD=DEFAULT
#    OMP_THREAD_LIMIT=2147483647
#    OMP_WAIT_POLICY=PASSIVE
#    KMP_AFFINITY='verbose,warnings,respect,granularity=fine,compact,1,0'
#
# 2021-11-30 02:07:11.324228: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='./cnn_facial_age-relu-softmax_AgeRange-20.png')

# %%
model.fit(
    train_datagen.flow(
        X_train, y_train,
        batch_size = batch_size
    ), # use augmented images
    validation_data = (X_test, y_test),
    steps_per_epoch=X_train.shape[0] // batch_size,
    epochs = epochs,
    callbacks = [
                    reduce_learning_rate,
                    early_stopping,
                    time_callback,
                    checkpoint
                ],
    verbose=True)
# Out:
# 2021-11-30 02:07:13.058790: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 122/122 [==============================] - 316s 3s/step - loss: 1.2801 - accuracy: 0.4788 - mae: 0.2155 - val_loss: 1.0339 - val_accuracy: 0.5907 - val_mae: 0.1764
#
# Epoch 00001: val_loss improved from inf to 1.03386, saving model to ./cnn_face-age__relu-softmax_AgeRange-20.epoch01-loss1.03.hdf5
# Epoch 2/100
# 122/122 [==============================] - 309s 3s/step - loss: 1.0325 - accuracy: 0.5875 - mae: 0.1771 - val_loss: 0.9342 - val_accuracy: 0.6186 - val_mae: 0.1580
#
# Epoch 00002: val_loss improved from 1.03386 to 0.93417, saving model to ./cnn_face-age__relu-softmax_AgeRange-20.epoch02-loss0.93.hdf5
# Epoch 3/100
# 122/122 [==============================] - 310s 3s/step - loss: 0.9527 - accuracy: 0.6193 - mae: 0.1655 - val_loss: 0.8440 - val_accuracy: 0.6654 - val_mae: 0.1502
#
# Epoch 00003: val_loss improved from 0.93417 to 0.84397, saving model to ./cnn_face-age__relu-softmax_AgeRange-20.epoch03-loss0.84.hdf5
# Epoch 4/100
# 122/122 [==============================] - 310s 3s/step - loss: 0.8837 - accuracy: 0.6467 - mae: 0.1555 - val_loss: 0.8087 - val_accuracy: 0.6738 - val_mae: 0.1388
#
# Epoch 00004: val_loss improved from 0.84397 to 0.80871, saving model to ./cnn_face-age__relu-softmax_AgeRange-20.epoch04-loss0.81.hdf5
# Epoch 5/100
# 122/122 [==============================] - 310s 3s/step - loss: 0.8111 - accuracy: 0.6721 - mae: 0.1445 - val_loss: 0.7403 - val_accuracy: 0.7022 - val_mae: 0.1348
#
# Epoch 00005: val_loss improved from 0.80871 to 0.74026, saving model to ./cnn_face-age__relu-softmax_AgeRange-20.epoch05-loss0.74.hdf5
# Epoch 6/100
# 122/122 [==============================] - 308s 3s/step - loss: 0.7587 - accuracy: 0.6915 - mae: 0.1367 - val_loss: 0.7151 - val_accuracy: 0.7030 - val_mae: 0.1278
#
# Epoch 00006: val_loss improved from 0.74026 to 0.71508, saving model to ./cnn_face-age__relu-softmax_AgeRange-20.epoch06-loss0.72.hdf5
# Epoch 7/100
# 122/122 [==============================] - 309s 3s/step - loss: 0.7213 - accuracy: 0.7053 - mae: 0.1303 - val_loss: 0.6662 - val_accuracy: 0.7226 - val_mae: 0.1257
#
# Epoch 00007: val_loss improved from 0.71508 to 0.66619, saving model to ./cnn_face-age__relu-softmax_AgeRange-20.epoch07-loss0.67.hdf5
# Epoch 8/100
# 122/122 [==============================] - 309s 3s/step - loss: 0.6960 - accuracy: 0.7115 - mae: 0.1269 - val_loss: 0.6509 - val_accuracy: 0.7234 - val_mae: 0.1201
#
# Epoch 00008: val_loss improved from 0.66619 to 0.65087, saving model to ./cnn_face-age__relu-softmax_AgeRange-20.epoch08-loss0.65.hdf5
# Epoch 9/100
# 122/122 [==============================] - 309s 3s/step - loss: 0.6563 - accuracy: 0.7300 - mae: 0.1213 - val_loss: 0.6060 - val_accuracy: 0.7472 - val_mae: 0.1134
#
# Epoch 00009: val_loss improved from 0.65087 to 0.60599, saving model to ./cnn_face-age__relu-softmax_AgeRange-20.epoch09-loss0.61.hdf5
# Epoch 10/100
# 122/122 [==============================] - 310s 3s/step - loss: 0.6351 - accuracy: 0.7413 - mae: 0.1176 - val_loss: 0.5906 - val_accuracy: 0.7551 - val_mae: 0.1076
#
# Epoch 00010: val_loss improved from 0.60599 to 0.59059, saving model to ./cnn_face-age__relu-softmax_AgeRange-20.epoch10-loss0.59.hdf5
# Epoch 11/100
# 122/122 [==============================] - 309s 3s/step - loss: 0.6195 - accuracy: 0.7429 - mae: 0.1153 - val_loss: 0.6034 - val_accuracy: 0.7520 - val_mae: 0.1079
#
# Epoch 00011: val_loss did not improve from 0.59059
# Epoch 12/100
# 122/122 [==============================] - 311s 3s/step - loss: 0.6015 - accuracy: 0.7524 - mae: 0.1123 - val_loss: 0.5707 - val_accuracy: 0.7612 - val_mae: 0.1059
#
# Epoch 00012: val_loss improved from 0.59059 to 0.57075, saving model to ./cnn_face-age__relu-softmax_AgeRange-20.epoch12-loss0.57.hdf5
# Epoch 13/100
# 122/122 [==============================] - 309s 3s/step - loss: 0.5838 - accuracy: 0.7590 - mae: 0.1093 - val_loss: 0.5703 - val_accuracy: 0.7684 - val_mae: 0.1091
#
# Epoch 00013: val_loss improved from 0.57075 to 0.57030, saving model to ./cnn_face-age__relu-softmax_AgeRange-20.epoch13-loss0.57.hdf5
# Epoch 14/100
# 122/122 [==============================] - 309s 3s/step - loss: 0.5727 - accuracy: 0.7629 - mae: 0.1078 - val_loss: 0.5481 - val_accuracy: 0.7717 - val_mae: 0.1018
#
# Epoch 00014: val_loss improved from 0.57030 to 0.54805, saving model to ./cnn_face-age__relu-softmax_AgeRange-20.epoch14-loss0.55.hdf5
# Epoch 15/100
# 122/122 [==============================] - 308s 3s/step - loss: 0.5606 - accuracy: 0.7661 - mae: 0.1061 - val_loss: 0.5463 - val_accuracy: 0.7658 - val_mae: 0.1017
#
# Epoch 00015: val_loss improved from 0.54805 to 0.54630, saving model to ./cnn_face-age__relu-softmax_AgeRange-20.epoch15-loss0.55.hdf5
# Epoch 16/100
# 122/122 [==============================] - 309s 3s/step - loss: 0.5418 - accuracy: 0.7738 - mae: 0.1021 - val_loss: 0.5545 - val_accuracy: 0.7669 - val_mae: 0.1029
#
# Epoch 00016: val_loss did not improve from 0.54630
# Epoch 17/100
# 122/122 [==============================] - 310s 3s/step - loss: 0.5427 - accuracy: 0.7753 - mae: 0.1027 - val_loss: 0.5186 - val_accuracy: 0.7868 - val_mae: 0.0976
#
# Epoch 00017: val_loss improved from 0.54630 to 0.51856, saving model to ./cnn_face-age__relu-softmax_AgeRange-20.epoch17-loss0.52.hdf5
# Epoch 18/100
# 122/122 [==============================] - 310s 3s/step - loss: 0.5344 - accuracy: 0.7789 - mae: 0.1012 - val_loss: 0.5269 - val_accuracy: 0.7802 - val_mae: 0.0978
#
# Epoch 00018: val_loss did not improve from 0.51856
# Epoch 19/100
# 122/122 [==============================] - 310s 3s/step - loss: 0.5189 - accuracy: 0.7852 - mae: 0.0984 - val_loss: 0.5184 - val_accuracy: 0.7832 - val_mae: 0.0970
#
# Epoch 00019: val_loss improved from 0.51856 to 0.51836, saving model to ./cnn_face-age__relu-softmax_AgeRange-20.epoch19-loss0.52.hdf5
# Epoch 20/100
# 122/122 [==============================] - 309s 3s/step - loss: 0.5190 - accuracy: 0.7867 - mae: 0.0983 - val_loss: 0.5203 - val_accuracy: 0.7817 - val_mae: 0.0938
#
# Epoch 00020: val_loss did not improve from 0.51836
# Epoch 21/100
# 122/122 [==============================] - 310s 3s/step - loss: 0.5064 - accuracy: 0.7876 - mae: 0.0962 - val_loss: 0.5128 - val_accuracy: 0.7802 - val_mae: 0.0958
#
# Epoch 00021: val_loss improved from 0.51836 to 0.51280, saving model to ./cnn_face-age__relu-softmax_AgeRange-20.epoch21-loss0.51.hdf5
# Epoch 22/100
# 122/122 [==============================] - 313s 3s/step - loss: 0.5029 - accuracy: 0.7918 - mae: 0.0956 - val_loss: 0.5139 - val_accuracy: 0.7899 - val_mae: 0.0961
#
# Epoch 00022: val_loss did not improve from 0.51280
# Epoch 00022: early stopping

# %%
baseline_adam_train_loss = model.history.history["loss"]
baseline_adam_val_loss = model.history.history["val_loss"]
baseline_adam_train_acc = model.history.history["mae"]
baseline_adam_val_acc = model.history.history["val_mae"]

results["baseline_adam"] = {'train-loss': baseline_adam_train_loss,
                             'val-loss': baseline_adam_val_loss,
                             'train-mae': baseline_adam_train_acc,
                             'val-mae': baseline_adam_val_acc}

# %% [markdown]
# ## Performance Visualization

# %%
plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-mae'])),results[cond]['train-mae'], '-', label=cond+"_train", color="blue")
    plt.plot(range(len(results[cond]['val-mae'])),results[cond]['val-mae'], '-', label=cond+"_val", color="green")
plt.title("Mean Absolute Error")
plt.xlabel("Epochs")
plt.legend()
plt.show()

# %% [markdown]
# ## Results on Test Set

# %%
model_test_results = model.evaluate(X_test, y_test, batch_size=128)
dict(zip(model.metrics_names, model_test_results))
# Out:
# 31/31 [==============================] - 16s 504ms/step - loss: 0.5139 - accuracy: 0.7899 - mae: 0.0961
# {'loss': 0.5138835906982422,
#  'accuracy': 0.7898772954940796,
#  'mae': 0.09608487784862518}

# %%
from tensorflow.math import argmax

# %%
y_pred = argmax(model.predict(X_test), axis=1)

# %% [markdown]
# ## Performance in Age Range of 20

# %%
pd.Series((y_pred)).plot(kind='hist', bins=40, label='Predicted', alpha=0.5)
pd.Series(argmax(y_test, axis = 1)).plot(kind='hist', bins=40, label='Original', alpha=0.5)

plt.legend(title='Group')

plt.ylabel('Frequency', fontsize=14)
plt.xlabel('Age', fontsize=14)
plt.title('Predicted vs Original', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Predicted vs Original')

# %%
import seaborn as sns
sns.heatmap(confusion_matrix(argmax(y_test, axis = 1), y_pred))
# Out:
# <AxesSubplot:>

# %%
print(classification_report(argmax(y_test, axis = 1), y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.94      1666
#            1       0.77      0.76      0.76      1021
#            2       0.58      0.71      0.64       645
#            3       0.62      0.56      0.59       414
#            4       0.84      0.46      0.59       164
#            5       0.00      0.00      0.00         2
#
#     accuracy                           0.79      3912
#    macro avg       0.63      0.57      0.59      3912
# weighted avg       0.80      0.79      0.79      3912
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
