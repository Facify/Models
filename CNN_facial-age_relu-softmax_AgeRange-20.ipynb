# %% [markdown]
# ## Importing and Processing Data

# %%
import pandas as pd
import numpy as np
import cv2

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

from tensorflow import keras
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import InputLayer, Conv2D, MaxPooling2D, AveragePooling2D,GlobalAveragePooling2D, GlobalMaxPooling2D,Dropout, Flatten, Dense
from keras import regularizers
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

import os

# %%
path="../input/facial-age/face_age/"

# %%
# Visualization of images

def visualize_image(age, number_of_images):
    plt.figure(figsize=(10, 10))
    folder=path+age+'/'
    images=os.listdir(folder)[:number_of_images]
    for i in range(number_of_images):
        img = cv2.imread(folder+images[i], 0)
        
#         highThresh, thresh_im = cv2.threshold(img, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
#         lowThresh = 0.5*highThresh
#         edges = cv2.Canny(img, lowThresh, highThresh)
        
#         v = np.median(img)
#         sigma = 0.33
#         lower = int(max(0, (1.0 - sigma) * v))
#         upper = int(min(255, (1.0 + sigma) * v))
#         edges = cv2.Canny(img, lower, upper)

#         plt.subplot(number_of_images//2, 4, 2*i+1),plt.imshow(img, cmap = 'gray')
#         plt.title('Original Image'), plt.xticks([]), plt.yticks([])
#         plt.subplot(number_of_images//2, 4, 2*i+2),plt.imshow(edges, cmap = 'gray')
#         plt.title('Edge Image'), plt.xticks([]), plt.yticks([])

        plt.subplot(number_of_images//2, 2, i+1),plt.imshow(img, cmap = 'gray')

visualize_image("026", 10)

# %%
X=[]
y=[]

for folder, _, imgs in os.walk(path):
    if folder!="face_age":
        for img in imgs:
            img_path=folder+'/'+img
            image = cv2.imread(img_path, 0)
            
#             highThresh, thresh_im = cv2.threshold(image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
#             lowThresh = 0.5*highThresh
#             edges = cv2.Canny(image, lowThresh, highThresh)
            
#             X.append(np.array(edges))
            X.append(np.array(image))
            y.append(int(folder[-3:]))

X=np.array(X)
y=np.array(y);

# %%
X=X.astype("float32")
#normalization
X /= 255.0
y = y//20 #dividing in range of 20

# %%
X = X.reshape(X.shape[0], 200, 200, 1)
X.shape
# Out:
# (19556, 200, 200, 1)

# %%
pd.DataFrame(y)[0].unique()
# Out:
# array([2, 4, 3, 0, 1, 5])

# %%
y = to_categorical(y, num_classes=6)

# %%
# os.mkdir("../dataset/Data")

# %%
# np.save("../dataset/face_age_data/X.npy", X)
# np.save("../dataset/face_age_data/y.npy", y)
# X = np.load('../dataset/face_age_data/X.npy')
# y = np.load('../dataset/face_age_data/y.npy')

# %% [markdown]
# ## Train, Test and Validation Datasets

# %%
# Train, validation and testing split

test_size = 0.2
seed = 42
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=seed, shuffle=True, stratify=y)
# X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size=0.5)

# %%
# save to files
# np.save('../dataset/face_age_data/X_train.npy', X_train)
# np.save('../dataset/face_age_data/y_train.npy', y_train)
# np.save('../dataset/face_age_data/X_val.npy', X_val)
# np.save('../dataset/face_age_data/y_val.npy', y_val)
# np.save('../dataset/face_age_data/X_test.npy', X_test)
# np.save('../dataset/face_age_data/y_test.npy', y_test)

# X_train = np.load('../dataset/face_age_data/X_train.npy')
# y_train = np.load('../dataset/face_age_data/y_train.npy')
# X_val = np.load('../dataset/face_age_data/X_val.npy')
# y_val = np.load('../dataset/face_age_data/y_val.npy')
# X_test = np.load('../dataset/face_age_data/X_test.npy')
# y_test = np.load('../dataset/face_age_data/y_test.npy')

# %%
# confirm the saved files
# os.listdir("../face_age_dataset/Data")

# %% [markdown]
# ## Image Augmentation

# %%
# Apply Image Augmentation

train_datagen = ImageDataGenerator(
    shear_range = 0.2, # random application of shearing
    zoom_range = 0.2, 
    horizontal_flip = True) # randomly flipping half of the images horizontally

test_datagen = ImageDataGenerator()

# %% [markdown]
# ## Callbacks and Default Hyperparameters

# %%
from keras.callbacks import Callback, ReduceLROnPlateau, EarlyStopping
from timeit import default_timer as timer

class TimingCallback(Callback):
    def __init__(self, logs={}):
        self.logs=[]
    def on_epoch_begin(self, epoch, logs={}):
        self.starttime = timer()
    def on_epoch_end(self, epoch, logs={}):
        self.logs.append(timer()-self.starttime)

early_stopping = EarlyStopping(
                                patience=6, # wait for 6 epochs
                                min_delta = 0.01, # if in 6 epochs the loss function doesn't increase (for accuracy) 
                                               # or decrease (for val_loss) by 1%, then stop
                                verbose=1, # print the training epoch on which training was stopped
                                mode = 'min',
                                monitor='val_loss')

reduce_learning_rate = ReduceLROnPlateau(
                                    monitor="val_loss",
                                    patience=3, # if val_loss plateaus for 3 epochs such that it doesn't see 
                                                # an improvement of size = epsilon
                                    episilon= 0.01,
                                    factor=0.1,  # then we reduce the learning rate by a factor of 0.1
                                    cooldown = 4, # and we wait for 4 epochs before we restart again
                                    verbose=1)

time_callback = TimingCallback()

        
# hyperparameters
lr = 0.01
epochs = 100
batch_size = 128
results = {}
input_shape =[200, 200]

# %% [markdown]
# ## CNN Model

# %%
def baseline_model():
    model = Sequential()

    model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(200, 200, 1)))
    model.add(MaxPooling2D((2, 2)))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2, 2)))

    model.add(Flatten())
    model.add(Dropout(0.4))
    
    model.add(Dense(128, activation='relu'))
    model.add(Dense(6, activation='softmax'))
    return model

# %%
filepath = './cnn_face-age__relu-softmax_AgeRange-20.epoch{epoch:02d}-loss{val_loss:.2f}.hdf5'
checkpoint = ModelCheckpoint(filepath, monitor="val_loss", save_best_only=True, mode="min", verbose=1)

# %%
# Adam= keras.optimizers.Adam(learning_rate=0.01,beta_1=0.9, beta_2=0.999, decay=0.0)

# %%
model = baseline_model()
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy", "mae"])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 198, 198, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 99, 99, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 97, 97, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 48, 48, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 46, 46, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 23, 23, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 33856)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 33856)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               4333696
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 774
# =================================================================
# Total params: 4,390,214
# Trainable params: 4,390,214
# Non-trainable params: 0
# _________________________________________________________________
# 2021-12-20 22:07:40.888193: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-20 22:07:41.001107: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-20 22:07:41.001840: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-20 22:07:41.002988: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-12-20 22:07:41.004001: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-20 22:07:41.004666: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-20 22:07:41.005285: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-20 22:07:42.684552: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-20 22:07:42.685417: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-20 22:07:42.686135: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-20 22:07:42.686756: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='./cnn_facial_age-relu-softmax_AgeRange-20.png')

# %%
model.fit(
    train_datagen.flow(
        X_train, y_train,
        batch_size = batch_size
    ), # use augmented images
    validation_data = (X_test, y_test),
    steps_per_epoch=X_train.shape[0] // batch_size,
    epochs = epochs,
    callbacks = [
                    reduce_learning_rate,
                    early_stopping,
                    time_callback,
                    checkpoint
                ],
    verbose=True)
# Out:
# 2021-12-20 22:07:44.381098: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2021-12-20 22:07:46.044587: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 122/122 [==============================] - ETA: 0s - loss: 1.2014 - accuracy: 0.5113 - mae: 0.2012
# 2021-12-20 22:08:32.113710: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 625920000 exceeds 10% of free system memory.
# 2021-12-20 22:08:32.824119: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 625920000 exceeds 10% of free system memory.
# 122/122 [==============================] - 50s 352ms/step - loss: 1.2014 - accuracy: 0.5113 - mae: 0.2012 - val_loss: 0.9277 - val_accuracy: 0.6217 - val_mae: 0.1633
#
# Epoch 00001: val_loss improved from inf to 0.92767, saving model to ./cnn_face-age__relu-softmax_AgeRange-20.epoch01-loss0.93.hdf5
# Epoch 2/100
# 122/122 [==============================] - 42s 341ms/step - loss: 0.9388 - accuracy: 0.6159 - mae: 0.1638 - val_loss: 0.8210 - val_accuracy: 0.6603 - val_mae: 0.1520
#
# Epoch 00002: val_loss improved from 0.92767 to 0.82098, saving model to ./cnn_face-age__relu-softmax_AgeRange-20.epoch02-loss0.82.hdf5
# Epoch 3/100
# 122/122 [==============================] - 43s 350ms/step - loss: 0.8319 - accuracy: 0.6553 - mae: 0.1484 - val_loss: 0.7534 - val_accuracy: 0.7019 - val_mae: 0.1395
#
# Epoch 00003: val_loss improved from 0.82098 to 0.75339, saving model to ./cnn_face-age__relu-softmax_AgeRange-20.epoch03-loss0.75.hdf5
# Epoch 4/100
# 122/122 [==============================] - 41s 339ms/step - loss: 0.7867 - accuracy: 0.6749 - mae: 0.1410 - val_loss: 0.6781 - val_accuracy: 0.7168 - val_mae: 0.1242
#
# Epoch 00004: val_loss improved from 0.75339 to 0.67812, saving model to ./cnn_face-age__relu-softmax_AgeRange-20.epoch04-loss0.68.hdf5
# Epoch 5/100
# 122/122 [==============================] - 42s 346ms/step - loss: 0.7310 - accuracy: 0.7012 - mae: 0.1325 - val_loss: 0.7005 - val_accuracy: 0.7111 - val_mae: 0.1212
#
# Epoch 00005: val_loss did not improve from 0.67812
# Epoch 6/100
# 122/122 [==============================] - 42s 341ms/step - loss: 0.7003 - accuracy: 0.7102 - mae: 0.1279 - val_loss: 0.6098 - val_accuracy: 0.7485 - val_mae: 0.1136
#
# Epoch 00006: val_loss improved from 0.67812 to 0.60982, saving model to ./cnn_face-age__relu-softmax_AgeRange-20.epoch06-loss0.61.hdf5
# Epoch 7/100
# 122/122 [==============================] - 42s 347ms/step - loss: 0.6603 - accuracy: 0.7280 - mae: 0.1212 - val_loss: 0.5949 - val_accuracy: 0.7528 - val_mae: 0.1103
#
# Epoch 00007: val_loss improved from 0.60982 to 0.59494, saving model to ./cnn_face-age__relu-softmax_AgeRange-20.epoch07-loss0.59.hdf5
# Epoch 8/100
# 122/122 [==============================] - 42s 344ms/step - loss: 0.6466 - accuracy: 0.7329 - mae: 0.1189 - val_loss: 0.5999 - val_accuracy: 0.7500 - val_mae: 0.1120
#
# Epoch 00008: val_loss did not improve from 0.59494
# Epoch 9/100
# 122/122 [==============================] - 42s 343ms/step - loss: 0.6213 - accuracy: 0.7424 - mae: 0.1153 - val_loss: 0.5642 - val_accuracy: 0.7628 - val_mae: 0.1086
#
# Epoch 00009: val_loss improved from 0.59494 to 0.56420, saving model to ./cnn_face-age__relu-softmax_AgeRange-20.epoch09-loss0.56.hdf5
# Epoch 10/100
# 122/122 [==============================] - 42s 340ms/step - loss: 0.5950 - accuracy: 0.7523 - mae: 0.1109 - val_loss: 0.5883 - val_accuracy: 0.7513 - val_mae: 0.1110
#
# Epoch 00010: val_loss did not improve from 0.56420
# Epoch 11/100
# 122/122 [==============================] - 41s 338ms/step - loss: 0.5859 - accuracy: 0.7624 - mae: 0.1091 - val_loss: 0.5300 - val_accuracy: 0.7802 - val_mae: 0.1027
#
# Epoch 00011: val_loss improved from 0.56420 to 0.53004, saving model to ./cnn_face-age__relu-softmax_AgeRange-20.epoch11-loss0.53.hdf5
# Epoch 12/100
# 122/122 [==============================] - 42s 344ms/step - loss: 0.5663 - accuracy: 0.7630 - mae: 0.1068 - val_loss: 0.5224 - val_accuracy: 0.7837 - val_mae: 0.0985
#
# Epoch 00012: val_loss improved from 0.53004 to 0.52238, saving model to ./cnn_face-age__relu-softmax_AgeRange-20.epoch12-loss0.52.hdf5
# Epoch 13/100
# 122/122 [==============================] - 42s 342ms/step - loss: 0.5583 - accuracy: 0.7709 - mae: 0.1042 - val_loss: 0.5080 - val_accuracy: 0.7899 - val_mae: 0.0974
#
# Epoch 00013: val_loss improved from 0.52238 to 0.50800, saving model to ./cnn_face-age__relu-softmax_AgeRange-20.epoch13-loss0.51.hdf5
# Epoch 14/100
# 122/122 [==============================] - 42s 348ms/step - loss: 0.5432 - accuracy: 0.7770 - mae: 0.1024 - val_loss: 0.5013 - val_accuracy: 0.7978 - val_mae: 0.0932
#
# Epoch 00014: val_loss improved from 0.50800 to 0.50127, saving model to ./cnn_face-age__relu-softmax_AgeRange-20.epoch14-loss0.50.hdf5
# Epoch 15/100
# 122/122 [==============================] - 42s 345ms/step - loss: 0.5223 - accuracy: 0.7854 - mae: 0.0986 - val_loss: 0.5115 - val_accuracy: 0.7853 - val_mae: 0.0992
#
# Epoch 00015: val_loss did not improve from 0.50127
# Epoch 16/100
# 122/122 [==============================] - 42s 344ms/step - loss: 0.5220 - accuracy: 0.7822 - mae: 0.0985 - val_loss: 0.4851 - val_accuracy: 0.7914 - val_mae: 0.0935
#
# Epoch 00016: val_loss improved from 0.50127 to 0.48514, saving model to ./cnn_face-age__relu-softmax_AgeRange-20.epoch16-loss0.49.hdf5
# Epoch 17/100
# 122/122 [==============================] - 42s 346ms/step - loss: 0.5039 - accuracy: 0.7965 - mae: 0.0954 - val_loss: 0.4844 - val_accuracy: 0.8011 - val_mae: 0.0906
#
# Epoch 00017: val_loss improved from 0.48514 to 0.48440, saving model to ./cnn_face-age__relu-softmax_AgeRange-20.epoch17-loss0.48.hdf5
# Epoch 18/100
# 122/122 [==============================] - 42s 343ms/step - loss: 0.4887 - accuracy: 0.7974 - mae: 0.0928 - val_loss: 0.4725 - val_accuracy: 0.8042 - val_mae: 0.0876
#
# Epoch 00018: val_loss improved from 0.48440 to 0.47251, saving model to ./cnn_face-age__relu-softmax_AgeRange-20.epoch18-loss0.47.hdf5
# Epoch 19/100
# 122/122 [==============================] - 43s 353ms/step - loss: 0.4856 - accuracy: 0.8026 - mae: 0.0923 - val_loss: 0.4986 - val_accuracy: 0.7932 - val_mae: 0.0937
#
# Epoch 00019: val_loss did not improve from 0.47251
# Epoch 20/100
# 122/122 [==============================] - 42s 340ms/step - loss: 0.4803 - accuracy: 0.8070 - mae: 0.0911 - val_loss: 0.4447 - val_accuracy: 0.8149 - val_mae: 0.0861
#
# Epoch 00020: val_loss improved from 0.47251 to 0.44466, saving model to ./cnn_face-age__relu-softmax_AgeRange-20.epoch20-loss0.44.hdf5
# Epoch 21/100
# 122/122 [==============================] - 42s 344ms/step - loss: 0.4622 - accuracy: 0.8142 - mae: 0.0881 - val_loss: 0.4734 - val_accuracy: 0.7991 - val_mae: 0.0878
#
# Epoch 00021: val_loss did not improve from 0.44466
# Epoch 22/100
# 122/122 [==============================] - 42s 341ms/step - loss: 0.4615 - accuracy: 0.8123 - mae: 0.0881 - val_loss: 0.4443 - val_accuracy: 0.8139 - val_mae: 0.0834
#
# Epoch 00022: val_loss improved from 0.44466 to 0.44427, saving model to ./cnn_face-age__relu-softmax_AgeRange-20.epoch22-loss0.44.hdf5
# Epoch 23/100
# 122/122 [==============================] - 42s 345ms/step - loss: 0.4523 - accuracy: 0.8183 - mae: 0.0859 - val_loss: 0.4301 - val_accuracy: 0.8208 - val_mae: 0.0850
#
# Epoch 00023: val_loss improved from 0.44427 to 0.43011, saving model to ./cnn_face-age__relu-softmax_AgeRange-20.epoch23-loss0.43.hdf5
# Epoch 24/100
# 122/122 [==============================] - 43s 348ms/step - loss: 0.4354 - accuracy: 0.8227 - mae: 0.0837 - val_loss: 0.4254 - val_accuracy: 0.8213 - val_mae: 0.0802
#
# Epoch 00024: val_loss improved from 0.43011 to 0.42535, saving model to ./cnn_face-age__relu-softmax_AgeRange-20.epoch24-loss0.43.hdf5
# Epoch 25/100
# 122/122 [==============================] - 42s 345ms/step - loss: 0.4281 - accuracy: 0.8261 - mae: 0.0822 - val_loss: 0.4242 - val_accuracy: 0.8234 - val_mae: 0.0807
#
# Epoch 00025: val_loss improved from 0.42535 to 0.42422, saving model to ./cnn_face-age__relu-softmax_AgeRange-20.epoch25-loss0.42.hdf5
# Epoch 26/100
# 122/122 [==============================] - 43s 354ms/step - loss: 0.4262 - accuracy: 0.8280 - mae: 0.0813 - val_loss: 0.4134 - val_accuracy: 0.8303 - val_mae: 0.0788
#
# Epoch 00026: val_loss improved from 0.42422 to 0.41335, saving model to ./cnn_face-age__relu-softmax_AgeRange-20.epoch26-loss0.41.hdf5
# Epoch 27/100
# 122/122 [==============================] - 42s 346ms/step - loss: 0.4199 - accuracy: 0.8299 - mae: 0.0805 - val_loss: 0.4183 - val_accuracy: 0.8346 - val_mae: 0.0748
#
# Epoch 00027: val_loss did not improve from 0.41335
# Epoch 28/100
# 122/122 [==============================] - 42s 344ms/step - loss: 0.4123 - accuracy: 0.8293 - mae: 0.0792 - val_loss: 0.4135 - val_accuracy: 0.8361 - val_mae: 0.0754
#
# Epoch 00028: val_loss did not improve from 0.41335
# Epoch 29/100
# 122/122 [==============================] - 42s 348ms/step - loss: 0.3963 - accuracy: 0.8381 - mae: 0.0758 - val_loss: 0.4254 - val_accuracy: 0.8206 - val_mae: 0.0791
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00029: val_loss did not improve from 0.41335
# Epoch 30/100
# 122/122 [==============================] - 42s 348ms/step - loss: 0.3682 - accuracy: 0.8530 - mae: 0.0720 - val_loss: 0.3847 - val_accuracy: 0.8479 - val_mae: 0.0703
#
# Epoch 00030: val_loss improved from 0.41335 to 0.38472, saving model to ./cnn_face-age__relu-softmax_AgeRange-20.epoch30-loss0.38.hdf5
# Epoch 31/100
# 122/122 [==============================] - 43s 349ms/step - loss: 0.3587 - accuracy: 0.8547 - mae: 0.0698 - val_loss: 0.3837 - val_accuracy: 0.8451 - val_mae: 0.0699
#
# Epoch 00031: val_loss improved from 0.38472 to 0.38365, saving model to ./cnn_face-age__relu-softmax_AgeRange-20.epoch31-loss0.38.hdf5
# Epoch 32/100
# 122/122 [==============================] - 43s 353ms/step - loss: 0.3511 - accuracy: 0.8587 - mae: 0.0685 - val_loss: 0.3852 - val_accuracy: 0.8469 - val_mae: 0.0699
#
# Epoch 00032: val_loss did not improve from 0.38365
# Epoch 33/100
# 122/122 [==============================] - 42s 345ms/step - loss: 0.3511 - accuracy: 0.8593 - mae: 0.0682 - val_loss: 0.3749 - val_accuracy: 0.8492 - val_mae: 0.0693
#
# Epoch 00033: val_loss improved from 0.38365 to 0.37495, saving model to ./cnn_face-age__relu-softmax_AgeRange-20.epoch33-loss0.37.hdf5
# Epoch 34/100
# 122/122 [==============================] - 42s 345ms/step - loss: 0.3452 - accuracy: 0.8627 - mae: 0.0671 - val_loss: 0.3830 - val_accuracy: 0.8479 - val_mae: 0.0694
#
# Epoch 00034: val_loss did not improve from 0.37495
# Epoch 35/100
# 122/122 [==============================] - 43s 348ms/step - loss: 0.3466 - accuracy: 0.8609 - mae: 0.0674 - val_loss: 0.3730 - val_accuracy: 0.8492 - val_mae: 0.0680
#
# Epoch 00035: val_loss improved from 0.37495 to 0.37300, saving model to ./cnn_face-age__relu-softmax_AgeRange-20.epoch35-loss0.37.hdf5
# Epoch 36/100
# 122/122 [==============================] - 42s 345ms/step - loss: 0.3405 - accuracy: 0.8640 - mae: 0.0669 - val_loss: 0.3812 - val_accuracy: 0.8471 - val_mae: 0.0693
#
# Epoch 00036: val_loss did not improve from 0.37300
# Epoch 37/100
# 122/122 [==============================] - 42s 343ms/step - loss: 0.3443 - accuracy: 0.8632 - mae: 0.0671 - val_loss: 0.3757 - val_accuracy: 0.8484 - val_mae: 0.0683
#
# Epoch 00037: val_loss did not improve from 0.37300
# Epoch 38/100
# 122/122 [==============================] - 42s 345ms/step - loss: 0.3482 - accuracy: 0.8619 - mae: 0.0675 - val_loss: 0.3707 - val_accuracy: 0.8499 - val_mae: 0.0679
#
# Epoch 00038: val_loss improved from 0.37300 to 0.37070, saving model to ./cnn_face-age__relu-softmax_AgeRange-20.epoch38-loss0.37.hdf5
# Epoch 39/100
# 122/122 [==============================] - 42s 346ms/step - loss: 0.3385 - accuracy: 0.8656 - mae: 0.0663 - val_loss: 0.3722 - val_accuracy: 0.8517 - val_mae: 0.0673
#
# Epoch 00039: val_loss did not improve from 0.37070
# Epoch 40/100
# 122/122 [==============================] - 42s 340ms/step - loss: 0.3386 - accuracy: 0.8651 - mae: 0.0660 - val_loss: 0.3697 - val_accuracy: 0.8535 - val_mae: 0.0672
#
# Epoch 00040: val_loss improved from 0.37070 to 0.36968, saving model to ./cnn_face-age__relu-softmax_AgeRange-20.epoch40-loss0.37.hdf5
# Epoch 41/100
# 122/122 [==============================] - 42s 345ms/step - loss: 0.3353 - accuracy: 0.8668 - mae: 0.0653 - val_loss: 0.3670 - val_accuracy: 0.8563 - val_mae: 0.0662
#
# Epoch 00041: val_loss improved from 0.36968 to 0.36700, saving model to ./cnn_face-age__relu-softmax_AgeRange-20.epoch41-loss0.37.hdf5
# Epoch 00041: early stopping

# %%
baseline_adam_train_loss = model.history.history["loss"]
baseline_adam_val_loss = model.history.history["val_loss"]
baseline_adam_train_acc = model.history.history["mae"]
baseline_adam_val_acc = model.history.history["val_mae"]

results["baseline_adam"] = {'train-loss': baseline_adam_train_loss,
                             'val-loss': baseline_adam_val_loss,
                             'train-mae': baseline_adam_train_acc,
                             'val-mae': baseline_adam_val_acc}

# %% [markdown]
# ## Performance Visualization

# %%
plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-mae'])),results[cond]['train-mae'], '-', label=cond+"_train", color="blue")
    plt.plot(range(len(results[cond]['val-mae'])),results[cond]['val-mae'], '-', label=cond+"_val", color="green")
plt.title("Mean Absolute Error")
plt.xlabel("Epochs")
plt.legend()
plt.show()

# %% [markdown]
# ## Results on Test Set

# %%
model_test_results = model.evaluate(X_test, y_test, batch_size=128)
dict(zip(model.metrics_names, model_test_results))
# Out:
# 2021-12-20 22:50:27.316116: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 625920000 exceeds 10% of free system memory.
# 2021-12-20 22:50:27.989245: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 625920000 exceeds 10% of free system memory.
# 31/31 [==============================] - 1s 35ms/step - loss: 0.3670 - accuracy: 0.8563 - mae: 0.0662
# {'loss': 0.3669985234737396,
#  'accuracy': 0.8563394546508789,
#  'mae': 0.06619924306869507}

# %%
from tensorflow.math import argmax

# %%
y_pred = argmax(model.predict(X_test), axis=1)
# Out:
# 2021-12-20 22:50:29.557390: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 625920000 exceeds 10% of free system memory.

# %% [markdown]
# ## Performance in Age Range of 20

# %%
pd.Series((y_pred)).plot(kind='hist', bins=40, label='Predicted', alpha=0.5)
pd.Series(argmax(y_test, axis = 1)).plot(kind='hist', bins=40, label='Original', alpha=0.5)

plt.legend(title='Group')

plt.ylabel('Frequency', fontsize=14)
plt.xlabel('Age', fontsize=14)
plt.title('Predicted vs Original', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Predicted vs Original')

# %%
import seaborn as sns
sns.heatmap(confusion_matrix(argmax(y_test, axis = 1), y_pred))
# Out:
# <AxesSubplot:>

# %%
print(classification_report(argmax(y_test, axis = 1), y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.97      1666
#            1       0.81      0.85      0.83      1021
#            2       0.72      0.66      0.69       645
#            3       0.72      0.78      0.75       414
#            4       0.82      0.84      0.83       164
#            5       1.00      0.50      0.67         2
#
#     accuracy                           0.86      3912
#    macro avg       0.84      0.76      0.79      3912
# weighted avg       0.86      0.86      0.86      3912
