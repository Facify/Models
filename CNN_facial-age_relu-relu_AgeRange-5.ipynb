# %% [markdown]
# ## Importing and Processing Data

# %%
import pandas as pd
import numpy as np

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

from tensorflow import keras
from keras.models import Sequential
from keras.layers import InputLayer, Conv2D, MaxPooling2D,GlobalAveragePooling2D,Dropout, Flatten, Dense
from keras import regularizers
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

from PIL import Image
import os

# %%
path="../input/facial-age/face_age/"

# %%
# Visualization of images

def visualize_image(age, number_of_images):
    plt.figure(figsize=(10, 10))
    folder=path+age+'/'
    images=os.listdir(folder)[:number_of_images]
    for i in range(number_of_images):
        img=mpimg.imread(folder+images[i])
        plt.subplot(number_of_images//2, 2, i+1)
        plt.imshow(img)

visualize_image("023", 10)

# %%
X=[]
y=[]

for folder, _, imgs in os.walk(path):
    if folder!="face_age":
        for img in imgs:
            img_path=folder+'/'+img
            image=Image.open(img_path)
            image=image.convert('L') #gray-scale images
            X.append(np.array(image))
            y.append(int(folder[-3:]))

X=np.array(X)
y=np.array(y);

# %%
X=X.astype("float32")
#normalization
X /= 255.0
y = y//5 #dividing in range of 5

# %%
X = X.reshape(X.shape[0], 200, 200, 1)
X.shape
# Out:
# (19556, 200, 200, 1)

# %%
# os.mkdir("../dataset/Data")

# %%
# np.save("../dataset/face_age_data/X.npy", X)
# np.save("../dataset/face_age_data/y.npy", y)
# X = np.load('../dataset/face_age_data/X.npy')
# y = np.load('../dataset/face_age_data/y.npy')

# %% [markdown]
# ## Train, Test and Validation Datasets

# %%
# Train, validation and testing split (70/15/15)

test_size = 0.3
seed = 42
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=seed, shuffle=True, stratify=y)
# X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size=0.5)

# %%
# save to files
# np.save('../dataset/face_age_data/X_train.npy', X_train)
# np.save('../dataset/face_age_data/y_train.npy', y_train)
# np.save('../dataset/face_age_data/X_val.npy', X_val)
# np.save('../dataset/face_age_data/y_val.npy', y_val)
# np.save('../dataset/face_age_data/X_test.npy', X_test)
# np.save('../dataset/face_age_data/y_test.npy', y_test)

# X_train = np.load('../dataset/face_age_data/X_train.npy')
# y_train = np.load('../dataset/face_age_data/y_train.npy')
# X_val = np.load('../dataset/face_age_data/X_val.npy')
# y_val = np.load('../dataset/face_age_data/y_val.npy')
# X_test = np.load('../dataset/face_age_data/X_test.npy')
# y_test = np.load('../dataset/face_age_data/y_test.npy')

# %%
# confirm the saved files
# os.listdir("../face_age_dataset/Data")

# %% [markdown]
# ## Image Augmentation

# %%
# Apply Image Augmentation

train_datagen = ImageDataGenerator(
    shear_range = 0.2, # random application of shearing
    zoom_range = 0.2, 
    horizontal_flip = True) # randomly flipping half of the images horizontally

test_datagen = ImageDataGenerator()

# %% [markdown]
# ## Callbacks and Default Hyperparameters

# %%
from keras.callbacks import Callback, ReduceLROnPlateau, EarlyStopping
from timeit import default_timer as timer

class TimingCallback(Callback):
    def __init__(self, logs={}):
        self.logs=[]
    def on_epoch_begin(self, epoch, logs={}):
        self.starttime = timer()
    def on_epoch_end(self, epoch, logs={}):
        self.logs.append(timer()-self.starttime)

early_stopping = EarlyStopping(
                                patience=5, # wait for 5 epochs
                                min_delta = 0.01, # if in 5 epochs the loss function doesn't increase (for accuracy) 
                                               # or decrease (for val_loss) by 1%, then stop
                                verbose=1, # print the training epoch on which training was stopped
                                mode = 'min',
                                monitor='val_loss')

reduce_learning_rate = ReduceLROnPlateau(
                                    monitor="val_loss",
                                    patience=3, # if val_loss plateaus for 3 epochs such that it doesn't see 
                                                # an improvement of size = epsilon
                                    episilon= 0.01,
                                    factor=0.1,  # then we reduce the learning rate by a factor of 0.1
                                    cooldown = 4, # and we wait for 4 epochs before we restart again
                                    verbose=1)

time_callback = TimingCallback()

        
# hyperparameters
lr = 0.01
epochs = 50
batch_size = 128
results = {}
input_shape =[200, 200]

# %% [markdown]
# ## Simple CNN Model
#
# * A simple CNN model with 6 layers:
# Input - Conv - MaxPool - Dropout - Flatten - Output

# %%
def baseline_model():
    model = Sequential()
    model.add(Conv2D(filters=32,kernel_size=(3,3),activation="relu",
                   padding="valid",
                   input_shape=(input_shape[0], input_shape[1], 1)))
    model.add(MaxPooling2D(pool_size=2, strides=2, padding='valid'))
    model.add(Dropout(0.2))
    model.add(Flatten())
    model.add(Dense(1,activation="relu")) 
    return model

# %%
filepath = './cnn_face-age__relu-relu.epoch{epoch:02d}-loss{val_loss:.2f}.hdf5'
checkpoint = ModelCheckpoint(filepath, monitor="val_loss", save_best_only=True, mode="min", verbose=1)

# %%
# Adam= keras.optimizers.Adam(learning_rate=0.01,beta_1=0.9, beta_2=0.999, decay=0.0)

# %%
model = baseline_model()
model.compile(optimizer="adam", loss="mse", metrics=['mae'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 198, 198, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 99, 99, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 99, 99, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 313632)            0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 313633
# =================================================================
# Total params: 313,953
# Trainable params: 313,953
# Non-trainable params: 0
# _________________________________________________________________
# User settings:
#
#    KMP_AFFINITY=granularity=fine,verbose,compact,1,0
#    KMP_BLOCKTIME=0
#    KMP_DUPLICATE_LIB_OK=True
#    KMP_INIT_AT_FORK=FALSE
#    KMP_SETTINGS=1
#    KMP_WARNINGS=0
#
# Effective settings:
#
#    KMP_ABORT_DELAY=0
#    KMP_ADAPTIVE_LOCK_PROPS='1,1024'
#    KMP_ALIGN_ALLOC=64
#    KMP_ALL_THREADPRIVATE=128
#    KMP_ATOMIC_MODE=2
#    KMP_BLOCKTIME=0
#    KMP_CPUINFO_FILE: value is not defined
#    KMP_DETERMINISTIC_REDUCTION=false
#    KMP_DEVICE_THREAD_LIMIT=2147483647
#    KMP_DISP_NUM_BUFFERS=7
#    KMP_DUPLICATE_LIB_OK=true
#    KMP_ENABLE_TASK_THROTTLING=true
#    KMP_FORCE_REDUCTION: value is not defined
#    KMP_FOREIGN_THREADS_THREADPRIVATE=true
#    KMP_FORKJOIN_BARRIER='2,2'
#    KMP_FORKJOIN_BARRIER_PATTERN='hyper,hyper'
#    KMP_GTID_MODE=3
#    KMP_HANDLE_SIGNALS=false
#    KMP_HOT_TEAMS_MAX_LEVEL=1
#    KMP_HOT_TEAMS_MODE=0
#    KMP_INIT_AT_FORK=true
#    KMP_LIBRARY=throughput
#    KMP_LOCK_KIND=queuing
#    KMP_MALLOC_POOL_INCR=1M
#    KMP_NUM_LOCKS_IN_BLOCK=1
#    KMP_PLAIN_BARRIER='2,2'
#    KMP_PLAIN_BARRIER_PATTERN='hyper,hyper'
#    KMP_REDUCTION_BARRIER='1,1'
#    KMP_REDUCTION_BARRIER_PATTERN='hyper,hyper'
#    KMP_SCHEDULE='static,balanced;guided,iterative'
#    KMP_SETTINGS=true
#    KMP_SPIN_BACKOFF_PARAMS='4096,100'
#    KMP_STACKOFFSET=64
#    KMP_STACKPAD=0
#    KMP_STACKSIZE=8M
#    KMP_STORAGE_MAP=false
#    KMP_TASKING=2
#    KMP_TASKLOOP_MIN_TASKS=0
#    KMP_TASK_STEALING_CONSTRAINT=1
#    KMP_TEAMS_THREAD_LIMIT=4
#    KMP_TOPOLOGY_METHOD=all
#    KMP_USE_YIELD=1
#    KMP_VERSION=false
#    KMP_WARNINGS=false
#    OMP_AFFINITY_FORMAT='OMP: pid %P tid %i thread %n bound to OS proc set {%A}'
#    OMP_ALLOCATOR=omp_default_mem_alloc
#    OMP_CANCELLATION=false
#    OMP_DEFAULT_DEVICE=0
#    OMP_DISPLAY_AFFINITY=false
#    OMP_DISPLAY_ENV=false
#    OMP_DYNAMIC=false
#    OMP_MAX_ACTIVE_LEVELS=1
#    OMP_MAX_TASK_PRIORITY=0
#    OMP_NESTED: deprecated; max-active-levels-var=1
#    OMP_NUM_THREADS: value is not defined
#    OMP_PLACES: value is not defined
#    OMP_PROC_BIND='intel'
#    OMP_SCHEDULE='static'
#    OMP_STACKSIZE=8M
#    OMP_TARGET_OFFLOAD=DEFAULT
#    OMP_THREAD_LIMIT=2147483647
#    OMP_WAIT_POLICY=PASSIVE
#    KMP_AFFINITY='verbose,warnings,respect,granularity=fine,compact,1,0'
#
# 2021-11-29 05:53:25.225756: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='./cnn_facial_age-relu-relu.png')

# %%
model.fit(
    train_datagen.flow(
        X_train, y_train,
        batch_size = batch_size
    ), # use augmented images
    validation_data = (X_test, y_test),
    steps_per_epoch=X_train.shape[0] // batch_size,
    epochs = epochs,
    callbacks = [
                    reduce_learning_rate,
                    early_stopping,
                    time_callback,
                    checkpoint
                ],
    verbose=True)
# Out:
# 2021-11-29 05:53:26.851360: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/50
# 106/106 [==============================] - 98s 909ms/step - loss: 21.3067 - mae: 3.7100 - val_loss: 13.1481 - val_mae: 2.9884
#
# Epoch 00001: val_loss improved from inf to 13.14814, saving model to ./cnn_face-age__relu-relu.epoch01-loss13.15.hdf5
# Epoch 2/50
# 106/106 [==============================] - 97s 908ms/step - loss: 13.5466 - mae: 2.8432 - val_loss: 10.7921 - val_mae: 2.6057
#
# Epoch 00002: val_loss improved from 13.14814 to 10.79210, saving model to ./cnn_face-age__relu-relu.epoch02-loss10.79.hdf5
# Epoch 3/50
# 106/106 [==============================] - 96s 907ms/step - loss: 11.7685 - mae: 2.6065 - val_loss: 9.2215 - val_mae: 2.2557
#
# Epoch 00003: val_loss improved from 10.79210 to 9.22154, saving model to ./cnn_face-age__relu-relu.epoch03-loss9.22.hdf5
# Epoch 4/50
# 106/106 [==============================] - 96s 906ms/step - loss: 11.5817 - mae: 2.5581 - val_loss: 9.9978 - val_mae: 2.4840
#
# Epoch 00004: val_loss did not improve from 9.22154
# Epoch 5/50
# 106/106 [==============================] - 97s 909ms/step - loss: 10.7912 - mae: 2.4606 - val_loss: 8.7949 - val_mae: 2.0892
#
# Epoch 00005: val_loss improved from 9.22154 to 8.79487, saving model to ./cnn_face-age__relu-relu.epoch05-loss8.79.hdf5
# Epoch 6/50
# 106/106 [==============================] - 97s 910ms/step - loss: 9.8001 - mae: 2.3350 - val_loss: 8.5523 - val_mae: 2.0317
#
# Epoch 00006: val_loss improved from 8.79487 to 8.55228, saving model to ./cnn_face-age__relu-relu.epoch06-loss8.55.hdf5
# Epoch 7/50
# 106/106 [==============================] - 97s 908ms/step - loss: 9.3874 - mae: 2.2544 - val_loss: 8.0352 - val_mae: 2.1013
#
# Epoch 00007: val_loss improved from 8.55228 to 8.03518, saving model to ./cnn_face-age__relu-relu.epoch07-loss8.04.hdf5
# Epoch 8/50
# 106/106 [==============================] - 97s 911ms/step - loss: 9.3462 - mae: 2.2542 - val_loss: 7.3599 - val_mae: 1.9952
#
# Epoch 00008: val_loss improved from 8.03518 to 7.35994, saving model to ./cnn_face-age__relu-relu.epoch08-loss7.36.hdf5
# Epoch 9/50
# 106/106 [==============================] - 98s 917ms/step - loss: 9.0205 - mae: 2.2056 - val_loss: 9.0615 - val_mae: 2.0403
#
# Epoch 00009: val_loss did not improve from 7.35994
# Epoch 10/50
# 106/106 [==============================] - 97s 913ms/step - loss: 8.7193 - mae: 2.1604 - val_loss: 7.6272 - val_mae: 2.0847
#
# Epoch 00010: val_loss did not improve from 7.35994
# Epoch 11/50
# 106/106 [==============================] - 97s 909ms/step - loss: 8.5210 - mae: 2.1295 - val_loss: 7.0801 - val_mae: 1.9568
#
# Epoch 00011: val_loss improved from 7.35994 to 7.08009, saving model to ./cnn_face-age__relu-relu.epoch11-loss7.08.hdf5
# Epoch 12/50
# 106/106 [==============================] - 97s 913ms/step - loss: 8.3936 - mae: 2.1093 - val_loss: 6.6266 - val_mae: 1.8323
#
# Epoch 00012: val_loss improved from 7.08009 to 6.62662, saving model to ./cnn_face-age__relu-relu.epoch12-loss6.63.hdf5
# Epoch 13/50
# 106/106 [==============================] - 97s 907ms/step - loss: 8.0028 - mae: 2.0553 - val_loss: 7.1106 - val_mae: 1.9752
#
# Epoch 00013: val_loss did not improve from 6.62662
# Epoch 14/50
# 106/106 [==============================] - 97s 910ms/step - loss: 8.3109 - mae: 2.1013 - val_loss: 6.5472 - val_mae: 1.8100
#
# Epoch 00014: val_loss improved from 6.62662 to 6.54716, saving model to ./cnn_face-age__relu-relu.epoch14-loss6.55.hdf5
# Epoch 15/50
# 106/106 [==============================] - 96s 905ms/step - loss: 7.7013 - mae: 2.0139 - val_loss: 8.3430 - val_mae: 1.9961
#
# Epoch 00015: val_loss did not improve from 6.54716
# Epoch 16/50
# 106/106 [==============================] - 97s 908ms/step - loss: 7.9716 - mae: 2.0535 - val_loss: 6.3458 - val_mae: 1.7961
#
# Epoch 00016: val_loss improved from 6.54716 to 6.34579, saving model to ./cnn_face-age__relu-relu.epoch16-loss6.35.hdf5
# Epoch 17/50
# 106/106 [==============================] - 96s 905ms/step - loss: 7.4607 - mae: 1.9731 - val_loss: 6.2287 - val_mae: 1.7993
#
# Epoch 00017: val_loss improved from 6.34579 to 6.22869, saving model to ./cnn_face-age__relu-relu.epoch17-loss6.23.hdf5
# Epoch 18/50
# 106/106 [==============================] - 97s 908ms/step - loss: 7.3880 - mae: 1.9635 - val_loss: 6.2060 - val_mae: 1.7595
#
# Epoch 00018: val_loss improved from 6.22869 to 6.20603, saving model to ./cnn_face-age__relu-relu.epoch18-loss6.21.hdf5
# Epoch 19/50
# 106/106 [==============================] - 97s 910ms/step - loss: 7.2967 - mae: 1.9532 - val_loss: 6.1492 - val_mae: 1.7977
#
# Epoch 00019: val_loss improved from 6.20603 to 6.14916, saving model to ./cnn_face-age__relu-relu.epoch19-loss6.15.hdf5
# Epoch 20/50
# 106/106 [==============================] - 97s 910ms/step - loss: 7.2836 - mae: 1.9506 - val_loss: 6.7369 - val_mae: 1.9342
#
# Epoch 00020: val_loss did not improve from 6.14916
# Epoch 21/50
# 106/106 [==============================] - 97s 910ms/step - loss: 7.1522 - mae: 1.9322 - val_loss: 6.6257 - val_mae: 1.7661
#
# Epoch 00021: val_loss did not improve from 6.14916
# Epoch 22/50
# 106/106 [==============================] - 97s 911ms/step - loss: 7.3184 - mae: 1.9526 - val_loss: 6.0678 - val_mae: 1.7824
#
# Epoch 00022: val_loss improved from 6.14916 to 6.06781, saving model to ./cnn_face-age__relu-relu.epoch22-loss6.07.hdf5
# Epoch 23/50
# 106/106 [==============================] - 97s 908ms/step - loss: 6.9575 - mae: 1.9013 - val_loss: 5.9937 - val_mae: 1.7817
#
# Epoch 00023: val_loss improved from 6.06781 to 5.99373, saving model to ./cnn_face-age__relu-relu.epoch23-loss5.99.hdf5
# Epoch 24/50
# 106/106 [==============================] - 97s 909ms/step - loss: 6.8805 - mae: 1.8914 - val_loss: 5.9098 - val_mae: 1.7352
#
# Epoch 00024: val_loss improved from 5.99373 to 5.90979, saving model to ./cnn_face-age__relu-relu.epoch24-loss5.91.hdf5
# Epoch 25/50
# 106/106 [==============================] - 97s 908ms/step - loss: 6.8528 - mae: 1.8865 - val_loss: 5.7462 - val_mae: 1.7050
#
# Epoch 00025: val_loss improved from 5.90979 to 5.74615, saving model to ./cnn_face-age__relu-relu.epoch25-loss5.75.hdf5
# Epoch 26/50
# 106/106 [==============================] - 97s 910ms/step - loss: 6.7622 - mae: 1.8718 - val_loss: 5.9977 - val_mae: 1.6982
#
# Epoch 00026: val_loss did not improve from 5.74615
# Epoch 27/50
# 106/106 [==============================] - 97s 908ms/step - loss: 6.8695 - mae: 1.8807 - val_loss: 6.4597 - val_mae: 1.7595
#
# Epoch 00027: val_loss did not improve from 5.74615
# Epoch 28/50
# 106/106 [==============================] - 96s 906ms/step - loss: 6.7351 - mae: 1.8625 - val_loss: 5.7601 - val_mae: 1.7158
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00028: val_loss did not improve from 5.74615
# Epoch 29/50
# 106/106 [==============================] - 97s 909ms/step - loss: 6.3409 - mae: 1.8100 - val_loss: 5.5663 - val_mae: 1.6680
#
# Epoch 00029: val_loss improved from 5.74615 to 5.56626, saving model to ./cnn_face-age__relu-relu.epoch29-loss5.57.hdf5
# Epoch 30/50
# 106/106 [==============================] - 97s 913ms/step - loss: 6.1998 - mae: 1.7822 - val_loss: 5.6866 - val_mae: 1.7181
#
# Epoch 00030: val_loss did not improve from 5.56626
# Epoch 31/50
# 106/106 [==============================] - 97s 909ms/step - loss: 6.0698 - mae: 1.7688 - val_loss: 5.5115 - val_mae: 1.6679
#
# Epoch 00031: val_loss improved from 5.56626 to 5.51149, saving model to ./cnn_face-age__relu-relu.epoch31-loss5.51.hdf5
# Epoch 32/50
# 106/106 [==============================] - 98s 919ms/step - loss: 6.2053 - mae: 1.7801 - val_loss: 5.5989 - val_mae: 1.6917
#
# Epoch 00032: val_loss did not improve from 5.51149
# Epoch 33/50
# 106/106 [==============================] - 97s 910ms/step - loss: 6.2064 - mae: 1.7912 - val_loss: 5.5176 - val_mae: 1.6707
#
# Epoch 00033: val_loss did not improve from 5.51149
# Epoch 34/50
# 106/106 [==============================] - 97s 909ms/step - loss: 6.1435 - mae: 1.7786 - val_loss: 5.4977 - val_mae: 1.6451
#
# Epoch 00034: val_loss improved from 5.51149 to 5.49774, saving model to ./cnn_face-age__relu-relu.epoch34-loss5.50.hdf5
# Epoch 35/50
# 106/106 [==============================] - 98s 919ms/step - loss: 6.1178 - mae: 1.7706 - val_loss: 5.4416 - val_mae: 1.6453
#
# Epoch 00035: val_loss improved from 5.49774 to 5.44160, saving model to ./cnn_face-age__relu-relu.epoch35-loss5.44.hdf5
# Epoch 36/50
# 106/106 [==============================] - 98s 924ms/step - loss: 6.0969 - mae: 1.7707 - val_loss: 5.5626 - val_mae: 1.6947
#
# Epoch 00036: val_loss did not improve from 5.44160
# Epoch 37/50
# 106/106 [==============================] - 98s 923ms/step - loss: 6.0357 - mae: 1.7599 - val_loss: 5.4808 - val_mae: 1.6802
#
# Epoch 00037: val_loss did not improve from 5.44160
# Epoch 38/50
# 106/106 [==============================] - 97s 916ms/step - loss: 6.1964 - mae: 1.7822 - val_loss: 5.4574 - val_mae: 1.6470
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00038: val_loss did not improve from 5.44160
# Epoch 39/50
# 106/106 [==============================] - 96s 907ms/step - loss: 6.1047 - mae: 1.7637 - val_loss: 5.4343 - val_mae: 1.6531
#
# Epoch 00039: val_loss improved from 5.44160 to 5.43432, saving model to ./cnn_face-age__relu-relu.epoch39-loss5.43.hdf5
# Epoch 40/50
# 106/106 [==============================] - 97s 909ms/step - loss: 5.9829 - mae: 1.7493 - val_loss: 5.4319 - val_mae: 1.6536
#
# Epoch 00040: val_loss improved from 5.43432 to 5.43194, saving model to ./cnn_face-age__relu-relu.epoch40-loss5.43.hdf5
# Epoch 00040: early stopping

# %%
baseline_adam_train_loss = model.history.history["loss"]
baseline_adam_val_loss = model.history.history["val_loss"]
baseline_adam_train_acc = model.history.history["mae"]
baseline_adam_val_acc = model.history.history["val_mae"]

results["baseline_adam"] = {'train-loss': baseline_adam_train_loss,
                             'val-loss': baseline_adam_val_loss,
                             'train-mae': baseline_adam_train_acc,
                             'val-mae': baseline_adam_val_acc}

# %% [markdown]
# ## Performance Visualization

# %%
plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-mae'])),results[cond]['train-mae'], '-', label=cond+"_train", color="blue")
    plt.plot(range(len(results[cond]['val-mae'])),results[cond]['val-mae'], '-', label=cond+"_val", color="green")
plt.title("Mean Absolute Error")
plt.xlabel("Epochs")
plt.legend()
plt.show()

# %% [markdown]
# ## Results on Test Set

# %%
model_test_results = model.evaluate(X_test, y_test, batch_size=128)
dict(zip(model.metrics_names, model_test_results))
# Out:
# 46/46 [==============================] - 4s 87ms/step - loss: 5.4319 - mae: 1.6536
# {'loss': 5.431942462921143, 'mae': 1.6536333560943604}

# %%
y_pred = model.predict(X).reshape(-1)

# %% [markdown]
# ## Performance in Age Range of 5

# %%
y_pred_range=np.round((y_pred), 0).astype(int)
float(100*sum(np.equal(y, y_pred_range).astype(int))/len(y_pred_range))
# Out:
# 29.085702597668234

# %%
pd.Series((5 * y_pred_range.reshape((len(y_pred))))).plot(kind='hist', bins=40, label='Predicted', alpha=0.5)
pd.Series((5 * y)).plot(kind='hist', bins=40, label='Original', alpha=0.5)

plt.legend(title='Group')

plt.ylabel('Frequency', fontsize=14)
plt.xlabel('Age', fontsize=14)
plt.title('Predicted vs Original', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Predicted vs Original')

# %%
import seaborn as sns
sns.heatmap(confusion_matrix(y, y_pred_range))
# Out:
# <AxesSubplot:>

# %%
print(classification_report(y, y_pred_range))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.76      0.77      4262
#            1       0.27      0.17      0.20      1630
#            2       0.16      0.16      0.16      1042
#            3       0.16      0.13      0.14      1394
#            4       0.18      0.20      0.19      1322
#            5       0.22      0.20      0.21      1712
#            6       0.13      0.21      0.16       960
#            7       0.17      0.23      0.20      1108
#            8       0.09      0.20      0.12       608
#            9       0.11      0.17      0.13       742
#           10       0.17      0.15      0.16      1078
#           11       0.15      0.15      0.15       798
#           12       0.13      0.11      0.12       678
#           13       0.13      0.09      0.11       634
#           14       0.10      0.07      0.08       384
#           15       0.20      0.12      0.15       374
#           16       0.09      0.05      0.07       256
#           17       0.28      0.07      0.11       378
#           18       0.07      0.04      0.05       144
#           19       0.09      0.10      0.09        42
#           20       0.00      0.00      0.00         6
#           21       0.00      0.00      0.00         0
#           22       0.00      0.00      0.00         4
#           23       0.00      0.00      0.00         0
#           24       0.00      0.00      0.00         0
#           25       0.00      0.00      0.00         0
#           26       0.00      0.00      0.00         0
#
#     accuracy                           0.29     19556
#    macro avg       0.14      0.13      0.13     19556
# weighted avg       0.31      0.29      0.29     19556
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
