# %% [markdown]
# ## Importing and Processing Data

# %%
import pandas as pd
import numpy as np

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

from tensorflow import keras
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import InputLayer, Conv2D, MaxPooling2D,GlobalAveragePooling2D,Dropout, Flatten, Dense
from keras import regularizers
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

from PIL import Image
import os

# %%
path="../input/facial-age/face_age/"

# %%
# Visualization of images

def visualize_image(age, number_of_images):
    plt.figure(figsize=(10, 10))
    folder=path+age+'/'
    images=os.listdir(folder)[:number_of_images]
    for i in range(number_of_images):
        img=mpimg.imread(folder+images[i])
        plt.subplot(number_of_images//2, 2, i+1)
        plt.imshow(img)

visualize_image("023", 10)

# %%
X=[]
y=[]
width=200
height=200
for folder, _, imgs in os.walk(path):
    if folder!="face_age":
        for img in imgs:
            img_path=folder+'/'+img
            image=Image.open(img_path)
            image=image.convert('L') #gray-scale images
            image=image.resize((width, height))
            X.append(np.array(image))
            y.append(int(folder[-3:]))

X=np.array(X)
y=np.array(y);

# %%
X=X.astype("float32")
#normalization
X /= 255.0
y = y//5 #dividing in range of 5

# %%
X = X.reshape(X.shape[0], width, height, 1)
X.shape
# Out:
# (19556, 200, 200, 1)

# %%
pd.DataFrame(y)[0].unique()
# Out:
# array([11, 17, 12,  9, 10, 19,  3,  8,  1,  2,  5, 15,  0, 16, 18,  7, 14,
#        13, 20,  6,  4, 22])

# %%
y = to_categorical(y, num_classes=23)

# %%
# os.mkdir("../dataset/Data")

# %%
# np.save("../dataset/face_age_data/X.npy", X)
# np.save("../dataset/face_age_data/y.npy", y)
# X = np.load('../dataset/face_age_data/X.npy')
# y = np.load('../dataset/face_age_data/y.npy')

# %% [markdown]
# ## Train, Test and Validation Datasets

# %%
# Train, validation and testing split (70/15/15)

test_size = 0.2
seed = 42
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=seed, shuffle=True, stratify=y)
# X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size=0.5)

# %%
# save to files
# np.save('../dataset/face_age_data/X_train.npy', X_train)
# np.save('../dataset/face_age_data/y_train.npy', y_train)
# np.save('../dataset/face_age_data/X_val.npy', X_val)
# np.save('../dataset/face_age_data/y_val.npy', y_val)
# np.save('../dataset/face_age_data/X_test.npy', X_test)
# np.save('../dataset/face_age_data/y_test.npy', y_test)

# X_train = np.load('../dataset/face_age_data/X_train.npy')
# y_train = np.load('../dataset/face_age_data/y_train.npy')
# X_val = np.load('../dataset/face_age_data/X_val.npy')
# y_val = np.load('../dataset/face_age_data/y_val.npy')
# X_test = np.load('../dataset/face_age_data/X_test.npy')
# y_test = np.load('../dataset/face_age_data/y_test.npy')

# %%
# confirm the saved files
# os.listdir("../face_age_dataset/Data")

# %% [markdown]
# ## Image Augmentation

# %%
# Apply Image Augmentation

train_datagen = ImageDataGenerator(
    shear_range = 0.2, # random application of shearing
    zoom_range = 0.2, 
    horizontal_flip = True) # randomly flipping half of the images horizontally

test_datagen = ImageDataGenerator()

# %% [markdown]
# ## Callbacks and Default Hyperparameters

# %%
from keras.callbacks import Callback, ReduceLROnPlateau, EarlyStopping
from timeit import default_timer as timer

class TimingCallback(Callback):
    def __init__(self, logs={}):
        self.logs=[]
    def on_epoch_begin(self, epoch, logs={}):
        self.starttime = timer()
    def on_epoch_end(self, epoch, logs={}):
        self.logs.append(timer()-self.starttime)

early_stopping = EarlyStopping(
                                patience=5, # wait for 5 epochs
                                min_delta = 0.01, # if in 5 epochs the loss function doesn't increase (for accuracy) 
                                               # or decrease (for val_loss) by 1%, then stop
                                verbose=1, # print the training epoch on which training was stopped
                                mode = 'min',
                                monitor='val_loss')

reduce_learning_rate = ReduceLROnPlateau(
                                    monitor="val_loss",
                                    patience=3, # if val_loss plateaus for 3 epochs such that it doesn't see 
                                                # an improvement of size = epsilon
                                    episilon= 0.01,
                                    factor=0.1,  # then we reduce the learning rate by a factor of 0.1
                                    cooldown = 4, # and we wait for 4 epochs before we restart again
                                    verbose=1)

time_callback = TimingCallback()

        
# hyperparameters
lr = 0.01
epochs = 100
batch_size = 128
results = {}
input_shape =[width, height]

# %% [markdown]
# ## CNN Model

# %%
def baseline_model():
    model = Sequential()

    model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(200, 200, 1)))
    model.add(MaxPooling2D((2, 2)))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Conv2D(32, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2, 2)))

    model.add(Flatten())

    model.add(Dense(32, activation='relu'))
    model.add(Dense(23, activation='softmax'))
    return model

# %%
filepath = './cnn_face-age__relu-softmax_AgeRange-5.epoch{epoch:02d}-loss{val_loss:.2f}.hdf5'
checkpoint = ModelCheckpoint(filepath, monitor="val_loss", save_best_only=True, mode="min", verbose=1)

# %%
# Adam= keras.optimizers.Adam(learning_rate=0.01,beta_1=0.9, beta_2=0.999, decay=0.0)

# %%
model = baseline_model()
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy", "mae"])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 198, 198, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 99, 99, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 97, 97, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 48, 48, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 46, 46, 32)        18464
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 23, 23, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 16928)             0
# _________________________________________________________________
# dense (Dense)                (None, 32)                541728
# _________________________________________________________________
# dense_1 (Dense)              (None, 23)                759
# =================================================================
# Total params: 579,767
# Trainable params: 579,767
# Non-trainable params: 0
# _________________________________________________________________
# User settings:
#
#    KMP_AFFINITY=granularity=fine,verbose,compact,1,0
#    KMP_BLOCKTIME=0
#    KMP_DUPLICATE_LIB_OK=True
#    KMP_INIT_AT_FORK=FALSE
#    KMP_SETTINGS=1
#    KMP_WARNINGS=0
#
# Effective settings:
#
#    KMP_ABORT_DELAY=0
#    KMP_ADAPTIVE_LOCK_PROPS='1,1024'
#    KMP_ALIGN_ALLOC=64
#    KMP_ALL_THREADPRIVATE=128
#    KMP_ATOMIC_MODE=2
#    KMP_BLOCKTIME=0
#    KMP_CPUINFO_FILE: value is not defined
#    KMP_DETERMINISTIC_REDUCTION=false
#    KMP_DEVICE_THREAD_LIMIT=2147483647
#    KMP_DISP_NUM_BUFFERS=7
#    KMP_DUPLICATE_LIB_OK=true
#    KMP_ENABLE_TASK_THROTTLING=true
#    KMP_FORCE_REDUCTION: value is not defined
#    KMP_FOREIGN_THREADS_THREADPRIVATE=true
#    KMP_FORKJOIN_BARRIER='2,2'
#    KMP_FORKJOIN_BARRIER_PATTERN='hyper,hyper'
#    KMP_GTID_MODE=3
#    KMP_HANDLE_SIGNALS=false
#    KMP_HOT_TEAMS_MAX_LEVEL=1
#    KMP_HOT_TEAMS_MODE=0
#    KMP_INIT_AT_FORK=true
#    KMP_LIBRARY=throughput
#    KMP_LOCK_KIND=queuing
#    KMP_MALLOC_POOL_INCR=1M
#    KMP_NUM_LOCKS_IN_BLOCK=1
#    KMP_PLAIN_BARRIER='2,2'
#    KMP_PLAIN_BARRIER_PATTERN='hyper,hyper'
#    KMP_REDUCTION_BARRIER='1,1'
#    KMP_REDUCTION_BARRIER_PATTERN='hyper,hyper'
#    KMP_SCHEDULE='static,balanced;guided,iterative'
#    KMP_SETTINGS=true
#    KMP_SPIN_BACKOFF_PARAMS='4096,100'
#    KMP_STACKOFFSET=64
#    KMP_STACKPAD=0
#    KMP_STACKSIZE=8M
#    KMP_STORAGE_MAP=false
#    KMP_TASKING=2
#    KMP_TASKLOOP_MIN_TASKS=0
#    KMP_TASK_STEALING_CONSTRAINT=1
#    KMP_TEAMS_THREAD_LIMIT=4
#    KMP_TOPOLOGY_METHOD=all
#    KMP_USE_YIELD=1
#    KMP_VERSION=false
#    KMP_WARNINGS=false
#    OMP_AFFINITY_FORMAT='OMP: pid %P tid %i thread %n bound to OS proc set {%A}'
#    OMP_ALLOCATOR=omp_default_mem_alloc
#    OMP_CANCELLATION=false
#    OMP_DEFAULT_DEVICE=0
#    OMP_DISPLAY_AFFINITY=false
#    OMP_DISPLAY_ENV=false
#    OMP_DYNAMIC=false
#    OMP_MAX_ACTIVE_LEVELS=1
#    OMP_MAX_TASK_PRIORITY=0
#    OMP_NESTED: deprecated; max-active-levels-var=1
#    OMP_NUM_THREADS: value is not defined
#    OMP_PLACES: value is not defined
#    OMP_PROC_BIND='intel'
#    OMP_SCHEDULE='static'
#    OMP_STACKSIZE=8M
#    OMP_TARGET_OFFLOAD=DEFAULT
#    OMP_THREAD_LIMIT=2147483647
#    OMP_WAIT_POLICY=PASSIVE
#    KMP_AFFINITY='verbose,warnings,respect,granularity=fine,compact,1,0'
#
# 2021-11-30 02:33:37.989811: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='./cnn_facial_age-relu-softmax_AgeRange-5.png')

# %%
model.fit(
    train_datagen.flow(
        X_train, y_train,
        batch_size = batch_size
    ), # use augmented images
    validation_data = (X_test, y_test),
    steps_per_epoch=X_train.shape[0] // batch_size,
    epochs = epochs,
    callbacks = [
                    reduce_learning_rate,
                    early_stopping,
                    time_callback,
                    checkpoint
                ],
    verbose=True)
# Out:
# 2021-11-30 02:33:39.648443: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 122/122 [==============================] - 308s 3s/step - loss: 2.6402 - accuracy: 0.1997 - mae: 0.0757 - val_loss: 2.2503 - val_accuracy: 0.2868 - val_mae: 0.0677
#
# Epoch 00001: val_loss improved from inf to 2.25033, saving model to ./cnn_face-age__relu-softmax_AgeRange-5.epoch01-loss2.25.hdf5
# Epoch 2/100
# 122/122 [==============================] - 307s 3s/step - loss: 2.1977 - accuracy: 0.2999 - mae: 0.0672 - val_loss: 2.0665 - val_accuracy: 0.3234 - val_mae: 0.0653
#
# Epoch 00002: val_loss improved from 2.25033 to 2.06655, saving model to ./cnn_face-age__relu-softmax_AgeRange-5.epoch02-loss2.07.hdf5
# Epoch 3/100
# 122/122 [==============================] - 306s 3s/step - loss: 2.0482 - accuracy: 0.3375 - mae: 0.0647 - val_loss: 1.9985 - val_accuracy: 0.3392 - val_mae: 0.0633
#
# Epoch 00003: val_loss improved from 2.06655 to 1.99852, saving model to ./cnn_face-age__relu-softmax_AgeRange-5.epoch03-loss2.00.hdf5
# Epoch 4/100
# 122/122 [==============================] - 306s 3s/step - loss: 1.9486 - accuracy: 0.3542 - mae: 0.0631 - val_loss: 1.8596 - val_accuracy: 0.3722 - val_mae: 0.0622
#
# Epoch 00004: val_loss improved from 1.99852 to 1.85956, saving model to ./cnn_face-age__relu-softmax_AgeRange-5.epoch04-loss1.86.hdf5
# Epoch 5/100
# 122/122 [==============================] - 310s 3s/step - loss: 1.8652 - accuracy: 0.3692 - mae: 0.0618 - val_loss: 1.7965 - val_accuracy: 0.3778 - val_mae: 0.0616
#
# Epoch 00005: val_loss improved from 1.85956 to 1.79651, saving model to ./cnn_face-age__relu-softmax_AgeRange-5.epoch05-loss1.80.hdf5
# Epoch 6/100
# 122/122 [==============================] - 308s 3s/step - loss: 1.7845 - accuracy: 0.3891 - mae: 0.0605 - val_loss: 1.7081 - val_accuracy: 0.3985 - val_mae: 0.0603
#
# Epoch 00006: val_loss improved from 1.79651 to 1.70815, saving model to ./cnn_face-age__relu-softmax_AgeRange-5.epoch06-loss1.71.hdf5
# Epoch 7/100
# 122/122 [==============================] - 305s 2s/step - loss: 1.7261 - accuracy: 0.3980 - mae: 0.0597 - val_loss: 1.6663 - val_accuracy: 0.4113 - val_mae: 0.0585
#
# Epoch 00007: val_loss improved from 1.70815 to 1.66628, saving model to ./cnn_face-age__relu-softmax_AgeRange-5.epoch07-loss1.67.hdf5
# Epoch 8/100
# 122/122 [==============================] - 311s 3s/step - loss: 1.6571 - accuracy: 0.4223 - mae: 0.0584 - val_loss: 1.6103 - val_accuracy: 0.4294 - val_mae: 0.0580
#
# Epoch 00008: val_loss improved from 1.66628 to 1.61025, saving model to ./cnn_face-age__relu-softmax_AgeRange-5.epoch08-loss1.61.hdf5
# Epoch 9/100
# 122/122 [==============================] - 310s 3s/step - loss: 1.6225 - accuracy: 0.4235 - mae: 0.0578 - val_loss: 1.5744 - val_accuracy: 0.4333 - val_mae: 0.0574
#
# Epoch 00009: val_loss improved from 1.61025 to 1.57444, saving model to ./cnn_face-age__relu-softmax_AgeRange-5.epoch09-loss1.57.hdf5
# Epoch 10/100
# 122/122 [==============================] - 309s 3s/step - loss: 1.5925 - accuracy: 0.4385 - mae: 0.0571 - val_loss: 1.5472 - val_accuracy: 0.4384 - val_mae: 0.0564
#
# Epoch 00010: val_loss improved from 1.57444 to 1.54718, saving model to ./cnn_face-age__relu-softmax_AgeRange-5.epoch10-loss1.55.hdf5
# Epoch 11/100
# 122/122 [==============================] - 306s 3s/step - loss: 1.5655 - accuracy: 0.4420 - mae: 0.0566 - val_loss: 1.5257 - val_accuracy: 0.4407 - val_mae: 0.0556
#
# Epoch 00011: val_loss improved from 1.54718 to 1.52566, saving model to ./cnn_face-age__relu-softmax_AgeRange-5.epoch11-loss1.53.hdf5
# Epoch 12/100
# 122/122 [==============================] - 306s 3s/step - loss: 1.5392 - accuracy: 0.4522 - mae: 0.0559 - val_loss: 1.4966 - val_accuracy: 0.4481 - val_mae: 0.0559
#
# Epoch 00012: val_loss improved from 1.52566 to 1.49663, saving model to ./cnn_face-age__relu-softmax_AgeRange-5.epoch12-loss1.50.hdf5
# Epoch 13/100
# 122/122 [==============================] - 306s 3s/step - loss: 1.5058 - accuracy: 0.4595 - mae: 0.0554 - val_loss: 1.4951 - val_accuracy: 0.4450 - val_mae: 0.0553
#
# Epoch 00013: val_loss improved from 1.49663 to 1.49510, saving model to ./cnn_face-age__relu-softmax_AgeRange-5.epoch13-loss1.50.hdf5
# Epoch 14/100
# 122/122 [==============================] - 305s 2s/step - loss: 1.4881 - accuracy: 0.4609 - mae: 0.0550 - val_loss: 1.4726 - val_accuracy: 0.4517 - val_mae: 0.0551
#
# Epoch 00014: val_loss improved from 1.49510 to 1.47256, saving model to ./cnn_face-age__relu-softmax_AgeRange-5.epoch14-loss1.47.hdf5
# Epoch 15/100
# 122/122 [==============================] - 306s 3s/step - loss: 1.4704 - accuracy: 0.4644 - mae: 0.0548 - val_loss: 1.4539 - val_accuracy: 0.4568 - val_mae: 0.0541
#
# Epoch 00015: val_loss improved from 1.47256 to 1.45386, saving model to ./cnn_face-age__relu-softmax_AgeRange-5.epoch15-loss1.45.hdf5
# Epoch 16/100
# 122/122 [==============================] - 309s 3s/step - loss: 1.4348 - accuracy: 0.4767 - mae: 0.0539 - val_loss: 1.4699 - val_accuracy: 0.4581 - val_mae: 0.0537
#
# Epoch 00016: val_loss did not improve from 1.45386
# Epoch 17/100
# 122/122 [==============================] - 306s 3s/step - loss: 1.4488 - accuracy: 0.4711 - mae: 0.0540 - val_loss: 1.4568 - val_accuracy: 0.4560 - val_mae: 0.0547
#
# Epoch 00017: val_loss did not improve from 1.45386
# Epoch 18/100
# 122/122 [==============================] - 306s 3s/step - loss: 1.4242 - accuracy: 0.4749 - mae: 0.0538 - val_loss: 1.4454 - val_accuracy: 0.4583 - val_mae: 0.0535
#
# Epoch 00018: val_loss improved from 1.45386 to 1.44538, saving model to ./cnn_face-age__relu-softmax_AgeRange-5.epoch18-loss1.45.hdf5
# Epoch 19/100
# 122/122 [==============================] - 307s 3s/step - loss: 1.4185 - accuracy: 0.4790 - mae: 0.0537 - val_loss: 1.4053 - val_accuracy: 0.4719 - val_mae: 0.0533
#
# Epoch 00019: val_loss improved from 1.44538 to 1.40528, saving model to ./cnn_face-age__relu-softmax_AgeRange-5.epoch19-loss1.41.hdf5
# Epoch 20/100
# 122/122 [==============================] - 307s 3s/step - loss: 1.4069 - accuracy: 0.4791 - mae: 0.0534 - val_loss: 1.4074 - val_accuracy: 0.4714 - val_mae: 0.0530
#
# Epoch 00020: val_loss did not improve from 1.40528
# Epoch 21/100
# 122/122 [==============================] - 307s 3s/step - loss: 1.3825 - accuracy: 0.4869 - mae: 0.0528 - val_loss: 1.3995 - val_accuracy: 0.4721 - val_mae: 0.0532
#
# Epoch 00021: val_loss improved from 1.40528 to 1.39954, saving model to ./cnn_face-age__relu-softmax_AgeRange-5.epoch21-loss1.40.hdf5
# Epoch 22/100
# 122/122 [==============================] - 307s 3s/step - loss: 1.3811 - accuracy: 0.4876 - mae: 0.0528 - val_loss: 1.3917 - val_accuracy: 0.4696 - val_mae: 0.0527
#
# Epoch 00022: val_loss improved from 1.39954 to 1.39169, saving model to ./cnn_face-age__relu-softmax_AgeRange-5.epoch22-loss1.39.hdf5
# Epoch 23/100
# 122/122 [==============================] - 308s 3s/step - loss: 1.3695 - accuracy: 0.4889 - mae: 0.0525 - val_loss: 1.3819 - val_accuracy: 0.4770 - val_mae: 0.0526
#
# Epoch 00023: val_loss improved from 1.39169 to 1.38193, saving model to ./cnn_face-age__relu-softmax_AgeRange-5.epoch23-loss1.38.hdf5
# Epoch 24/100
# 122/122 [==============================] - 306s 3s/step - loss: 1.3480 - accuracy: 0.4945 - mae: 0.0520 - val_loss: 1.3905 - val_accuracy: 0.4688 - val_mae: 0.0534
#
# Epoch 00024: val_loss did not improve from 1.38193
# Epoch 25/100
# 122/122 [==============================] - 308s 3s/step - loss: 1.3465 - accuracy: 0.4962 - mae: 0.0520 - val_loss: 1.3826 - val_accuracy: 0.4793 - val_mae: 0.0522
#
# Epoch 00025: val_loss did not improve from 1.38193
# Epoch 26/100
# 122/122 [==============================] - 310s 3s/step - loss: 1.3400 - accuracy: 0.4966 - mae: 0.0519 - val_loss: 1.3835 - val_accuracy: 0.4788 - val_mae: 0.0521
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00026: val_loss did not improve from 1.38193
# Epoch 27/100
# 122/122 [==============================] - 308s 3s/step - loss: 1.2898 - accuracy: 0.5121 - mae: 0.0510 - val_loss: 1.3394 - val_accuracy: 0.4931 - val_mae: 0.0516
#
# Epoch 00027: val_loss improved from 1.38193 to 1.33936, saving model to ./cnn_face-age__relu-softmax_AgeRange-5.epoch27-loss1.34.hdf5
# Epoch 28/100
# 122/122 [==============================] - 314s 3s/step - loss: 1.2818 - accuracy: 0.5169 - mae: 0.0507 - val_loss: 1.3371 - val_accuracy: 0.4921 - val_mae: 0.0513
#
# Epoch 00028: val_loss improved from 1.33936 to 1.33713, saving model to ./cnn_face-age__relu-softmax_AgeRange-5.epoch28-loss1.34.hdf5
# Epoch 29/100
# 122/122 [==============================] - 315s 3s/step - loss: 1.2724 - accuracy: 0.5192 - mae: 0.0505 - val_loss: 1.3317 - val_accuracy: 0.4941 - val_mae: 0.0513
#
# Epoch 00029: val_loss improved from 1.33713 to 1.33165, saving model to ./cnn_face-age__relu-softmax_AgeRange-5.epoch29-loss1.33.hdf5
# Epoch 30/100
# 122/122 [==============================] - 312s 3s/step - loss: 1.2713 - accuracy: 0.5167 - mae: 0.0504 - val_loss: 1.3358 - val_accuracy: 0.4949 - val_mae: 0.0513
#
# Epoch 00030: val_loss did not improve from 1.33165
# Epoch 31/100
# 122/122 [==============================] - 319s 3s/step - loss: 1.2716 - accuracy: 0.5237 - mae: 0.0503 - val_loss: 1.3273 - val_accuracy: 0.5000 - val_mae: 0.0512
#
# Epoch 00031: val_loss improved from 1.33165 to 1.32732, saving model to ./cnn_face-age__relu-softmax_AgeRange-5.epoch31-loss1.33.hdf5
# Epoch 32/100
# 122/122 [==============================] - 313s 3s/step - loss: 1.2633 - accuracy: 0.5250 - mae: 0.0502 - val_loss: 1.3245 - val_accuracy: 0.4985 - val_mae: 0.0510
#
# Epoch 00032: val_loss improved from 1.32732 to 1.32451, saving model to ./cnn_face-age__relu-softmax_AgeRange-5.epoch32-loss1.32.hdf5
# Epoch 33/100
# 122/122 [==============================] - 309s 3s/step - loss: 1.2616 - accuracy: 0.5266 - mae: 0.0501 - val_loss: 1.3258 - val_accuracy: 0.4992 - val_mae: 0.0510
#
# Epoch 00033: val_loss did not improve from 1.32451
# Epoch 34/100
# 122/122 [==============================] - 315s 3s/step - loss: 1.2616 - accuracy: 0.5218 - mae: 0.0501 - val_loss: 1.3300 - val_accuracy: 0.4969 - val_mae: 0.0510
#
# Epoch 00034: val_loss did not improve from 1.32451
# Epoch 35/100
# 122/122 [==============================] - 312s 3s/step - loss: 1.2584 - accuracy: 0.5263 - mae: 0.0501 - val_loss: 1.3259 - val_accuracy: 0.4967 - val_mae: 0.0509
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00035: val_loss did not improve from 1.32451
# Epoch 36/100
# 122/122 [==============================] - 314s 3s/step - loss: 1.2517 - accuracy: 0.5274 - mae: 0.0499 - val_loss: 1.3211 - val_accuracy: 0.5005 - val_mae: 0.0509
#
# Epoch 00036: val_loss improved from 1.32451 to 1.32111, saving model to ./cnn_face-age__relu-softmax_AgeRange-5.epoch36-loss1.32.hdf5
# Epoch 00036: early stopping

# %%
baseline_adam_train_loss = model.history.history["loss"]
baseline_adam_val_loss = model.history.history["val_loss"]
baseline_adam_train_acc = model.history.history["mae"]
baseline_adam_val_acc = model.history.history["val_mae"]

results["baseline_adam"] = {'train-loss': baseline_adam_train_loss,
                             'val-loss': baseline_adam_val_loss,
                             'train-mae': baseline_adam_train_acc,
                             'val-mae': baseline_adam_val_acc}

# %% [markdown]
# ## Performance Visualization

# %%
plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-mae'])),results[cond]['train-mae'], '-', label=cond+"_train", color="blue")
    plt.plot(range(len(results[cond]['val-mae'])),results[cond]['val-mae'], '-', label=cond+"_val", color="green")
plt.title("Mean Absolute Error")
plt.xlabel("Epochs")
plt.legend()
plt.show()

# %% [markdown]
# ## Results on Test Set

# %%
model_test_results = model.evaluate(X_test, y_test, batch_size=128)
dict(zip(model.metrics_names, model_test_results))
# Out:
# 31/31 [==============================] - 16s 502ms/step - loss: 1.3211 - accuracy: 0.5005 - mae: 0.0509
# {'loss': 1.321112036705017,
#  'accuracy': 0.5005112290382385,
#  'mae': 0.05089285969734192}

# %%
from tensorflow.math import argmax

# %%
y_pred = argmax(model.predict(X_test), axis=1)

# %% [markdown]
# ## Performance in Age Range of 5

# %%
pd.Series((y_pred)).plot(kind='hist', bins=40, label='Predicted', alpha=0.5)
pd.Series(argmax(y_test, axis = 1)).plot(kind='hist', bins=40, label='Original', alpha=0.5)

plt.legend(title='Group')

plt.ylabel('Frequency', fontsize=14)
plt.xlabel('Age', fontsize=14)
plt.title('Predicted vs Original', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Predicted vs Original')

# %%
import seaborn as sns
sns.heatmap(confusion_matrix(argmax(y_test, axis = 1), y_pred))
# Out:
# <AxesSubplot:>

# %%
print(classification_report(argmax(y_test, axis = 1), y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.92      0.92       852
#            1       0.58      0.66      0.62       326
#            2       0.50      0.45      0.47       208
#            3       0.54      0.60      0.57       279
#            4       0.47      0.42      0.45       264
#            5       0.38      0.53      0.44       342
#            6       0.38      0.06      0.10       192
#            7       0.28      0.39      0.33       222
#            8       0.27      0.07      0.11       122
#            9       0.20      0.11      0.14       148
#           10       0.26      0.49      0.34       216
#           11       0.26      0.15      0.19       160
#           12       0.23      0.18      0.20       136
#           13       0.29      0.32      0.30       127
#           14       0.21      0.04      0.07        77
#           15       0.23      0.27      0.25        75
#           16       0.33      0.02      0.04        51
#           17       0.34      0.68      0.45        76
#           18       0.39      0.41      0.40        29
#           19       0.00      0.00      0.00         8
#           20       0.00      0.00      0.00         1
#           22       0.00      0.00      0.00         1
#
#     accuracy                           0.50      3912
#    macro avg       0.32      0.31      0.29      3912
# weighted avg       0.50      0.50      0.48      3912
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
